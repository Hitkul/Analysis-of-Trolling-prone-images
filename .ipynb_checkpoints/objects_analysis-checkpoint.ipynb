# %%
import pandas as pd
import re
from pattern.text.en import singularize
from spellchecker import SpellChecker
spell = SpellChecker()
from tqdm import tqdm_notebook as tqdm
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.remove('other')
import string
import enchant
import pickle
d = enchant.Dict("en_US")
tqdm().pandas()
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
def datafram_from_csv(file_path):
    df = pd.read_csv(file_path,encoding='latin1')
    return df

# %%
def get_concat_data(list_of_files):
    list_of_df = [datafram_from_csv(i) for i in list_of_files]
    df = pd.concat(list_of_df, axis=0, ignore_index=True)
    return df

# %%
df = get_concat_data(['data/Insta_labeled_data/image_labels_0plus_to_10_.csv','data/Insta_labeled_data/image_labels_10plus_to_40.csv','data/Insta_labeled_data/image_labels_40plus.csv'])

# %%
df.head()
# Out:
#                                             id_image  \
# 0  https://scontent.cdninstagram.com/hphotos-xaf1...
# 1  https://scontent.cdninstagram.com/hphotos-xap1...
# 2  https://scontent.cdninstagram.com/hphotos-xap1...
# 3  https://scontent.cdninstagram.com/hphotos-xaf1...
# 4  https://scontent.cdninstagram.com/hphotos-xap1...
#
#                                          label_image
# 0  Person  Person\nCelebrity\nClothes\nText  Pers...
# 1              Person  Celebrity celebritÃ  Person
# 2  Nature\nPerson\nClothes\nFood  Person\nFood  P...
# 3                      Cartoon  Other art dontknow
# 4                        Clothes  Clothes  Clothes

# %%
duplicate_map = {
 'acres':'adress',
 'advertisment':'advertising',
    'ad':'advertising',
    'animals':'animal',
    'bicycle':'bike',
    'broke':'broken',
    'buildingslandmark':'building',
    'celebrating':'celebration',
    'cigar':'cigarette',
    'cloth':'clothe',
    'clubbing':'club',
    'musical':'music',
    'paintdrawing':'painting',
    'art':'painting',
    'artwork':'painting',
    'tv':'television',
    'showing':'show',
    'dontknow': '',
    'figurine':'figure',
    'graffiti':'graphics',
    'glas':'glass',
    'golden':'gold',
    'gras':'grass',
    'home':'house',
    'instruments':'instrument',
    'kids':'kid',
    'loading':'load',
    'motorbike':'motorcycle',
    'sex':'sensual',
    'sexy':'sensual'
}

# %%
objects = [spell.correction(singularize(j.lower())) for i in tqdm(df['label_image'].tolist()) for j in re.split(' |\n', i) if j!='']
# Out:
# HBox(children=(IntProgress(value=0, max=2260), HTML(value='')))

# %%
objects = [word for word in objects if word not in stop_words]
objects = [s.translate(str.maketrans('','',string.punctuation)) for s in objects]
objects = [duplicate_map[i] if i in duplicate_map.keys() else i for i in objects]
objects = [word for word in objects if word not in ['','ð¸ð½ñ\x82ðµñ\x80ñ\x8cðµñ\x80','ñ\x80ðµðºð»ð°ð¼ð°','load','picture','photo','nice','content','love']]

# %%
unique_objects = set(objects)
len(unique_objects)
# Out:
# 392

# %%
unique_objects
# Out:
# {'accessory',
#  'action',
#  'address',
#  'adress',
#  'advertising',
#  'advice',
#  'airplane',
#  'airport',
#  'alcohol',
#  'animal',
#  'apple',
#  'area',
#  'areawiev',
#  'arena',
#  'arm',
#  'army',
#  'article',
#  'artist',
#  'atelier',
#  'auditorium',
#  'automotive',
#  'baby',
#  'backpack',
#  'bag',
#  'bamboo',
#  'banner',
#  'barro',
#  'baseball',
#  'basketball',
#  'bathroom',
#  'beauty',
#  'bed',
#  'bedroom',
#  'behavior',
#  'best',
#  'bike',
#  'bikini',
#  'black',
#  'body',
#  'book',
#  'boot',
#  'booty',
#  'boy',
#  'broken',
#  'bu',
#  'building',
#  'burned',
#  'businesscard',
#  'buy',
#  'cake',
#  'camera',
#  'campaign',
#  'car',
#  'card',
#  'care',
#  'cartoon',
#  'cat',
#  'cd',
#  'celebration',
#  'celebrity',
#  'cellphone',
#  'chair',
#  'chandelier',
#  'christmas',
#  'church',
#  'cigarette',
#  'city',
#  'clock',
#  'clothe',
#  'cloud',
#  'club',
#  'coffee',
#  'colm',
#  'company',
#  'computer',
#  'concert',
#  'concussion',
#  'cool',
#  'coral',
#  'couple',
#  'craft',
#  'crashed',
#  'crayon',
#  'cup',
#  'currency',
#  'dance',
#  'demonstration',
#  'desktop',
#  'destruction',
#  'displayed',
#  'dj',
#  'document',
#  'dog',
#  'doll',
#  'dolly',
#  'door',
#  'drawing',
#  'drink',
#  'drug',
#  'earth',
#  'edifice',
#  'edited',
#  'education',
#  'egypt',
#  'engine',
#  'error',
#  'estrada',
#  'event',
#  'explosion',
#  'fabric',
#  'face',
#  'fact',
#  'festus',
#  'fight',
#  'figure',
#  'finger',
#  'fire',
#  'fish',
#  'fitted',
#  'flag',
#  'flight',
#  'flower',
#  'food',
#  'football',
#  'forest',
#  'forgive',
#  'found',
#  'friend',
#  'fuck',
#  'full',
#  'fun',
#  'furniture',
#  'futon',
#  'future',
#  'game',
#  'garden',
#  'get',
#  'gift',
#  'girl',
#  'glass',
#  'goal',
#  'gold',
#  'graphics',
#  'grass',
#  'greeting',
#  'guitar',
#  'gum',
#  'gun',
#  'hand',
#  'harley',
#  'harry',
#  'health',
#  'holiday',
#  'holocaust',
#  'homophony',
#  'horror',
#  'house',
#  'hunger',
#  'hunting',
#  'idol',
#  'image',
#  'inappropriate',
#  'information',
#  'injured',
#  'insect',
#  'instagram',
#  'instagrammusic',
#  'instrument',
#  'interior',
#  'it',
#  'jesu',
#  'jewelry',
#  'joke',
#  'journal',
#  'keep',
#  'keyboard',
#  'kid',
#  'kind',
#  'knife',
#  'landscape',
#  'laptop',
#  'lascar',
#  'leg',
#  'lgb',
#  'light',
#  'lighter',
#  'like',
#  'link',
#  'list',
#  'live',
#  'logo',
#  'look',
#  'luxury',
#  'lyric',
#  'made',
#  'magazine',
#  'makeup',
#  'man',
#  'manicure',
#  'many',
#  'map',
#  'masked',
#  'media',
#  'medical',
#  'medium',
#  'meeting',
#  'meme',
#  'message',
#  'mobile',
#  'model',
#  'money',
#  'moto',
#  'motorcycle',
#  'mountain',
#  'mounted',
#  'movie',
#  'muscle',
#  'music',
#  'nail',
#  'name',
#  'nature',
#  'necklace',
#  'network',
#  'new',
#  'newspaper',
#  'nickle',
#  'nickname',
#  'night',
#  'nightlife',
#  'nip',
#  'none',
#  'nude',
#  'object',
#  'office',
#  'opium',
#  'other',
#  'outdoor',
#  'page',
#  'paint',
#  'painting',
#  'paper',
#  'parachute',
#  'park',
#  'part',
#  'party',
#  'passage',
#  'passing',
#  'person',
#  'pet',
#  'phone',
#  'phrase',
#  'pic',
#  'piece',
#  'pig',
#  'place',
#  'plague',
#  'plane',
#  'plastic',
#  'playground',
#  'playing',
#  'politic',
#  'pool',
#  'portrait',
#  'pose',
#  'positive',
#  'post',
#  'postcard',
#  'poster',
#  'present',
#  'prince',
#  'product',
#  'public',
#  'publicity',
#  'puzzle',
#  'radio',
#  'ray',
#  'relationship',
#  'restaurant',
#  'riot',
#  'road',
#  'robot',
#  'room',
#  'rubber',
#  'running',
#  'satanism',
#  'scifi',
#  'screen',
#  'screenshot',
#  'secord',
#  'self',
#  'selfcare',
#  'sell',
#  'sensual',
#  'shield',
#  'shirt',
#  'shoe',
#  'show',
#  'shown',
#  'sign',
#  'signboard',
#  'singing',
#  'sitting',
#  'skate',
#  'skating',
#  'sketch',
#  'sky',
#  'smoke',
#  'smokey',
#  'smoking',
#  'snacking',
#  'snow',
#  'snowmobile',
#  'soccer',
#  'social',
#  'sofa',
#  'song',
#  'sport',
#  'square',
#  'stadium',
#  'stair',
#  'standard',
#  'statuette',
#  'studio',
#  'stuff',
#  'sunglasses',
#  'sweet',
#  'swimming',
#  'sword',
#  'symbol',
#  'taboo',
#  'talking',
#  'tampon',
#  'tank',
#  'tattoo',
#  'team',
#  'technic',
#  'technology',
#  'telefon',
#  'television',
#  'telling',
#  'term',
#  'terror',
#  'text',
#  'thing',
#  'thinking',
#  'thumb',
#  'ticket',
#  'tiger',
#  'toilet',
#  'tool',
#  'tools',
#  'tooth',
#  'tower',
#  'town',
#  'toy',
#  'traffic',
#  'trained',
#  'trash',
#  'travel',
#  'tree',
#  'tshirt',
#  'tweet',
#  'twin',
#  'uptake',
#  'urban',
#  'ux',
#  'vacation',
#  'vandal',
#  'vegetable',
#  'video',
#  'view',
#  'village',
#  'violence',
#  'vip',
#  'voting',
#  'wall',
#  'wallet',
#  'watch',
#  'weapon',
#  'web',
#  'weird',
#  'well',
#  'winter',
#  'woman',
#  'wont',
#  'wood',
#  'work',
#  'wound',
#  'wrestling',
#  'wrist',
#  'wristwatch',
#  'york'}

# %%
final_objects =[]
extras = []
result = sorted([(x, objects.count(x)) for x in unique_objects], key=lambda y: y[1])
for elem in result:
    if elem[1]>=5:
        final_objects.append(elem[0])
    else:
        extras.append(elem[0])

# %%
len(final_objects)
# Out:
# 42

# %%
with open('data/DATA_I_MADE/final_objects.pkl', 'wb') as fp:
    pickle.dump(final_objects, fp)

with open('data/DATA_I_MADE/extra_onjects.pkl', 'wb') as fp:
    pickle.dump(extras, fp)

# %% [markdown]
# ## Main work

# %%
with open('data/DATA_I_MADE/final_objects.pkl', 'rb') as fp:
    final_objects = pickle.load(fp)

with open('data/DATA_I_MADE/extra_onjects.pkl', 'rb') as fp:
    extras = pickle.load(fp)

# %%
df['label_image'].tolist()
# Out:
# ['Person  Person\nCelebrity\nClothes\nText  Person  ',
#  'Person  Celebrity celebritÃ\xa0 Person  ',
#  'Nature\nPerson\nClothes\nFood  Person\nFood  Person\nFood  ',
#  'Cartoon  Other art dontknow  ',
#  'Clothes  Clothes  Clothes  ',
#  'Person  Person\nClothes\nShoes  Person\nClothes  ',
#  'Text  Text  Text  ',
#  'Person  Person\nClothes  Person  ',
#  'Person  Person  Nature\nPerson  ',
#  'Person\nOther music Celebrity  Person  ',
#  'Person\nClothes\nShoes  Person\nClothes\nShoes  Person\nShoes  ',
#  'Clothes\nShoes  Person\nClothes\nShoes  Person\nClothes\nShoes  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person  ',
#  'Shoes  Person\nClothes\nShoes\nSports  Person\nClothes\nShoes\nSports  ',
#  'Car\nPerson\nClothes  Person  Person  ',
#  'Person\nClothes  Person\nClothes  Person  ',
#  'Person  Person coppia Person  ',
#  'Cartoon\nOther pets Other animal Cartoon  ',
#  'Person  Person  Clothes  ',
#  'Other cat Other cat Other PET ',
#  'Other Toy dontknow  Other  ',
#  'Person\nClothes standard pose Car\nPerson\nClothes\nShoes  Person\nClothes  ',
#  'Nature\nCartoon  Text  Cartoon  ',
#  'Text  Text  Text  ',
#  'Shoes  Shoes  Shoes  ',
#  'Cartoon\nClothes\nShoes\nText  Person  Cartoon\nPerson  ',
#  'Clothes\nOther dolls Person\nClothes  Person  ',
#  'Person\nFood  Person  Person\nFood  ',
#  'Text\nOther some kind of an ad Text  Other an advertisment ',
#  'Cartoon\nPerson\nFood smokey apple Person\nFood  Person\nFood  ',
#  'Person  Person  Person\nClothes  ',
#  'Person  Person  Person  ',
#  'Person\nFood  Food  Other Restaurant ',
#  'Person  Person\nClothes  Person  ',
#  'Person\nCelebrity\nText  Celebrity  Person\nCelebrity\nClothes  ',
#  'Other poster Celebrity  Other  ',
#  'dontknow  Other City Nature  ',
#  'Person  Person\nClothes  Person\nClothes  ',
#  'Person\nText  Person\nText  Person  ',
#  'Person  Person\nClothes\nText  Person  ',
#  'Person  Person\nClothes  Person  ',
#  'Person  Person  Person  ',
#  'Car\nPerson\nCelebrity\nClothes  Person\nCelebrity\nClothes\nSports  Person\nCelebrity\nClothes  ',
#  'Person\nText  Person\nClothes\nText  Person  ',
#  'Person\nClothes  Person\nClothes\nText  Clothes\nTattoo  ',
#  'Person\nClothes sweet couple Person\nClothes  Person\nCelebrity  ',
#  'Clothes  Clothes\nOther Bowties Clothes  ',
#  'Other pets Nature ANIMALS Other animal ',
#  'Person\nText  Person\nText  Tattoo  ',
#  'Person  Person  Person  ',
#  'Person\nText  Person  Person  ',
#  'Person  Person  Person  ',
#  'Text  Text  Text  ',
#  'Person\nText\nSports  Sports FITTNESS Clothes  ',
#  'Person  Person  Person\nClothes\nShoes  ',
#  'Person  Person  Person\nClothes  ',
#  'Nature\nCartoon  Cartoon  Cartoon  ',
#  'Person\nClothes  Person\nTattoo  Person  ',
#  'Other phone Other telefono Text  ',
#  'Nature\nPerson\nFood man hunting Nature\nPerson\nClothes  Nature  ',
#  'Person\nClothes  Person\nClothes  Person  ',
#  'Celebrity\nOther music Other music Other Guitar ',
#  'Person\nClothes  Person  Person  ',
#  'Person  Person  Person\nClothes\nFood  ',
#  'Person\nOther hands dontknow  Person\nText  ',
#  'Person  Person  Bike  ',
#  'Food  Food  Food  ',
#  'Person  Person  Person  ',
#  'dontknow  Cartoon vip dontknow  ',
#  'Other doll Other bambola Text\ndontknow  ',
#  'Person  Person\nTattoo  Person  ',
#  'Person  Person  Person  ',
#  'Other pets Other animal Text  ',
#  'Other education Other crayons Other  ',
#  'Person\nShoes\nText  Shoes  Person\nClothes\nShoes  ',
#  'Person\nClothes  Person\nText  Person\nClothes  ',
#  'Text  Other text Text  ',
#  'Person\nClothes\nFood  Person\nFood  Person\nFood  ',
#  'Person  Person  Person  ',
#  'Other Drawing Cartoon\ndontknow  Other  ',
#  'Person  Person\nClothes  Person\nClothes  ',
#  'Person  Person  Person  ',
#  'Celebrity\nText  Person\nCelebrity  Person\nCelebrity  ',
#  'Shoes  Shoes  Shoes  ',
#  'Person\nClothes\nShoes  Person\nClothes\nShoes  Person  ',
#  'Food  Food  Food  ',
#  'Cartoon\nPerson  Person\nCelebrity\nOther art Other Portrait ',
#  'Other animal Other Animals Other PET ',
#  'Person  Person  Person  ',
#  'Other piece of rubber gum dontknow  dontknow  ',
#  'Person  Person  Celebrity  ',
#  'Text  Text  Text  ',
#  'Person  Person  Person  ',
#  'Car  Car\nSports  Car  ',
#  'Food\nText  Food  Food\nText  ',
#  'Person  Celebrity  Person  ',
#  'Person\nClothes girl weird face Person\nClothes  Person\nClothes  ',
#  'Person  Celebrity  Person  ',
#  'Other picture Cartoon  Cartoon  ',
#  'Nature  Nature  Nature  ',
#  'Person\nText\nSports  Person\nText  Person  ',
#  'Person\nClothes  Person  Person  ',
#  'Other Meme Text  Cartoon  ',
#  'Person  Person\nCelebrity  Person\nText  ',
#  'Other  Text  Text  ',
#  'Person building Nature\nOther building Other Building ',
#  'Person  Person  Person  ',
#  'Food  Food  Food  ',
#  'Food  Food  Food  ',
#  'Person  Person  Person\nClothes\nSports  ',
#  'Car\nOther Airport Car\nOther airport Car  ',
#  'Person\nClothes\nOther music Person  Person  ',
#  'Person  Person  Person  ',
#  'Other wallet Clothes\nText  dontknow  ',
#  'Cartoon\nText  Cartoon\nText  Cartoon  ',
#  'Person\nText animals Person\nText  Nature\nPerson\nText  ',
#  'Person\nSports  Sports  Person  ',
#  'Other Outdoor, Swimming pool Nature\nPerson  dontknow  ',
#  'Person  Person  Person  ',
#  'Person\nClothes  Person  Person  ',
#  'Person  Person\nClothes\nShoes  Person\nClothes\nShoes  ',
#  'Person  Person  Person  ',
#  'Person\nClothes  Person  Person  ',
#  'Person  Person  Person  ',
#  'Person\nClothes\nTattoo  Person  Person\nTattoo  ',
#  'Other the cat Other cat Other Cat, Iphone ',
#  'Celebrity\nOther Movie Person\nCelebrity  Other tv ',
#  'Person  Celebrity  Person  ',
#  'Person  Text  Car\nPerson  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person  ',
#  'Person  Person\nClothes  Person  ',
#  'Person\nClothes  Person  Person  ',
#  'Clothes\nSports  Clothes  Clothes  ',
#  'Bike\nPerson\nClothes\nSports  Person  Person\nSports  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person\nClothes  ',
#  'Shoes  Shoes  Shoes  ',
#  'Other Drawing Cartoon  Cartoon  ',
#  'Person  Person  Person  ',
#  'Clothes  Other buy new backpack Clothes  ',
#  'Other post Text\nOther social network Text  ',
#  'Person  Celebrity  Celebrity  ',
#  'Clothes\nText  Clothes  Clothes  ',
#  'Person  Person  Person  ',
#  'Text  Text  Text  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person  ',
#  'Other instagram,music Text  dontknow  ',
#  'Car  Car  Car  ',
#  'Nature\nPerson  Person  Nature  ',
#  'Cartoon\nText  Text  Text  ',
#  'Cartoon\nPerson\nClothes  Cartoon\nClothes  Person  ',
#  'Text  Text  Text  ',
#  'Text  Text  Text  ',
#  'Person\nTattoo\nOther animal Person  Person  ',
#  'Person\nText  Text  Text  ',
#  'Nature\nPerson\nClothes\nShoes\nSports  Nature\nPerson\nSports  Person\nSports  ',
#  'Person\nClothes\nTattoo  Person\nCelebrity\nTattoo  Person  ',
#  'Person  Person\nClothes  Person\nCelebrity  ',
#  'Other  Clothes  Cartoon  ',
#  'Person  Person\nTattoo  Person  ',
#  'Food  Food\nText  Food  ',
#  'Person\nCelebrity\nClothes\nText  Celebrity\nText  Person\nText  ',
#  'Person\nCelebrity  Person  Car\nPerson  ',
#  'Person  Person  Person  ',
#  'Person  Person\nClothes  Person\nText  ',
#  'Nature\nShoes\nSports  Person  Person\nSports  ',
#  'Person  Person  Person  ',
#  'Person\nCelebrity  Person\nCelebrity\nClothes  Person\nCelebrity\nClothes  ',
#  'Text  Text\nOther image Text  ',
#  'Person\nOther love Person\nClothes  Person\nClothes  ',
#  'Tattoo  Tattoo  Tattoo  ',
#  'Text  Text  Text  ',
#  'Person\nCelebrity  Person  Person\nCelebrity\nClothes  ',
#  'Car\nCelebrity\nSports  Person  Person  ',
#  'Person\nSports  Person\nSports  Person  ',
#  'Person  Person  Person  ',
#  'Person\nSports  Celebrity\nSports  Sports  ',
#  'Person  Person\nCelebrity\nText  Person  ',
#  'Sports  Person  Person\nSports  ',
#  'Nature\nPerson\nCelebrity\nClothes\nShoes\nTattoo  Person  Person  ',
#  'Person\nText  Person\nCelebrity\nClothes\nText  Person\nCelebrity\nClothes\nFood\nText  ',
#  'Cartoon  Cartoon\nText  Text  ',
#  'Person  Person  Person  ',
#  'Other  Text  Text  ',
#  'Person\nClothes  Person  Person  ',
#  'Cartoon  Cartoon  Cartoon  ',
#  'Other An edited photo dontknow  Cartoon  ',
#  'Person\nCelebrity  Person\nSports  Person  ',
#  'Person  Person  Nature\nPerson  ',
#  'Person  Person\nSports  Person\nClothes  ',
#  'Person\nClothes  Person  Person  ',
#  'Car\nNature\nPerson  Car\nPerson  Car\nPerson  ',
#  'Clothes\nText  Person\nClothes  Person\nClothes  ',
#  'Text  Text  Text  ',
#  'Text  Text  Text  ',
#  'Tattoo  Tattoo  Tattoo  ',
#  'Other pets Other pets Other  ',
#  'Bike  Bike\nSports  Sports  ',
#  'Celebrity\nText  Text  Person\nText  ',
#  'dontknow  Car  Other  ',
#  'dontknow  dontknow  dontknow  ',
#  'Person\nCelebrity\nClothes\nText sunglasses Person\nClothes\nText  Person\nText  ',
#  'Person  Person  Person\nCelebrity\nClothes  ',
#  'Person  Person  Person  ',
#  'Person  Person\nClothes  Person  ',
#  'Person\nClothes  Person  Person  ',
#  'Cartoon  Cartoon  Cartoon  ',
#  'Other craft Other It just look like an object dontknow  ',
#  'Text\nOther Desktop Cartoon\nText\nOther computer dontknow  ',
#  'Nature  Nature  Nature  ',
#  'Text  Text  Text  ',
#  'Text  Text  Text  ',
#  'Food\nText  Food\nText  Text  ',
#  'Person\nCelebrity  Person  Person\nCelebrity  ',
#  'Person\nText  Text  Person\nFood\nText  ',
#  'Person  Person\nCelebrity\nClothes\nOther  Person  ',
#  'Other  Other phone Cartoon  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person\nClothes  ',
#  'Sports  Person\nSports  Person\nSports  ',
#  'Person  Person  Person  ',
#  'Person\nCelebrity  Person\nCelebrity\nClothes\nShoes  Person\nCelebrity  ',
#  'Other Animals Other Cat dontknow  ',
#  'Sports  dontknow  Sports  ',
#  'Person\nFood  Person  Food  ',
#  'Person  Person\nCelebrity  Person  ',
#  'Person\nText\nSports  Person\nText\nSports  Person\nText  ',
#  'Person\nCelebrity\nClothes\nSports  Person\nText\nSports  Person\nSports  ',
#  'Other Relationship Cartoon  Text  ',
#  'Person\nClothes  Person  Person  ',
#  'Person\nSports  Person  Person  ',
#  'Text  Car\nText\nOther keep positive thingking Text  ',
#  'Text  Text  Text  ',
#  'Person  Person  Person  ',
#  'Cartoon\nText  dontknow  Text  ',
#  'Text  Text  Text  ',
#  'Text  Other no image Text  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person  ',
#  'Person\nOther pictures Person\nCelebrity\nClothes  Person\nFood  ',
#  'Sports\nOther  Person\nSports  Person\nShoes  ',
#  'Person  Person  Person  ',
#  'Shoes  Shoes  Shoes  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person  ',
#  'Person\nText  Person\nCelebrity\nClothes\nText  Person\nCelebrity\nText  ',
#  'Nature\nPerson\nClothes  Person  Person  ',
#  'Person  Person\nCelebrity  Person\nCelebrity\nClothes  ',
#  'Person  Person  Person  ',
#  'Person  Person\nClothes  Person  ',
#  'Tattoo  Tattoo  Tattoo  ',
#  'Person\nCelebrity\nClothes  Celebrity  Person  ',
#  'Shoes\nSports  Shoes\nSports  Shoes\nSports  ',
#  'Person  Person  Person  ',
#  'Text love Text  Text  ',
#  'Person\nTattoo  Person\nTattoo  Tattoo  ',
#  'Cartoon\nText  dontknow  Food\nText\nOther Pictures ',
#  'Person  Person  Person  ',
#  'Person\nFood  Person\nFood  Person  ',
#  'Car\nText  Text  Text  ',
#  'Cartoon  Other Drawing dontknow  ',
#  'Bike\nPerson  Person\nClothes\nSports  Person\nSports  ',
#  'Car\nPerson\nSports nascar Car\nPerson\nClothes\nShoes\nSports  Car\nPerson  ',
#  'Person\nSports  Person\nSports  Person  ',
#  'Person phone Person\nClothes  Person  ',
#  'Person  Person  Person\nFood  ',
#  'Person  Person  Person\nClothes  ',
#  'Person\nSports  Person  Person\nClothes  ',
#  'Person\nText  Person\nClothes\nText  Person\nText  ',
#  'Nature\nPerson\nClothes\nSports  Person  Person  ',
#  'Text  Text  Text  ',
#  'Person  Person  Person  ',
#  'Person  Person\nFood  Person\nFood  ',
#  'Person  Person\nClothes\nShoes  Person  ',
#  'Person\nClothes  Person\nClothes  Person  ',
#  'dontknow  Cartoon\nText  dontknow  ',
#  'Person\nSports  Person\nSports  Person\nClothes\nShoes\nSports  ',
#  'Person\nCelebrity  Person\nClothes  Celebrity  ',
#  'Person\nClothes  Celebrity  Celebrity  ',
#  'Person\nClothes  Person  Person  ',
#  'Nature\nPerson  Nature\nPerson  Nature\nPerson  ',
#  'Cartoon\nPerson\nCelebrity\nClothes\nTattoo\nText  Celebrity  Celebrity  ',
#  'Celebrity\nSports  Person  Person\nCelebrity  ',
#  'Person\nCelebrity\nClothes  Person  Person  ',
#  'Person  Person\nCelebrity  Person  ',
#  'Person  Person\nClothes  Person\nClothes  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person\nSports  ',
#  'Person\nClothes  Person\nOther DJ Person  ',
#  'Person\nShoes\nTattoo  Shoes\nTattoo  Tattoo  ',
#  'Person\nCelebrity  Nature\nPerson\nCelebrity\nClothes nice Person  ',
#  'Person\nText  Person  Person\nClothes\nText  ',
#  'Person\nClothes\nShoes boy talking on phone Person  Person  ',
#  'Person picture Cartoon  Person  ',
#  'Person  Person\nClothes  Person  ',
#  'Other Instrumento Musical Other musical instrument Other Music, Music instrument ',
#  'Bike\nSports  Bike  Bike  ',
#  'dontknow  Person\nCelebrity\nText  Person\nCelebrity\nText  ',
#  'Person  Person  Person\nClothes  ',
#  'Person  Person  Car\nPerson\nClothes  ',
#  'Drugs  Person  Person  ',
#  'Bike\nPerson\nSports  Bike\nSports  Bike\nPerson\nSports  ',
#  'Person  Person  Person  ',
#  'Person\nCelebrity\nClothes  Person  Person\nCelebrity  ',
#  'Cartoon  Cartoon  Cartoon\nText  ',
#  'Text  Text  Text  ',
#  'Car  Car\nPerson  Car\nPerson  ',
#  'Text  Text  Text  ',
#  'Person\nSports  Person\nSports  Person\nSports  ',
#  'Cartoon\nText\nOther advice Text  Other sign ',
#  'Person  Person  Celebrity  ',
#  'Text  Text  Text  ',
#  'Person\nCelebrity\nSports  Celebrity\nClothes\nSports  Celebrity\nClothes  ',
#  'Nature\nPerson\nClothes\nSports  Person\nSports  Nature\nPerson\nSports  ',
#  'Person  Person\nCelebrity\nOther Concert Person\nClothes  ',
#  'dontknow  dontknow there is no picture dontknow  ',
#  'dontknow\nOther Broken image, not loading dontknow  Other  ',
#  'Person  Person  Nature\nPerson  ',
#  'Text  Text  Text  ',
#  'Other square Person  Person  ',
#  'Clothes  Person\nClothes  Person\nClothes  ',
#  'Person\nTattoo  Tattoo  Tattoo  ',
#  'Person\nSports  Person\nSports  Person\nClothes\nShoes\nSports  ',
#  'Tattoo  Person  Person  ',
#  'Person\nClothes\nShoes  Person\nClothes  Person  ',
#  'Person  Person  Person  ',
#  'Person\nClothes  Person\nClothes  Person  ',
#  'Person\nOther sensual content Person  Person  ',
#  'Person  Person\nSports\nOther Skate Person\nClothes\nShoes\nSports  ',
#  'Text  Text  Text  ',
#  'Sports  Sports  Sports  ',
#  'Person  Person  Person  ',
#  'dontknow  Other  dontknow  ',
#  'Celebrity  Person\nCelebrity  Person\nCelebrity  ',
#  'Person\nClothes  Person  Person  ',
#  'Person  Person\nClothes\nOther door Person\nClothes  ',
#  'Sports  Person\nText  Person  ',
#  'Person  Person  Nature\nPerson  ',
#  'Person\nCelebrity\nOther artist Person  Person\nCelebrity  ',
#  'Person  Person  Person  ',
#  'Person\nSports  Sports  Person\nSports  ',
#  'dontknow  dontknow  dontknow  ',
#  'Sports Advertising Text\nSports  Text  ',
#  'Person  Person  Person  ',
#  'Person\nOther pig Person  Person  ',
#  'Other tickets Other Entradas dontknow  ',
#  'Person\nCelebrity  Person\nClothes\nOther toys Person\nCelebrity\nSports  ',
#  'Person  Person\nClothes nice Person  ',
#  'Other trash Clothes\nText  Other room full of cool stuff ',
#  'Person  Bike\nNature\nPerson\nClothes\nShoes  Bike\nPerson  ',
#  'Person\nCelebrity  Person\nCelebrity\nClothes  Person\nCelebrity\nClothes\nText  ',
#  'Person\nClothes  Person\nOther concert Person  ',
#  'Person\nClothes  Person\nOther Baby Person  ',
#  'Person\nOther Meme Person\nClothes nice Other mame ',
#  'Celebrity  Nature\nPerson\nClothes dog, house Person\nOther animal ',
#  'Celebrity  Person\nCelebrity\nText  Celebrity  ',
#  'Person\nText\nSports  Person\nSports  Person\nSports  ',
#  'Cartoon  Cartoon  Person  ',
#  'Person  Person  Person  ',
#  'Clothes  Clothes  Clothes  ',
#  'Sports  Person  Sports  ',
#  'Person\nCelebrity\nOther Music Person  Person\nClothes  ',
#  'Person  Person  Person  ',
#  'Person\nClothes\nShoes people are celebrating  some thing Nature\nOther meeting Person  ',
#  'Text  Food\nText  Person\nOther Clubbing ',
#  'Person  Person\nCelebrity\nClothes  Celebrity  ',
#  'Celebrity  Person\nCelebrity  Person  ',
#  'Other statuette Other Nicknack Other Figurine ',
#  'Person  Person  Person  ',
#  'Text  Text  Text  ',
#  'Other interior Other ROOM Other room ',
#  'dontknow\nOther The image is not showing. Other  dontknow  ',
#  'Person\nCelebrity  Celebrity  Celebrity  ',
#  'Person  Person  Person  ',
#  'Cartoon  Other Sketch. Tattoo  ',
#  'Person\nCelebrity  Person\nOther necklace Person  ',
#  'Person  Person\nClothes  Person  ',
#  'Person\nSports  Person  Person  ',
#  'Person\nSports  Person\nClothes\nSports  Person\nCelebrity\nSports  ',
#  'Cartoon  Cartoon\nText\nOther robot Cartoon future ',
#  'Person\nTattoo\nText\nSports  Person\nSports  Person  ',
#  'Person\nShoes\nSports  Person\nCelebrity  Celebrity  ',
#  'Sports  Person  Person\nSports  ',
#  'Person  Person  Person  ',
#  'Person\nCelebrity  Text  Text  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person  ',
#  'Other songs Person\nCelebrity\nText  Text  ',
#  'Shoes  Cartoon  Shoes  ',
#  'Person  Person  Person  ',
#  'Cartoon  Cartoon  Cartoon  ',
#  'Clothes\nShoes  Clothes  Clothes  ',
#  'Food  Food  Food  ',
#  'Person\nCelebrity\nClothes\nShoes\nSports  Person\nCelebrity  Person  ',
#  'Person\nSports  Sports  Sports  ',
#  'Person  Person  Person  ',
#  'Car\nPerson\nText  Person\nText  Person\nText  ',
#  'Cartoon  Person  Cartoon  ',
#  'Cartoon  Cartoon\nPerson\nText  Cartoon  ',
#  'Person\nClothes  Person  Person  ',
#  'Other black image dontknow  dontknow  ',
#  'Person\nCelebrity\nSports  Sports  Person  ',
#  'Person\nSports  Person\nSports  Person\nSports  ',
#  'Person\nClothes  Nature\nPerson\nCelebrity  Person  ',
#  'Cartoon  Text  Cartoon  ',
#  'Person\nText  Person  Person\nClothes\nText  ',
#  'Tattoo  Tattoo  Tattoo  ',
#  'Bike\nPerson\nSports  Person  Person\nText\nSports  ',
#  'Person  Person\nOther office Person  ',
#  'Person  Person  Person  ',
#  'Person  Person\nText  Person  ',
#  'Person\nCelebrity\nSports basquetball Person  Person\nSports  ',
#  'Person\nCelebrity  Person\nCelebrity  Person\nText  ',
#  'Clothes  Clothes  Person  ',
#  'Nature\nPerson\nClothes\nText  Nature\nPerson\nText  Text  ',
#  'Text  Text  Text message ',
#  'Person  Person\nCelebrity  Person\nCelebrity  ',
#  'Other cigarette lighter Other cloth dontknow  ',
#  'Car  Car  Car\nPerson  ',
#  'Person\nCelebrity\nClothes\nShoes\nFood  Person  Person  ',
#  'Person  Person  Person  ',
#  'Person  Other  dontknow  ',
#  'Nature  Other Animal Other dog ',
#  'Person\nCelebrity  Person\nCelebrity  Person\nOther music ',
#  'Person\nCelebrity\nSports  Person\nSports  Person\nCelebrity\nSports  ',
#  'Cartoon\nText  Cartoon\nText  Cartoon\nText  ',
#  'Sports  Shoes  Shoes\nSports  ',
#  'Person  Person  Person  ',
#  'Person\nCelebrity\nClothes\nShoes  Other broken dontknow  ',
#  'Person  Person\nClothes  Person  ',
#  'Person  Person  Person\nClothes\nShoes  ',
#  'Nature\nPerson\nSports  Nature\nPerson\nSports  Nature\nSports  ',
#  'Person\nDrugs  Person  Person  ',
#  'dontknow  Food  Food  ',
#  'Person\nCelebrity\nShoes\nSports  Person\nSports  Celebrity\nSports  ',
#  'Sports  Sports  Other Audotorium ',
#  'Shoes  Shoes  Shoes  ',
#  'Person\nCelebrity\nTattoo  Person\nClothes\nShoes  Person\nClothes  ',
#  'Person\nOther music Other music Person  ',
#  'Person\nOther Photo Person  Person  ',
#  'Cartoon\nTattoo\nOther sketch Cartoon  dontknow  ',
#  'Person\nTattoo  Person  Person\nTattoo  ',
#  'Person  Person  Person\nTattoo  ',
#  'Person\nSports  Person\nCelebrity\nSports  Person\nClothes\nSports  ',
#  'Person  Person  Person  ',
#  'Shoes  Shoes  Shoes  ',
#  'Sports  Sports  Person\nSports  ',
#  'Other toy Other toys Person\nSports  ',
#  'Person\nSports  Person\nSports  Person  ',
#  'Nature  Other fish Nature\nText  ',
#  'Sports  Person  Celebrity\nSports  ',
#  'Drugs  Drugs  Drugs  ',
#  'Sports  Sports  Person\nSports  ',
#  'Bike  Bike\nPerson  Bike\nPerson  ',
#  'Other Black Cat Other  Other animal ',
#  'Sports  Sports  Person\nSports  ',
#  'Person  Person\nCelebrity  Person  ',
#  'Person\nSports  Person\nSports  Person\nSports  ',
#  'Nature  dontknow  Other corals ',
#  'Other house Other Building Nature  ',
#  'Other music Person\nCelebrity  Person\nText  ',
#  'Text  Person\nCelebrity\nText  Text  ',
#  'Person\nShoes  Person\nShoes  Other Woman Legs ',
#  'Car  Car  Car  ',
#  'Shoes  Shoes  Shoes  ',
#  'Celebrity  Person\nCelebrity\nText  Person\nText  ',
#  'Clothes  Clothes\nShoes  Clothes  ',
#  'Person  Person  Person  ',
#  'dontknow  Drugs  Drugs  ',
#  'Person  Person  Person  ',
#  'Person\nText\nOther meme Person  Person  ',
#  'Person  Person\nText  Person  ',
#  'Person\nCelebrity\nTattoo singing Person\nCelebrity  Person  ',
#  'Person  Person  Person  ',
#  'Person\nSports  Person\nSports  Sports  ',
#  'Person  Person  Person  ',
#  'Text  dontknow  Text  ',
#  'Person  Person  Person  ',
#  'Text  Person  Text  ',
#  'Text  Other cake Cartoon  ',
#  'Person\nTattoo  Person\nTattoo  Person  ',
#  'Tattoo  Tattoo  Tattoo  ',
#  'Sports  Person\nSports  Sports  ',
#  'Person  Person\nText  Celebrity\nText  ',
#  'Person  Person  Person  ',
#  'Person  Person\nSports  Person  ',
#  'Person  Nature\nPerson\nClothes  Person  ',
#  'Nature\nPerson\nText  Person  Person  ',
#  'Other web Text  Text  ',
#  'Person\nClothes pose for the photo Person  Person  ',
#  'Text  Cartoon\nOther  Cartoon  ',
#  'Person  Person  Person  ',
#  'Other building Other park Sports  ',
#  'Other Publicity Text  Text  ',
#  'dontknow  dontknow\nOther no image dontknow  ',
#  'Celebrity  Person  Person\nCelebrity  ',
#  'Celebrity  Person  Celebrity  ',
#  'Person\nOther cats Person  Person  ',
#  'Drugs  dontknow  dontknow  ',
#  'Sports  Sports  Person\nSports  ',
#  'Person  Person  Person  ',
#  'Text  Nature\nText  Nature  ',
#  'dontknow  Other no photo dontknow  ',
#  'Person\nClothes  Person\nClothes  Person  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person  ',
#  'Nature  Nature\nPerson  Person  ',
#  'Person\nSports  Sports  Sports  ',
#  'Person  Person  Person  ',
#  'Person  Person\nOther selfies Person  ',
#  'Person\nSports  Person  Person\nClothes\nShoes  ',
#  'Person  Person  Cartoon\nPerson  ',
#  'Person\nText\nSports  Sports  Person\nClothes\nShoes  ',
#  'Person  Person  Person  ',
#  'Person\nCelebrity\nSports  Person\nCelebrity  Sports  ',
#  'Nature\nPerson snow Nature\nPerson  Nature  ',
#  'Person  Person  Nature\nPerson\nSports  ',
#  'Text  Text  Text  ',
#  'Person\nCelebrity\nSports  Sports  Sports  ',
#  'Sports  Other toy Sports  ',
#  'Car\nPerson  Car  Car\nPerson  ',
#  'Person  Person  Person  ',
#  'Person\nClothes  Person  Person  ',
#  'Car  Car  Car  ',
#  'Sports  Sports  Person\nSports  ',
#  'Person\nClothes  Person\nClothes  Person\nClothes  ',
#  'dontknow  Text  Text  ',
#  'Person  Nature\nPerson  Nature\nPerson\nSports  ',
#  'Sports  Person  Person  ',
#  'Person  Person\nClothes  Person  ',
#  'Clothes  Clothes  Clothes  ',
#  'Nature  Nature  Nature  ',
#  'Food  Food  Food  ',
#  'Person\nOther Social media Other  Text  ',
#  'Person\nClothes\nShoes\nSports playing skating Person  Other kids ',
#  'Tattoo  Tattoo  Person\nTattoo  ',
#  'Person  Person  Person  ',
#  'Cartoon tools, picture Other Paint/Drawing Other Art ',
#  'Nature\nPerson  Nature\nPerson\nCelebrity  Person  ',
#  'Person  Sports  Person\nSports  ',
#  'Other Ñ\x80ÐµÐºÐ»Ð°Ð¼Ð° Text  Text  ',
#  'Text\ndontknow terms Text  Text  ',
#  'Tattoo  Person\nTattoo  Tattoo  ',
#  'Text  Text  Text  ',
#  'Tattoo  Other Tatoo Tattoo  ',
#  'Nature\nPerson  Person  Person  ',
#  'dontknow  Other tools Other weapon ',
#  'Other glass dontknow  Drugs  ',
#  'Person  Person  Person\nText  ',
#  'Person\nSports  Person\nSports  Person\nSports skating ',
#  'Person  Person  Person\nCelebrity  ',
#  'Person\nSports  Sports  Sports  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person  ',
#  'Tattoo  Person\nTattoo tiger Tattoo  ',
#  'Person\nOther snow Other winter Nature  ',
#  'Clothes\nOther animal Other cat Person  ',
#  "Other doll's Person  Person\nClothes  ",
#  'Person\nText\nSports  Sports  Person\nSports  ',
#  'Person\nCelebrity\nSports  Sports  Sports  ',
#  'Person  Person\nSports  Nature\nPerson\nSports  ',
#  'Person  Person  Person  ',
#  'Car  Car  Car  ',
#  'Person  Person  Person  ',
#  'Other Ð¸Ð½Ñ\x82ÐµÑ\x80Ñ\x8cÐµÑ\x80 Other House Other House ',
#  'Person  Text  Text  ',
#  'Other radio Text  Text  ',
#  'Person  Person  Person  ',
#  'Tattoo tattoo Person  Tattoo  ',
#  'Person\nTattoo\nText  Person\nCelebrity\nTattoo\nText  Person  ',
#  'Other No image Other  dontknow  ',
#  'Person  Person\nText airport Person\nText  ',
#  'Text  Person\nText  Text  ',
#  'Text  Other  Nature  ',
#  'Person  Person  Person  ',
#  'Other weapon Nature  Person  ',
#  'Person\nSports  Nature\nPerson  Nature\nPerson  ',
#  'Person  Person\nFood  Person  ',
#  'Person\nCelebrity\nSports  Sports  Person\nCelebrity\nSports  ',
#  'dontknow  Celebrity  Clothes  ',
#  'Person\nCelebrity\nClothes possing Person  Person  ',
#  'Bike\nSports  Sports  Bike\nPerson  ',
#  'Celebrity  Person  Celebrity\nDrugs\nText  ',
#  'Nature  Car\nNature  Nature  ',
#  'Person\nCelebrity\nClothes  Cartoon\nText  Person\nSports  ',
#  'Person\nCelebrity\nText  Person  Person  ',
#  'Tattoo  Person\nTattoo  Person\nTattoo  ',
#  'Person\nClothes\nTattoo  Person  Person  ',
#  'Person  Text  Text cd ',
#  'Cartoon\nPerson  Person\nCelebrity  Celebrity  ',
#  'Person  Person  Person\nCelebrity  ',
#  'Car\nText running Car  Car  ',
#  'Person\nCelebrity  Person  Person  ',
#  'dontknow  Person  Other  ',
#  'dontknow\nOther sci-fi dontknow  dontknow  ',
#  'Tattoo  Person\nTattoo  Tattoo  ',
#  'Person  Person\nClothes  Person  ',
#  'Person  Person  Person  ',
#  'Nature\nPerson\nSports  Sports  Sports  ',
#  'Car\nPerson\nClothes\nShoes  Car\nPerson  Car\nPerson  ',
#  'Person  Person  Celebrity  ',
#  'Nature\nOther event Nature  Nature\nOther  ',
#  'Sports Games Sports  Other  ',
#  'Other song list Other songs Text  ',
#  'Person  Person  Person  ',
#  'Celebrity\nSports  Person  Sports  ',
#  'Cartoon\nPerson  Person  Cartoon  ',
#  'Person  Person\nCelebrity\nClothes\nShoes  Person  ',
#  'Person\nCelebrity  Person\nCelebrity\nClothes  Person  ',
#  'Person  Person  Person\nClothes  ',
#  'Person  Person  Person\nClothes  ',
#  'Person\nCelebrity\nClothes\nTattoo\nText  Person\nCelebrity  Celebrity  ',
#  'Other Medical Other XRAY Other  ',
#  'Person\nSports muscles Person  Person  ',
#  'Person  Person  Person\nCelebrity  ',
#  'Sports  Person\nSports  Person\nSports  ',
#  'Other  Other drawing Cartoon  ',
#  'Person  Person\nClothes\nSports  Person  ',
#  'Text  Bike  dontknow  ',
#  'Other laptop Other computer Celebrity  ',
#  'Person\nClothes  Person\nText  Person\nClothes  ',
#  'Person\nSports  Nature\nPerson\nSports  Nature\nPerson\nClothes\nSports  ',
#  'Person\nText  Person\nCelebrity  Person\nCelebrity  ',
#  'Other Stairs Nature\nCartoon  dontknow  ',
#  'Person\nSports  Person\nText  Person  ',
#  'Other money , sell . buy Other money Other money ',
#  'Food  Food  dontknow  ',
#  'Person\nSports  Person  Person  ',
#  'Person  Person  Person  ',
#  'Person  Clothes  Person\nCelebrity  ',
#  'Person\nCelebrity  Person\nClothes  Person  ',
#  'Clothes\nShoes  Clothes\nShoes\nSports  Clothes\nShoes  ',
#  'Nature\nPerson\nSports  Person  Car\nPerson  ',
#  'Person\nCelebrity  Person\nText  Person\nClothes  ',
#  'Bike  dontknow  Bike  ',
#  'Person  Nature\nPerson\nText  Person  ',
#  'Cartoon\nPerson  Person  Person  ',
#  'Sports  Other edifice Other buiding ',
#  'Food  Other Plastic Other Ñ\x80ÐµÐºÐ»Ð°Ð¼Ð° ',
#  'Person  Person  Person  ',
#  'Person  Person  Person  ',
#  'Person\nCelebrity  Person\nCelebrity\nSports  Person\nCelebrity  ',
#  'Person\nCelebrity\nTattoo\nText\nSports  Person\nSports  Sports  ',
#  'Car\nNature  Other paisajes urbanos Car\nNature  ',
#  'Nature\nPerson  Person  Nature\nPerson  ',
#  'Tattoo  Tattoo  Tattoo  ',
#  'Person  Celebrity  Person\nTattoo  ',
#  'dontknow\nOther baÃ±o dontknow  dontknow  ',
#  'Other Love Person  Person  ',
#  'Shoes\nTattoo  Shoes  Shoes  ',
#  'Text  Text  Text  ',
#  'Person  Other Music Person music ',
#  'Person\nText  Person  Person  ',
#  'Shoes  Shoes  Shoes  ',
#  'Drugs  Person  Person\nClothes  ',
#  'Person\nSports  Celebrity  Person\nSports  ',
#  'Person\nText  Other Horror Text  ',
#  'dontknow  Other tools Bike  ',
#  'Clothes  Person  Person  ',
#  'Sports  Person\nSports  Sports  ',
#  'Clothes  Clothes  Clothes  ',
#  'Person  Person  Person\nClothes  ',
#  'Person\nCelebrity  Person  Celebrity  ',
#  'Tattoo  Tattoo  Tattoo  ',
#  'Other Show Person\nCelebrity  Celebrity  ',
#  'Person\nClothes ass Person  Other  ',
#  'Person\nCelebrity  Person  Person  ',
#  'Person  Person  Person  ',
#  'Person\nSports basketball Person\nClothes\nSports  Person  ',
#  'Person\nText  Bike\nCartoon\nPerson  Person  ',
#  'Tattoo  Tattoo  Tattoo  ',
#  'Person  Person\nSports  Person\nSports  ',
#  'Person\nClothes  Person\nSports  Person\nSports  ',
#  'Sports  Sports  Sports  ',
#  'Person  Person\nTattoo  Person\nShoes  ',
#  'Tattoo  Tattoo  Tattoo  ',
#  'Person\nClothes  Person  Person\nCelebrity  ',
#  'Sports  Person\nCelebrity\nClothes\nSports  Sports  ',
#  'Person  Person  Car\nPerson  ',
#  'Person  Person  Person\nClothes  ',
#  'Text  Text  Other  ',
#  'dontknow  dontknow  dontknow  ',
#  'dontknow  Other broken dontknow  ',
#  'Person\nTattoo  Sports  Person\nCelebrity  ',
#  'Sports  Nature\nPerson\nSports  Person\nSports  ',
#  'Text  Text  Text  ',
#  'Person  Person  Person  ',
#  'Person  Sports  Celebrity  ',
#  'Person  Person  Person  ',
#  'Other wristwatch Other golden wrist watch Other clock ',
#  'Person\nCelebrity\nClothes  Person  Person  ',
#  'Text  Text  Text  ',
#  'Person\nClothes  Person  Person  ',
#  'Person  Person  Person  ',
#  'Text  Text  Text  ',
#  'Person\nCelebrity  Person\nCelebrity  Celebrity  ',
#  'Person  Person  Celebrity model ',
#  'Celebrity\nText  Person\nSports  Other  ',
#  'Person  Car\nPerson  Car\nPerson  ',
#  'Person\nClothes  Person  Person  ',
#  'Sports  Tattoo  Sports  ',
#  'Person  Person  Person  ',
#  'Other Fandals Other public bathroom dontknow  ',
#  'Person\nTattoo\nOther sexy Person  Person  ',
#  'Tattoo\nText  Text  Text  ',
#  'Sports  Sports  Sports  ',
#  'Person  Nature\nPerson\nClothes  Person  ',
#  'Person\nClothes  Person\nOther Baseball Person  ',
#  'Food  Food  Food  ',
#  'Person\nClothes\nTattoo  Person\nTattoo  Person  ',
#  'Person  Person  Person  ',
#  'Bike\nSports  Sports  Bike\nPerson\nClothes\nShoes\nSports  ',
#  'Person\nCelebrity celebrity Person\nSports  Person\nClothes  ',
#  'Person music Person  Person  ',
#  'Shoes\nSports soccer Person\nShoes\nSports  Sports  ',
#  'Clothes thinking Person  Person  ',
#  'Celebrity music Person  Person\nCelebrity  ',
#  'Person\nSports  Sports  Person\nSports  ',
#  'Person  Person  Person  ',
#  'Person\nCelebrity\nTattoo  Person  Person  ',
#  'Other dogs Other dogs Other dog ',
#  'Person  Person  Person  ',
#  'Other voting page Text  Text  ',
#  'Person\nSports  Person\nSports  Bike\nSports  ',
#  'dontknow  dontknow\nOther Image Broken dontknow broken ',
#  'Food  Other cupcake Food  ',
#  'Tattoo  Tattoo  Person\nTattoo\nText  ',
#  'Other Social Media, Tweets Text  Text  ',
#  'Sports  Person\nSports  Sports  ',
#  'Person  Person  Person  ',
#  'Bike  Bike  Other motorbike ',
#  'Person  Person  Person  ',
#  'Cartoon\nPerson\nCelebrity  Person\nCelebrity  Celebrity  ',
#  'Car  Other Flight Car\nBike  ',
#  'Person  Person  Person  ',
#  'Person  Person\nSports  Person\nSports  ',
#  'Person  Person  Person  ',
#  'Person\nSports  Person\nSports  Sports  ',
#  'Cartoon  Cartoon  Cartoon  ',
#  'Person\nSports  Person  Person  ',
#  'Person\nClothes\nOther sword Person  Person  ',
#  'Person  Person\nSports  Person  ',
#  'Person  Person  Celebrity  ',
#  'Person\nSports  Sports  Person  ',
#  'Other image is not load dontknow  dontknow  ',
#  'Bike  Text  Text  ',
#  'Person\nCelebrity  Person\nCelebrity\nText  Person  ',
#  'Person  Person  Person  ',
#  'Nature\nOther building Nature  Nature  ',
#  'Text  Text  Text  ',
#  'Person\nSports team Person\nSports  Person\nSports  ',
#  'Person\nSports  Sports  Person  ',
#  'Person  Person  Person\nClothes  ',
#  'Person  Person  Person  ',
#  'Person\nSports  Person\nSports  Celebrity\nSports  ',
#  'Person  Person  Person  ',
#  'Person\ndontknow  Person  Person  ',
#  'Person  Person  Person  ',
#  'Shoes  Shoes\nSports  Shoes  ',
#  'Sports  Person\nSports  Sports  ',
#  'Person\nClothes  Person  Clothes  ',
#  'Other Broken Other broken dontknow  ',
#  'Person\nCelebrity  Person  Celebrity  ',
#  'Person\nSports trained Person\nClothes\nShoes  Person  ',
#  'Celebrity  Person  Person  ',
#  'Clothes\nShoes  Clothes  Person\nClothes  ',
#  'Person  Other kids Person\nClothes  ',
#  'Cartoon  Cartoon  Cartoon  ',
#  'Tattoo  Other Art Person\nTattoo  ',
#  'Clothes  Clothes\nSports  Celebrity\nText\nSports  ',
#  'Sports  Person\nSports  Person\nClothes\nSports  ',
#  'Person\nText\nSports  Person  Person\nSports  ',
#  'Person\nClothes  Person\nSports  Person\nClothes\nSports  ',
#  'Other Action Figure Other toy Cartoon  ',
#  'Person\nCelebrity\nTattoo  Celebrity\nText  Person\nCelebrity\nText  ',
#  'Person\nTattoo Travel Person\nClothes\nTattoo  Person\nCelebrity  ',
#  'Person  Other Army Person  ',
#  'Person  Person  Person  ',
#  'Person\nCelebrity\nSports  Person  Person  ',
#  'Text  Text  Other Home ',
#  'Person  Person  Person  ',
#  'Person\nTattoo  Tattoo  Tattoo  ',
#  'Person  Other Kid Person  ',
#  'Person sensual content Person  Person  ',
#  'Drugs  Other drugs Drugs  ',
#  'Nature  dontknow  dontknow  ',
#  'Tattoo  Tattoo  Other tattoo ',
#  'Person\nCelebrity  Other concert Celebrity  ',
#  'Person\nSports  Person\nSports  Person\nSports  ',
#  'Nature\nText\nOther sign Nature\nText traffic sign Nature  ',
#  'Person  Person  Person  ',
#  'Text  Other Fun fact. Text  ',
#  'Person\nClothes  Person  Person\nCelebrity  ',
#  'Nature\nPerson\nClothes  Person  Nature\nPerson  ',
#  'Shoes  Shoes  Shoes  ',
#  'Person  Person  Person  ',
#  'Car traficc Car  Car  ',
#  'Other FLOWER Tattoo\nText  Tattoo\nText  ',
#  'Clothes  Clothes  Clothes\nShoes  ',
#  'Person\nSports  Person\nCelebrity\nSports  Sports  ',
#  'Other dog Nature\nOther dogs Other dogs ',
#  'Other Broken dontknow\nOther  Other  ',
#  'Other TV Other Television Show dontknow  ',
#  'Person  Person  Person  ',
#  'Nature\nPerson  Person  Person  ',
#  'Person  Person  Person  ',
#  'Food  Food  Other  ',
#  'Text  Text  Text  ',
#  'Person\nSports  Person\nSports  Person\nSports  ',
#  'Person  Person\nCelebrity\nClothes\nSports  Person  ',
#  'Person  Person  Person  ',
#  'Person\nOther sex? Other  Person\nClothes  ',
#  'Other toilet dontknow  dontknow  ',
#  'Sports  Person  Person  ',
#  'Car\nSports  dontknow  Car  ',
#  'Sports  Person  Person  ',
#  'Person  Person\nCelebrity selfie Person  ',
#  'Other Broken Other  Other no image ',
#  'Person\nCelebrity\nOther animals Celebrity  Person  ',
#  'Person\nCelebrity party Person  Person  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person  ',
#  'Sports  Person\nSports  Person\nSports futbol ',
#  'Person\nCelebrity\nText  Person\nCelebrity  Celebrity\nText  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person  ',
#  'Nature  Nature garden Nature  ',
#  'Person  Person  Person  ',
#  'Person  Person\nClothes  Celebrity  ',
#  'Person  Person  Person  ',
#  'Sports  Sports  Sports  ',
#  'Car  Car  Car  ',
#  'Celebrity sitting Person  Person  ',
#  'Person  Person  Person  ',
#  'Person\ndontknow  Celebrity  Person  ',
#  'Nature  Other tattoo Tattoo  ',
#  'Clothes\nText\nSports  Clothes  Clothes  ',
#  'Person\nClothes\nSports  Person\nSports  Person  ',
#  'Text  Text  Text  ',
#  'Bike  Bike  Bike  ',
#  'Person  Person  Person  ',
#  'Person\nCelebrity\nSports\nOther health Person  Celebrity  ',
#  'Person  Person\nCelebrity  Person  ',
#  'Text  Text  Text  ',
#  'Person\nSports  Person\nSports  Person\nSports  ',
#  'Person  Person\nClothes\nSports  Person\nSports  ',
#  'Text  Text  Text  ',
#  'Person Alcohol Person\nOther alkohol Person  ',
#  'Person\nSports  Sports  Sports  ',
#  'Nature  Other building Nature\nOther Building ',
#  'Person\nSports  Sports  Sports  ',
#  'Other Document Other  Text\nOther book ',
#  'Person\nDrugs  Drugs  Drugs  ',
#  'Person\nOther Politics Person\nCelebrity  Person\nCelebrity  ',
#  'Person\nOther  Person  Person  ',
#  'Nature\nPerson\nClothes  Person  Person  ',
#  'Tattoo  Tattoo  Person  ',
#  'Person  Person  Person  ',
#  'Other pet Other dog Other dog ',
#  'Celebrity\nSports  Person\nCelebrity\nSports  Person toy ',
#  'Text  Text  Text  ',
#  'Shoes\nSports  Shoes  Shoes  ',
#  'Person\nCelebrity\nSports  Person\nSports  Sports  ',
#  'Other game Cartoon  Text  ',
#  'Person  Person\nCelebrity  Person  ',
#  'Nature\nPerson\nSports  Nature\nPerson\nSports  Nature\nSports  ',
#  'Person  Celebrity  Person  ',
#  'Person\nText  Person\nText  Person\nText  ',
#  'Person  Nature\nPerson  Person  ',
#  'Person\nText  Person  Person  ',
#  'Text telloing Text  Text  ',
#  'Person  Nature\nPerson\nClothes  Nature\nPerson\nClothes  ',
#  'Person\nSports  Person  Other dance ',
#  'Person\nClothes  Person  Person  ',
#  'Car\nPerson thinking Person  Car\nPerson  ',
#  'Cartoon  Cartoon\nText  Cartoon  ',
#  'Bike\nPerson  Bike  Bike\nPerson  ',
#  'Person\nCelebrity\nClothes  Person  Celebrity  ',
#  'Person\nSports  Person\nSports  Person\nSports  ',
#  'Person  Person  Person  ',
#  'Person\nSports  Sports  Sports  ',
#  'Food  dontknow  Other tampons ',
#  'Person  Person\nClothes  Person  ',
#  'Person  Person  Person  ',
#  'Food  Food  Food  ',
#  'Person\nOther concert Celebrity  Celebrity  ',
#  'Car  Car  Car  ',
#  'Person  Person  Person\nSports  ',
#  'Cartoon  Cartoon  Cartoon\nText  ',
#  'Person\nOther work Person  Person  ',
#  'Person\nOther cellphone Person\nOther phones Person  ',
#  'Person  Person  Person  ',
#  'Person  Person  Person  ',
#  'Person\nSports  Person\nSports  Person\nSports  ',
#  'Sports  Sports  Person\nSports  ',
#  'Shoes  Shoes  Shoes  ',
#  'Person  Person  Person  ',
#  'Nature\nText  Nature\nText  Text  ',
#  'Text\nOther logo Other Advertising Sports  ',
#  'Person\nCelebrity\nText  Person\nText  Person  ',
#  'Person\nClothes  Person\nCelebrity\nClothes\nText  Person  ',
#  'Other signboard Other road lights and signs Other post ',
#  'Food  Food  Food  ',
#  'Tattoo  Tattoo\nText  Tattoo  ',
#  'Person  Person  Person\nClothes  ',
#  'Person  Person  Person\nClothes  ',
#  'Text  Text  Text  ',
#  'Sports  Person  Person\nSports  ',
#  'Drugs  Nature\nDrugs\nTattoo  Food  ',
#  'Person\nSports  Person\nSports  Person\nSports  ',
#  'Person  Person\nText  Person  ',
#  'Person  Person  Person  ',
#  'Text  Text  Text  ',
#  'Tattoo  Person  Tattoo  ',
#  'Celebrity  Celebrity  Person\nCelebrity\nClothes  ',
#  'Text  Text  Text  ',
#  'Person  Person  Person  ',
#  'Other the concert Other music Other concert ',
#  'Person  Nature\nPerson  Nature  ',
#  'Person\nSports  Cartoon  Car\nPerson\nClothes\nShoes  ',
#  'Food  dontknow  Food  ',
#  'Bike\nPerson  Bike\nPerson\nClothes\nSports  Bike  ',
#  'Other gold Other  Other gold ',
#  'Other joke Text  Text  ',
#  'Other no image dontknow broken Other broken ',
#  'Tattoo  Tattoo  Tattoo  ',
#  'Person  Person\nClothes  Person  ',
#  'Tattoo  Person\nTattoo\nText  Person  ',
#  'Text  Other Animal. Text Animals ',
#  'Cartoon  Other dolls Cartoon  ',
#  'Person  Person  Person  ',
#  'Other no image dontknow  dontknow  ',
#  'Person\nClothes  Person\nCelebrity  Celebrity  ',
#  'Person  Person\nClothes  Person\nOther Vacation ',
#  'Person  Tattoo  Person\nCelebrity  ',
#  'Person\nText  Person  Person  ',
#  'Person\nClothes\nShoes  Person\nCelebrity  Person  ',
#  'Person  Person  Person  ',
#  'Celebrity\nSports  Person\nSports  Person\nClothes\nSports  ',
#  'Celebrity\nOther twin towers new york city Other  Other city ',
#  'Person  Person  Person  ',
#  'Person\nOther glasses Person  Person  ',
#  'Text  Other phrases Text  ',
#  'Person\nCelebrity\nSports\nOther wrestling Sports  Sports  ',
#  'Person\nSports  Sports  Person\nCelebrity\nSports goal ',
#  'Person\nTattoo made tattoo Tattoo  Tattoo  ',
#  'Celebrity  Person\nCelebrity  Person  ',
#  'Car\nBike\nPerson  Person  Person  ',
#  'Other Buildings/Landmarks Other Building dontknow  ',
#  'Text\nOther clock Text\nOther clock Other clock ',
#  'Person  Person\nSports  Person  ',
#  'Other  Car  Text  ',
#  'Other prince of egypt image Tattoo  dontknow  ',
#  'Tattoo  Tattoo  Tattoo  ',
#  'Person  Person  Person\nClothes  ',
#  'Nature  Nature  Other grass ',
#  'Person  Person  Person  ',
#  'Person\nCelebrity  Person  Person  ',
#  'Sports  Bike\nPerson  Bike\nPerson  ',
#  'Sports  Person  Person  ',
#  'Person  Person  Person  ',
#  'Person\nClothes  Person  Person  ',
#  'Person  Person  Person\nClothes  ',
#  'Person  Person\nCelebrity  Person  ',
#  'Person  Person\nSports  Person  ',
#  'Text  Person\nText  Person  ',
#  'Person\nCelebrity  Person  Person  ',
#  'Text  Text  Text  ',
#  'Tattoo  Person\nTattoo  Person\nTattoo  ',
#  'Car  Car  Car  ',
#  'dontknow  Other  dontknow  ',
#  'Other no image dontknow  dontknow  ',
#  'Person\nCelebrity  Person  Person\nCelebrity\nText  ',
#  'Person\nSports  Sports  Sports  ',
#  'Person  Person  Person  ',
#  'Car\nPerson\nCelebrity  Car\nPerson\nText  Car  ',
#  'Celebrity  Other Arena Other  ',
#  'Person  Person  Person\ndontknow  ',
#  'Person  Person  Person  ',
#  'Text message Person\nCelebrity\nText  Person  ',
#  'Person  Person\nText  Person  ',
#  'Other toilet dontknow  Other Toilet ',
#  'Tattoo  Person\nTattoo\nText  Tattoo  ',
#  'Person  Sports  Person  ',
#  'Cartoon  Cartoon\nPerson beauty Tattoo  ',
#  'Cartoon\nPerson  Cartoon\nPerson  Cartoon  ',
#  'Other colour dontknow  dontknow  ',
#  'Person\nText  Person\nCelebrity\nText  Person  ',
#  'Person\nDrugs smoking Person  Person  ',
#  'Person\nTattoo  Tattoo  Tattoo  ',
#  'Person\nCelebrity  Celebrity\nClothes  Person  ',
#  'Car  Car  Car  ',
#  'Person\nSports  Sports  Sports  ',
#  'Other studio Other Office dontknow  ',
#  'Person\nCelebrity\nClothes\nText  Person\nCelebrity\nText  Celebrity\nText  ',
#  ...]

# %%
def pre_process_class(objects_str):
    objects = [spell.correction(singularize(j.lower())) for j in re.split(' |\n', objects_str) if j!='']
    objects = [word for word in objects if word not in stop_words]
    objects = [s.translate(str.maketrans('','',string.punctuation)) for s in objects]
    objects = [duplicate_map[i] if i in duplicate_map.keys() else i for i in objects]
    objects = [word for word in objects if word not in ['','ð¸ð½ñ\x82ðµñ\x80ñ\x8cðµñ\x80','ñ\x80ðµðºð»ð°ð¼ð°','load','picture','photo','nice','content','love']]
    objects = [w for w in objects if w in final_objects]
    return list(set(objects))

# %%
def get_object_in_row(row):
    return pre_process_class(row['label_image'])

# %%
df['objects'] = df.progress_apply(lambda row: get_object_in_row(row),axis=1)
# Out:
# HBox(children=(IntProgress(value=0, max=2260), HTML(value='')))

# %%
df.head()
# Out:
#                                             id_image  \
# 0  https://scontent.cdninstagram.com/hphotos-xaf1...
# 1  https://scontent.cdninstagram.com/hphotos-xap1...
# 2  https://scontent.cdninstagram.com/hphotos-xap1...
# 3  https://scontent.cdninstagram.com/hphotos-xaf1...
# 4  https://scontent.cdninstagram.com/hphotos-xap1...
#
#                                          label_image  \
# 0  Person  Person\nCelebrity\nClothes\nText  Pers...
# 1              Person  Celebrity celebritÃ  Person
# 2  Nature\nPerson\nClothes\nFood  Person\nFood  P...
# 3                      Cartoon  Other art dontknow
# 4                        Clothes  Clothes  Clothes
#
#                              objects
# 0  [text, clothe, celebrity, person]
# 1                [celebrity, person]
# 2     [nature, clothe, food, person]
# 3         [cartoon, painting, other]
# 4                           [clothe]

# %%
with open('data/DATA_I_MADE/objects_df.pkl', 'wb') as fp:
    pickle.dump(df, fp)

# %% [markdown]
# ## Start here

# %%
with open('data/DATA_I_MADE/objects_df.pkl', 'rb') as fp:
    df = pickle.load(fp)

# %%
df.head()
# Out:
#                                             id_image  \
# 0  https://scontent.cdninstagram.com/hphotos-xaf1...
# 1  https://scontent.cdninstagram.com/hphotos-xap1...
# 2  https://scontent.cdninstagram.com/hphotos-xap1...
# 3  https://scontent.cdninstagram.com/hphotos-xaf1...
# 4  https://scontent.cdninstagram.com/hphotos-xap1...
#
#                                          label_image  \
# 0  Person  Person\nCelebrity\nClothes\nText  Pers...
# 1              Person  Celebrity celebritÃ  Person
# 2  Nature\nPerson\nClothes\nFood  Person\nFood  P...
# 3                      Cartoon  Other art dontknow
# 4                        Clothes  Clothes  Clothes
#
#                              objects
# 0  [text, clothe, celebrity, person]
# 1                [celebrity, person]
# 2     [nature, clothe, food, person]
# 3         [cartoon, painting, other]
# 4                           [clothe]

# %%
img_urls_object_file = df['id_image'].tolist()

# %% [markdown]
# session file

# %%
df_labels = get_concat_data(['data/Insta_labeled_data/sessions_0plus_to_10_metadata.csv','data/Insta_labeled_data/sessions_10plus_to_40_metadata.csv','data/Insta_labeled_data/sessions_40plus_metadata.csv'])
# Out:
# /home/hitkul/anaconda3/envs/nii_project/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
img_urls_session_file = df_labels['img_url'].tolist()

# %% [markdown]
# final file

# %%
with open('data/DATA_I_MADE/final_csv_with_image_names.pkl', 'rb') as fp:
    df_final = pickle.load(fp)

# %%
df_final = df_final[df_final.final_image_name.notnull()]

# %%
img_url_final_file = df_final['img_url'].tolist()

# %% [markdown]
# images mapping

# %%
list_of_files = ['data/instagram_images/namesall_info_media_ids_to_collect_0plus_to_10.txt','data/instagram_images/namesall_info_media_ids_to_collect_10plus_to_40.txt','data/instagram_images/namesall_info_media_ids_to_collect_40plus.txt']
list_of_df = [pd.read_csv(i, sep=' ',names=['image_id','links']) for i in list_of_files]
df_image_folder = pd.concat(list_of_df, axis=0, ignore_index=True)

# %%
img_urls_image_file = df_image_folder['links'].tolist()

# %%
img_url_final_file = [i.replace('\n','').replace('\r','') for i in img_url_final_file]
img_urls_image_file = [i.replace('\n','').replace('\r','') for i in img_urls_image_file]
img_urls_object_file = [i.replace('\n','').replace('\r','') for i in img_urls_object_file]
img_urls_session_file = [i.replace('\n','').replace('\r','') for i in img_urls_session_file]

# %% [markdown]
# matching

# %%
len(set(img_urls_object_file)),len(set(img_urls_session_file)),len(set(img_url_final_file)),len(set(img_urls_image_file))
# Out:
# (2242, 2216, 1099, 1921)

# %%
len(set(img_urls_object_file)&set(img_urls_session_file))
# Out:
# 2213

# %%
len(set(img_urls_object_file)&set(img_url_final_file))
# Out:
# 1097

# %%
len(set(img_urls_object_file)&set(img_urls_image_file))
# Out:
# 138
