# %% [markdown]
# ## Instagram_images

# %%
import pandas as pd
from os import listdir
import json
import re
from pprint import pprint
from fuzzywuzzy import process
from tqdm import tqdm_notebook as tqdm
# from tqdm import tqdm

# %%
def get_imageid_link_lists(filename):
    df = pd.read_csv(filename, sep=' ',names=['image_id','links'])
    return df['image_id'].tolist(),df['links'].tolist()

# %%
def get_filenames_in_folder(foldername):
    return [i.replace('.jpg','') for i in listdir(foldername)]

# %%
def show_image_id_txt_file_map(filename,foldername):
    image_id,links = get_imageid_link_lists(filename)
    image_ids_folder = get_filenames_in_folder(foldername)
    print(f"FOLDER = {foldername.split('/')[-2]} and FILE= {filename.split('/')[-1]}")
    print(f"Total id and links present in txt file are {len(image_id),len(links)}")
    print(f"Total unique id and links present in txt file are {len(set(image_id)),len(set(links))}")
    print(f"Total images present in folder {len(image_ids_folder)}")
    print(f"Total unique images present in folder {len(set(image_ids_folder))}")
    print(f"Number of images present in both sets {len(set(image_ids_folder)&set(image_id))}")
    print(f"Number of IDs present in file but not in folder {len(set(image_id)-set(image_ids_folder))}")
    print(f"Number of IDs present in folder but not in file {len(set(image_ids_folder)-set(image_id))}")
    return image_id,image_ids_folder

# %%
image_id_0_10_file,image_id_0_10_folder = show_image_id_txt_file_map('data/instagram_images/namesall_info_media_ids_to_collect_0plus_to_10.txt','data/instagram_images/images_0_10/')
# Out:
# FOLDER = images_0_10 and FILE= namesall_info_media_ids_to_collect_0plus_to_10.txt
# Total id and links present in txt file are (270, 270)
# Total unique id and links present in txt file are (270, 270)
# Total images present in folder 276
# Total unique images present in folder 276
# Number of images present in both sets 267
# Number of IDs present in file but not in folder 3
# Number of IDs present in folder but not in file 9

# %%
image_id_10_40_file,image_id_10_40_folder = show_image_id_txt_file_map('data/instagram_images/namesall_info_media_ids_to_collect_10plus_to_40.txt','data/instagram_images/images_10_40/')
# Out:
# FOLDER = images_10_40 and FILE= namesall_info_media_ids_to_collect_10plus_to_40.txt
# Total id and links present in txt file are (835, 835)
# Total unique id and links present in txt file are (835, 835)
# Total images present in folder 987
# Total unique images present in folder 987
# Number of images present in both sets 831
# Number of IDs present in file but not in folder 4
# Number of IDs present in folder but not in file 156

# %%
image_id_40_plus_file,image_id_40_plus_folder = show_image_id_txt_file_map('data/instagram_images/namesall_info_media_ids_to_collect_40plus.txt','data/instagram_images/images_40plus//')
# Out:
# FOLDER =  and FILE= namesall_info_media_ids_to_collect_40plus.txt
# Total id and links present in txt file are (816, 816)
# Total unique id and links present in txt file are (816, 816)
# Total images present in folder 1000
# Total unique images present in folder 1000
# Number of images present in both sets 809
# Number of IDs present in file but not in folder 7
# Number of IDs present in folder but not in file 191

# %%
all_ids_file = image_id_0_10_file+image_id_10_40_file+image_id_40_plus_file
all_ids_folder = image_id_0_10_folder+image_id_10_40_folder+image_id_40_plus_folder

# %%
print(f"Total image ids file {len(all_ids_file)}")
print(f"Total unique image ids file {len(set(all_ids_file))}")
print(f"Total images folder {len(all_ids_folder)}")
print(f"Total unique images folder {len((all_ids_folder))}")

print(f"Number of images present in both sets {len(set(all_ids_file)&set(all_ids_folder))}")
print(f"Number of IDs present in file but not in folder {len(set(all_ids_file)-set(all_ids_folder))}")
print(f"Number of IDs present in folder but not in file {len(set(all_ids_folder)-set(all_ids_file))}")
# Out:
# Total image ids file 1921
# Total unique image ids file 1921
# Total images folder 2263
# Total unique images folder 2263
# Number of images present in both sets 1907
# Number of IDs present in file but not in folder 14
# Number of IDs present in folder but not in file 356

# %% [markdown]
# ---
# **NOTE**
#
# Looks like that these files are a map between image name (id) and source link.
#
# ---

# %% [markdown]
# ## Image enities labels

# %%
def get_links_and_entites(filename):
    df = pd.read_csv(filename, sep=',',names=["image_id","label_image"])
    return df['image_id'].tolist(),df['label_image'].tolist()

# %%
links,_ = get_links_and_entites("data/Insta_labeled_data/image_labels_0plus_to_10_.csv")
len(links)
# Out:
# 278

# %%
links,_ = get_links_and_entites("data/Insta_labeled_data/image_labels_10plus_to_40.csv")
len(links)
# Out:
# 1032

# %%
links,_ = get_links_and_entites("data/Insta_labeled_data/image_labels_40plus.csv")
len(links)
# Out:
# 953

# %% [markdown]
# ---
# **NOTE**
#
# * Entites label of each image.
# * Mapping is done using the links.
# * Answers of multiple annotators are given.
# ---

# %% [markdown]
# ## Labeled images

# %%
df = pd.read_csv('data/Insta_labeled_data/labeled_0plus_to_10__full.csv', encoding='latin-1')
len(df['img_url']),len(set(df['img_url']))
# Out:
# (1390, 278)

# %%
df = pd.read_csv('data/Insta_labeled_data/labeled_10plus_to_40_full.csv', encoding='latin-1')
len(df['img_url']),len(set(df['img_url']))
# Out:
# (5196, 1031)

# %%
df = pd.read_csv('data/Insta_labeled_data/labeled_40plus_full.csv', encoding='latin-1')
len(df['img_url']),len(set(df['img_url']))
# Out:
# /home/hitkul/anaconda3/envs/nii_project/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (4,216,217) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (6104, 935)

# %%
df.head()
# Out:
#     _unit_id         _created_at  _golden         _id _missed  \
# 0  649719574  1/17/2015 19:37:16    False  1531470430     NaN
# 1  649719574  1/17/2015 20:40:57    False  1531507988     NaN
# 2  649719574  1/17/2015 21:54:57    False  1531549350     NaN
# 3  649719574  1/18/2015 00:11:28    False  1531628330     NaN
# 4  649719574  1/18/2015 02:21:20    False  1531708189     NaN
#
#           _started_at  _tainted   _channel  _trust  _worker_id      ...        \
# 0  1/17/2015 19:33:34     False  clixsense  1.0000    26831570      ...
# 1  1/17/2015 20:33:40     False      elite  0.9800    30609759      ...
# 2  1/17/2015 21:53:10     False    prodege  0.9200     3696575      ...
# 3  1/18/2015 00:07:23     False     neodev  0.9200    29750518      ...
# 4  1/18/2015 02:16:41     False  clixsense  0.8889     7398771      ...
#
#    clmn97  clmn98  clmn99                                          cptn_time  \
# 0  empety  empety  empety  <font color="#0066CC">offthis_</font>   erase ...
# 1  empety  empety  empety  <font color="#0066CC">offthis_</font>   erase ...
# 2  empety  empety  empety  <font color="#0066CC">offthis_</font>   erase ...
# 3  empety  empety  empety  <font color="#0066CC">offthis_</font>   erase ...
# 4  empety  empety  empety  <font color="#0066CC">offthis_</font>   erase ...
#
#                                              img_url      likes  \
# 0  http://scontent-b.cdninstagram.com/hphotos-xap...  196 likes
# 1  http://scontent-b.cdninstagram.com/hphotos-xap...  196 likes
# 2  http://scontent-b.cdninstagram.com/hphotos-xap...  196 likes
# 3  http://scontent-b.cdninstagram.com/hphotos-xap...  196 likes
# 4  http://scontent-b.cdninstagram.com/hphotos-xap...  196 likes
#
#                            owner_cmnt                                owner_id  \
# 0  Media posted at 012-02-11 23:04:28  <font color="#0066CC">nailsfv</font>
# 1  Media posted at 012-02-11 23:04:28  <font color="#0066CC">nailsfv</font>
# 2  Media posted at 012-02-11 23:04:28  <font color="#0066CC">nailsfv</font>
# 3  Media posted at 012-02-11 23:04:28  <font color="#0066CC">nailsfv</font>
# 4  Media posted at 012-02-11 23:04:28  <font color="#0066CC">nailsfv</font>
#
#   question1_gold question2_gold
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
#
# [5 rows x 218 columns]

# %% [markdown]
# ---
# **NOTE**
# + *_unit_id* - unique id for each image
# + Each row is answer of one annotator
# + Other information about workers present
# + *question1* is Aggression or not Aggrestion
# + *question2* is Bullying or Not bullying
# + Comments on the image are also given
# + Image links used as a key
# + Looks like owner comment is the caption
# ---

# %% [markdown]
# ## Session Label

# %%
df_0_10 = pd.read_csv('data/Insta_labeled_data/sessions_0plus_to_10_metadata.csv', encoding='latin-1')
len(df_0_10['img_url']),len(set(df_0_10['img_url']))
# Out:
# (278, 278)

# %%
df_10_40 = pd.read_csv('data/Insta_labeled_data/sessions_10plus_to_40_metadata.csv', encoding='latin-1')
len(df_10_40['img_url']),len(set(df_10_40['img_url']))
# Out:
# (1018, 1017)

# %%
df_40 = pd.read_csv('data/Insta_labeled_data/sessions_40plus_metadata.csv', encoding='latin-1')
len(df_40['img_url']),len(set(df_40['img_url']))
# Out:
# (922, 921)

# %%
df_40.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  649719574    False   finalized                   5      1/18/15 2:21
# 1  649719575    False   finalized                   5      1/17/15 7:45
# 2  649719576    False   finalized                   5     1/17/15 17:15
# 3  649719577    False   finalized                   5      1/18/15 3:04
# 4  649719578    False   finalized                   5     1/17/15 12:10
#
#     question1  question1:confidence question2  question2:confidence  \
# 0  aggression                1.0000  bullying                1.0000
# 1  aggression                1.0000  bullying                0.6227
# 2  aggression                1.0000  bullying                1.0000
# 3  aggression                0.7876  bullying                0.5923
# 4  aggression                1.0000  bullying                1.0000
#
#                                                clmn1      ...       \
# 0  <font color="#0066CC">margretricee</font>   Ba...      ...
# 1  <font color="#0066CC">mightyzulu</font>   Damn...      ...
# 2  <font color="#0066CC">wayne_dizzle818</font>  ...      ...
# 3  <font color="#0066CC">samantha_nora</font>   S...      ...
# 4  <font color="#0066CC">itsmyrayeraye</font>   <...      ...
#
#                                              img_url       likes  \
# 0  http://scontent-b.cdninstagram.com/hphotos-xap...   196 likes
# 1  http://scontent-a.cdninstagram.com/hphotos-xpa...   570 likes
# 2  http://scontent-a.cdninstagram.com/hphotos-xfa...    44 likes
# 3  http://scontent-b.cdninstagram.com/hphotos-xpf...  1381 likes
# 4  http://scontent-b.cdninstagram.com/hphotos-xpf...  1936 likes
#
#                                           owner_cmnt  \
# 0                 Media posted at 012-02-11 23:04:28
# 1                                new bong mac got me
# 2   So I find out that I am missing some of my Fu...
# 3                                       Beautiful <3
# 4                                            Tragedy
#
#                                          owner_id shared media followed_by  \
# 0          <font color="#0066CC">nailsfv</font>            189       95224
# 1          <font color="#0066CC">treejtv</font>           1341       61385
# 2  <font color="#0066CC">danielrochatat2</font>            945       50710
# 3    <font color="#0066CC">chelseahouska</font>            711     1905124
# 4    <font color="#0066CC">andreaschoice</font>            443      532939
#
#   follows         id cyberaggression cyberbullying
# 0    6117  649719574               5             5
# 1     193  649719575               5             3
# 2    1071  649719576               5             5
# 3     272  649719577               4             3
# 4     427  649719578               5             5
#
# [5 rows x 215 columns]

# %% [markdown]
# ---
# **NOTE**
# + *_unit_id* is unique id for every image
# + *_trusted_judgments* = Number of trusted annotators
# + *question1* = Aggression or not
# + *question2* = Bullying or not
# + Metadata like shares, like and comments is also present
# + Cyberaggression and cyberbullying is the count of how many annotators called it that
# + *image_url* can be used for mapping
# ---

# %% [markdown]
# # Final Dataset

# %% [markdown]
# Concatinating all three frames

# %%
final_df = pd.concat([df_0_10,df_10_40,df_40], ignore_index=True,sort=True)

# %%
final_df.head()
# Out:
#    _golden _last_judgment_at  _trusted_judgments   _unit_id _unit_state  \
# 0    False      4/11/15 0:40                   5  702714440   finalized
# 1    False      4/11/15 0:37                   5  702714441   finalized
# 2    False      4/11/15 2:17                   5  702714442   finalized
# 3    False      4/11/15 2:09                   5  702714443   finalized
# 4    False     4/10/15 23:41                   5  702714444   finalized
#
#                                                clmn1  \
# 0  <font color="#0066CC">lynnseyerinalexandra</fo...
# 1  <font color="#0066CC">britterkritter</font>   ...
# 2  <font color="#0066CC">mariamagv</font>   where...
# 3  <font color="#0066CC">gladlychadly</font>   _...
# 4  <font color="#0066CC">fivefour</font>   <font ...
#
#                                               clmn10  \
# 0  <font color="#0066CC">niazki.lam</font>   larr...
# 1  <font color="#0066CC">kyleepickering</font>   ...
# 2  <font color="#0066CC">julianarosa67</font>   F...
# 3  <font color="#0066CC">crash_edisy</font>   <fo...
# 4  <font color="#0066CC">brohr285</font>   Still ...
#
#                                              clmn100  \
# 0                                             empety
# 1                                             empety
# 2  <font color="#0066CC">oopshiharry</font>   Can...
# 3                                             empety
# 4  <font color="#0066CC">buddhaplaysbass</font>  ...
#
#                                              clmn101  \
# 0                                             empety
# 1                                             empety
# 2  <font color="#0066CC">nuriaat</font>   <font c...
# 3                                             empety
# 4  <font color="#0066CC">tjbyerly</font>   <font ...
#
#                                              clmn102    ...     \
# 0                                             empety    ...
# 1                                             empety    ...
# 2  <font color="#0066CC">agusjalo</font>   This i...    ...
# 3                                             empety    ...
# 4  <font color="#0066CC">fivefour</font>   <font ...    ...
#
#                                              img_url             likes  \
# 0  https://scontent.cdninstagram.com/hphotos-xaf1...    4313\r\r likes
# 1  https://scontent.cdninstagram.com/hphotos-xap1...    2102\r\r likes
# 2  https://scontent.cdninstagram.com/hphotos-xap1...  108939\r\r likes
# 3  https://scontent.cdninstagram.com/hphotos-xaf1...    6441\r\r likes
# 4  https://scontent.cdninstagram.com/hphotos-xap1...    1153\r\r likes
#
#                                           owner_cmnt  \
# 0  gosh we love these five idiots so much __ for...
# 1  Anyone see the Pepsi halftime show commercial ...
# 2  Today I ate cr_pes and bought a drawing of ch...
# 3  New works in progress for an upcoming show at ...
# 4  Due to overwhelming response, we have went ahe...
#
#                                       owner_id   question1  \
# 0     <font color="#0066CC">maliksbby</font>       noneAgg
# 1  <font color="#0066CC">witneycarson</font>       noneAgg
# 2   <font color="#0066CC">namelessgem</font>       noneAgg
# 3          <font color="#0066CC">kaws</font>    aggression
# 4      <font color="#0066CC">fivefour</font>       noneAgg
#
#   question1:confidence question2 question2:confidence shared media     label
# 0               0.8124   noneBll               1.0000         1477    normal
# 1               1.0000   noneBll               1.0000          761    normal
# 2               0.8056   noneBll               0.8056          698    normal
# 3               0.5982  bullying               0.5982         1257  bullying
# 4               1.0000   noneBll               1.0000         2052    normal
#
# [5 rows x 216 columns]

# %% [markdown]
# Getting final label for each row

# %%
def get_final_label(row):
    if row['question1']=='noneAgg' and row['question2']=='noneBll':
        return 'normal'
    elif row['question1']=='aggression' and row['question2']=='noneBll':
        return 'aggression'
    else:
        return 'bullying'

# %%
final_df['label'] = final_df.apply (lambda row: get_final_label(row),axis=1)

# %%
final_df.head()
# Out:
#    _golden _last_judgment_at  _trusted_judgments   _unit_id _unit_state  \
# 0    False      4/11/15 0:40                   5  702714440   finalized
# 1    False      4/11/15 0:37                   5  702714441   finalized
# 2    False      4/11/15 2:17                   5  702714442   finalized
# 3    False      4/11/15 2:09                   5  702714443   finalized
# 4    False     4/10/15 23:41                   5  702714444   finalized
#
#                                                clmn1  \
# 0  <font color="#0066CC">lynnseyerinalexandra</fo...
# 1  <font color="#0066CC">britterkritter</font>   ...
# 2  <font color="#0066CC">mariamagv</font>   where...
# 3  <font color="#0066CC">gladlychadly</font>   _...
# 4  <font color="#0066CC">fivefour</font>   <font ...
#
#                                               clmn10  \
# 0  <font color="#0066CC">niazki.lam</font>   larr...
# 1  <font color="#0066CC">kyleepickering</font>   ...
# 2  <font color="#0066CC">julianarosa67</font>   F...
# 3  <font color="#0066CC">crash_edisy</font>   <fo...
# 4  <font color="#0066CC">brohr285</font>   Still ...
#
#                                              clmn100  \
# 0                                             empety
# 1                                             empety
# 2  <font color="#0066CC">oopshiharry</font>   Can...
# 3                                             empety
# 4  <font color="#0066CC">buddhaplaysbass</font>  ...
#
#                                              clmn101  \
# 0                                             empety
# 1                                             empety
# 2  <font color="#0066CC">nuriaat</font>   <font c...
# 3                                             empety
# 4  <font color="#0066CC">tjbyerly</font>   <font ...
#
#                                              clmn102    ...     \
# 0                                             empety    ...
# 1                                             empety    ...
# 2  <font color="#0066CC">agusjalo</font>   This i...    ...
# 3                                             empety    ...
# 4  <font color="#0066CC">fivefour</font>   <font ...    ...
#
#                                              img_url             likes  \
# 0  https://scontent.cdninstagram.com/hphotos-xaf1...    4313\r\r likes
# 1  https://scontent.cdninstagram.com/hphotos-xap1...    2102\r\r likes
# 2  https://scontent.cdninstagram.com/hphotos-xap1...  108939\r\r likes
# 3  https://scontent.cdninstagram.com/hphotos-xaf1...    6441\r\r likes
# 4  https://scontent.cdninstagram.com/hphotos-xap1...    1153\r\r likes
#
#                                           owner_cmnt  \
# 0  gosh we love these five idiots so much __ for...
# 1  Anyone see the Pepsi halftime show commercial ...
# 2  Today I ate cr_pes and bought a drawing of ch...
# 3  New works in progress for an upcoming show at ...
# 4  Due to overwhelming response, we have went ahe...
#
#                                       owner_id   question1  \
# 0     <font color="#0066CC">maliksbby</font>       noneAgg
# 1  <font color="#0066CC">witneycarson</font>       noneAgg
# 2   <font color="#0066CC">namelessgem</font>       noneAgg
# 3          <font color="#0066CC">kaws</font>    aggression
# 4      <font color="#0066CC">fivefour</font>       noneAgg
#
#   question1:confidence question2 question2:confidence shared media     label
# 0               0.8124   noneBll               1.0000         1477    normal
# 1               1.0000   noneBll               1.0000          761    normal
# 2               0.8056   noneBll               0.8056          698    normal
# 3               0.5982  bullying               0.5982         1257  bullying
# 4               1.0000   noneBll               1.0000         2052    normal
#
# [5 rows x 216 columns]

# %%
total_samples_in_dataset = len(final_df)
total_samples_in_dataset
# Out:
# 2218

# %% [markdown]
# Finding image name for each row using mapping links with ids

# %%
image_id_0_10,image_url_0_10 = get_imageid_link_lists('data/instagram_images/namesall_info_media_ids_to_collect_0plus_to_10.txt')
image_id_10_40,image_url_10_40 = get_imageid_link_lists('data/instagram_images/namesall_info_media_ids_to_collect_10plus_to_40.txt')
image_id_40,image_url_40 = get_imageid_link_lists('data/instagram_images/namesall_info_media_ids_to_collect_40plus.txt')

# %%
image_ids = image_id_0_10+image_id_10_40+image_id_40
image_urls = image_url_0_10+image_url_10_40+image_url_40

# %%
len(image_ids),len(image_urls)
# Out:
# (1921, 1921)

# %%
image_urls = [i.split('/')[-1] for i in image_urls]

# %%
link_id_mapping_dict = dict(zip(image_urls,image_ids))

# %%
def return_id_from_link(row):
    try:
        return link_id_mapping_dict[row['img_url'].split('/')[-1]]
    except:
        return None

# %%
final_df['image_names_url_mapping'] = final_df.apply (lambda row: return_id_from_link(row),axis=1)

# %%
ids_retrived_using_links = [i for i in final_df['image_names_url_mapping'].tolist() if i!=None]
len(ids_retrived_using_links)
# Out:
# 544

# %%
len(set(ids_retrived_using_links)&set(all_ids_folder))
# Out:
# 543

# %%
final_df.to_pickle('data/DATA_I_MADE/final_csv_with_url_mapping_results.pkl')

# %% [markdown]
# That did not work out as expected so resolving to jugad

# %% [markdown]
# # #Jugad

# %% [markdown]
# Finding all he media_ids_present in data dump..
#
# creating a id to dump file mapping of format
# ```JSON
# {
#  id:dumpfile
#  .
#  .
#
# }
# ```

# %%
def fetch_all_media_ids_in_user_info_file(filename):
    with open(filename,'r') as reader:
        lines = reader.readlines()
        
    index = [i+1 for i, j in enumerate(lines) if j == 'media ID:\n']
    ids = [lines[i].rstrip() for i in index]
    return ids

# %%
normal_users_filenames = listdir('data/Instagram_normal_users/')
normal_users_filenames.remove('README.txt')
common_users_filenames=listdir('data/Instagram_common_users/')
common_users_filenames.remove('uesrid_common_insta_collected.txt')

# %%
len(normal_users_filenames),len(common_users_filenames)
# Out:
# (36, 11)

# %%
all_ids_data_dump = {}

# %%
for file in tqdm(normal_users_filenames):
    for id_ in fetch_all_media_ids_in_user_info_file(f'data/Instagram_normal_users/{file}'):
        if id_ in all_ids_data_dump:
            all_ids_data_dump[id_].append(file)
        else:
            all_ids_data_dump[id_] = [file]
# Out:
# HBox(children=(IntProgress(value=0, max=36), HTML(value='')))

# %%
for file in tqdm(common_users_filenames):
    for id_ in fetch_all_media_ids_in_user_info_file(f'data/Instagram_common_users/{file}'):
        if id_ in all_ids_data_dump:
            all_ids_data_dump[id_].append(file)
        else:
            all_ids_data_dump[id_] = [file]
# Out:
# HBox(children=(IntProgress(value=0, max=11), HTML(value='')))

# %%
with open(f'data/DATA_I_MADE/datadump_id_to_filename_map.json','w') as fp:
            json.dump(all_ids_data_dump, fp,indent=4)

# %%
with open(f'data/DATA_I_MADE/datadump_id_to_filename_map.json','r') as fp:
           all_ids_data_dump=json.load(fp)

# %%
len(all_ids_data_dump.keys())
# Out:
# 5763354

# %%
len(all_ids_folder)
# Out:
# 2263

# %%
ids_present_in_data_dump = list(set(all_ids_data_dump.keys())&set(all_ids_folder))
len(ids_present_in_data_dump)
# Out:
# 1630

# %%
ids_not_present_in_data_dump = list(set(all_ids_folder)-set(ids_present_in_data_dump))
len(ids_not_present_in_data_dump)
# Out:
# 633

# %%
ids_not_in_dump_but_retrived_using_links = set(ids_not_present_in_data_dump)&set(ids_retrived_using_links)
len(ids_not_in_dump_but_retrived_using_links)
# Out:
# 227

# %% [markdown]
# ## Parsing user datadump

# %%
def read_user_datadump(filename):
    with open(filename,'r') as reader:
        lines = reader.readlines()
    return lines

# %%
def get_user_blocks(lines):
    user_blocks = []
    index_of_user_blocks=[i for i, j in enumerate(lines) if  "instagram user id:" in j] 
    number_of_blocks = len(index_of_user_blocks)
    for block_number, block_index in enumerate(index_of_user_blocks):
        if (block_number+1)==number_of_blocks:
            block_number-=1
        user_blocks.append(lines[block_index:index_of_user_blocks[block_number+1]])
    return user_blocks

# %%
def get_username_from_user_block(block):
    return block[0][block[0].index("user name:"):].split(':')[-1].strip()

# %%
def clean_comment_data_dump(comment):
    return ' '.join(comment.encode('ascii', 'ignore').strip( ' _'.encode('ascii')).decode("utf-8").split())

# %%
def get_media_id_and_comments_tuples(block):
    #Puling out all media blocks in user block
    index_media_blocks = [i for i, j in enumerate(block) if j == 'media ID:\n']
    number_of_media_blocks = len(index_media_blocks)
    media_blocks = []
    for block_number, block_index in enumerate(index_media_blocks):
        if (block_number+1)==number_of_media_blocks:
            block_number-=1
        media_blocks.append(block[block_index:index_media_blocks[block_number+1]])
    
    #making (comment,media_id) for each media block
    comment_id_tuples = []
    for m_block in media_blocks:
        if m_block!=[]:
            media_id_block = m_block[1].strip()
            comments_index = m_block.index('comments for this media:\n')
            like_index = m_block.index('likes for this media:\n')
            if like_index==comments_index+1:
                comment_id_tuples.append((None,media_id_block))     
            else:
                comment_lines_index = [i for i in range(comments_index+1,like_index) if "commentText:" in m_block[i]]
                for i in range(len(comment_lines_index)):
                    current_comment_index = comment_lines_index[i]
                    if i+1==len(comment_lines_index):
                        next_comment_index=like_index
                    else:
                        next_comment_index = comment_lines_index[i+1]
                    
                    comment_text = m_block[current_comment_index][m_block[current_comment_index].index('commentText:')+len('commentText:'):].strip()
                    
                    for i in range(current_comment_index+1,next_comment_index):
                        comment_text += m_block[i].strip() 
                    comment_text = clean_comment_data_dump(comment_text)    
                    comment_id_tuples.append((comment_text,media_id_block))                    
    return comment_id_tuples

# %%
all_files_to_parse = [f'data/Instagram_normal_users/{i}' for i in normal_users_filenames]+ [f'data/Instagram_common_users/{i}' for i in common_users_filenames]

# %% [markdown]
# Making Json from data dump..
#
# Format
# ``` JSON
# 'username':{
#
#     'comment1':media_id of tht comment
#     .
#     .
#     .
# }```

# %%
for file in tqdm(all_files_to_parse):
    username_comment_media_id_dict = dict()
    lines = read_user_datadump(file)
    user_blocks = [i for i in get_user_blocks(lines) if i!=[]]
    for user_block in user_blocks:
        username = get_username_from_user_block(user_block)
        media_id_comment_tuples = get_media_id_and_comments_tuples(user_block)
        temp_dict = dict(media_id_comment_tuples)
        if username in username_comment_media_id_dict.keys():
            username_comment_media_id_dict[username].update(temp_dict)
        else:
            username_comment_media_id_dict[username]=temp_dict
    dump_file_name = file.split('/')[-1].replace('.txt','')
    with open(f'data/DATA_I_MADE/username_indexed_datadump_jsons/{dump_file_name}.json','w') as fp:
        json.dump(username_comment_media_id_dict, fp,indent=4)
    count+=1
# Out:
# HBox(children=(IntProgress(value=0, max=47), HTML(value='')))

# %% [markdown]
# Making Json from data dump..
#
# Format
# ``` JSON
# {
# 'media_id':{
#     'username': username of media owner
#     'comments': [list of comments on that media]}
# .
# .
# .
# }```

# %%
for file in tqdm(all_files_to_parse):
    media_id_and_metadata_dict = dict()
    lines = read_user_datadump(file)
    user_blocks = [i for i in get_user_blocks(lines) if i!=[]]
    for user in user_blocks:
        username = get_username_from_user_block(user)
        media_id_tuples = get_media_id_and_comments_tuples(user)
        
        for comment_text, media_id in media_id_tuples:
            if media_id in media_id_and_metadata_dict.keys():
                media_id_and_metadata_dict[media_id]['comments'].append(comment_text)
            else:
                media_id_and_metadata_dict[media_id] = {'username':username,'comments':[comment_text]}
    dump_file_name = file.split('/')[-1].replace('.txt','')
    with open(f'data/DATA_I_MADE/media_id_indexed_datadump_jsons/{dump_file_name}.json','w') as fp:
        json.dump(media_id_and_metadata_dict, fp,indent=4)
    count+=1
# Out:
# HBox(children=(IntProgress(value=0, max=47), HTML(value='')))

# %% [markdown]
# creating username to datadump json filename mapping

# %%
filenames = listdir('data/DATA_I_MADE/username_indexed_datadump_jsons/')

# %%
username_file = dict()

# %%
for i in tqdm(filenames):
    with open(f'data/DATA_I_MADE/username_indexed_datadump_jsons/{i}','r') as reader:
        file_dict = json.load(reader)
    for user in file_dict.keys():
        if user in username_file.keys():
            username_file[user].append(i)
        else:
            username_file[user] = [i]
# Out:
# HBox(children=(IntProgress(value=0, max=47), HTML(value='')))

# %%
with open(f'data/DATA_I_MADE/username_to_file_mapping.json','w') as fp:
            json.dump(username_file, fp,indent=4)

# %% [markdown]
# creating media id to datadump json filename mapping

# %%
filenames = listdir('data/DATA_I_MADE/media_id_indexed_datadump_jsons/')

# %%
media_id_filename_mapping = dict()

# %%
for i in tqdm(filenames):
    with open(f'data/DATA_I_MADE/media_id_indexed_datadump_jsons/{i}','r') as reader:
        file_dict = json.load(reader)
    for media_id in file_dict.keys():
        if media_id in media_id_filename_mapping.keys():
            media_id_filename_mapping[media_id].append(i)
        else:
            media_id_filename_mapping[media_id] = [i]
# Out:
# HBox(children=(IntProgress(value=0, max=47), HTML(value='')))

# %%
with open(f'data/DATA_I_MADE/media_id_filename_mapping.json','w') as fp:
            json.dump(media_id_filename_mapping, fp,indent=4)

# %% [markdown]
# # Finding image for each sample

# %% [markdown]
# Helper functions

# %%
def clean_comment(comment):
    try:
        return comment[comment.index('</font>')+len('</font>'):comment.index('(created_at:')].replace('<font color="#0066CC">','').replace('</font>','').encode('ascii', 'ignore').strip( ' _'.encode('ascii')).decode("utf-8")
    except:
        return comment[comment.index('</font>')+len('</font>'):comment.index('(created at:')].replace('<font color="#0066CC">','').replace('</font>','').encode('ascii', 'ignore').strip( ' _'.encode('ascii')).decode("utf-8")

# %% [markdown]
# ## method 1

# %% [markdown]
# For each row:
#     1. Extract comments present in row -> Clean comment
#     2. Extract username of owner
#     3. Extract files in which that user block is present
#     4. Extract extract user block
#     5. Find out ids by matching comments extracted in point 1

# %%
with open('data/DATA_I_MADE/username_to_file_mapping.json','r') as reader:
    username_file_map = json.load(reader)

# %%
final_df
# Out:
#       _golden _last_judgment_at  _trusted_judgments   _unit_id _unit_state  \
# 0       False      4/11/15 0:40                   5  702714440   finalized
# 1       False      4/11/15 0:37                   5  702714441   finalized
# 2       False      4/11/15 2:17                   5  702714442   finalized
# 3       False      4/11/15 2:09                   5  702714443   finalized
# 4       False     4/10/15 23:41                   5  702714444   finalized
# 5       False     4/10/15 23:44                   5  702714445   finalized
# 6       False      4/11/15 0:40                   5  702714446   finalized
# 7       False      4/11/15 0:37                   5  702714447   finalized
# 8       False     4/10/15 23:48                   5  702714448   finalized
# 9       False     4/10/15 23:47                   5  702714449   finalized
# 10      False      4/11/15 0:42                   5  702714450   finalized
# 11      False      4/11/15 2:10                   5  702714451   finalized
# 12      False     4/10/15 23:48                   5  702714452   finalized
# 13      False      4/11/15 2:09                   5  702714453   finalized
# 14      False      4/11/15 2:11                   5  702714454   finalized
# 15      False     4/10/15 23:45                   5  702714455   finalized
# 16      False     4/10/15 23:44                   5  702714456   finalized
# 17      False     4/10/15 23:41                   5  702714457   finalized
# 18      False      4/11/15 2:14                   5  702714458   finalized
# 19      False      4/11/15 2:10                   5  702714459   finalized
# 20      False      4/11/15 2:08                   5  702714460   finalized
# 21      False      4/11/15 2:07                   5  702714461   finalized
# 22      False     4/10/15 23:48                   5  702714462   finalized
# 23      False     4/10/15 23:44                   5  702714463   finalized
# 24      False      4/11/15 2:14                   5  702714464   finalized
# 25      False      4/11/15 2:17                   5  702714465   finalized
# 26      False     4/10/15 23:34                   5  702714466   finalized
# 27      False     4/10/15 23:35                   5  702714467   finalized
# 28      False     4/10/15 23:37                   5  702714468   finalized
# 29      False      4/11/15 0:42                   5  702714469   finalized
# ...       ...               ...                 ...        ...         ...
# 2188    False     1/22/15 20:50                   5  652910847   finalized
# 2189    False     1/20/15 16:33                   5  652910848   finalized
# 2190    False      1/24/15 4:20                   5  652910849   finalized
# 2191    False      1/22/15 0:49                   5  652910850   finalized
# 2192    False      1/21/15 6:16                   5  652910851   finalized
# 2193    False     1/23/15 11:39                   5  652910852   finalized
# 2194    False     1/23/15 11:47                   5  652910853   finalized
# 2195    False     1/27/15 14:30                   5  652910854   finalized
# 2196    False     1/22/15 21:19                   5  652910855   finalized
# 2197    False      1/26/15 0:03                   5  652910856   finalized
# 2198    False     1/20/15 17:43                   5  652910857   finalized
# 2199    False     1/24/15 18:21                   5  652910858   finalized
# 2200    False     1/23/15 11:50                   5  652910859   finalized
# 2201    False      1/22/15 1:59                   5  652910860   finalized
# 2202    False      1/26/15 0:08                   5  652910861   finalized
# 2203    False     1/27/15 14:21                   5  652910862   finalized
# 2204    False     1/20/15 12:48                   5  652910863   finalized
# 2205    False     1/21/15 17:24                   5  652910864   finalized
# 2206    False     1/23/15 11:44                   5  652910865   finalized
# 2207    False      1/27/15 2:47                   5  652910866   finalized
# 2208    False      1/22/15 0:50                   5  652910867   finalized
# 2209    False     1/21/15 20:58                   5  652910868   finalized
# 2210    False      1/26/15 0:06                   5  652910869   finalized
# 2211    False      1/22/15 0:49                   5  652910870   finalized
# 2212    False      1/25/15 2:27                   5  652910871   finalized
# 2213    False      1/20/15 8:27                   5  652910872   finalized
# 2214    False     1/24/15 17:35                   5  652910873   finalized
# 2215    False     1/21/15 17:33                   5  652910874   finalized
# 2216    False      1/25/15 2:40                   5  652910875   finalized
# 2217    False      1/21/15 0:40                   5  652910876   finalized
#
#                                                   clmn1  \
# 0     <font color="#0066CC">lynnseyerinalexandra</fo...
# 1     <font color="#0066CC">britterkritter</font>   ...
# 2     <font color="#0066CC">mariamagv</font>   where...
# 3     <font color="#0066CC">gladlychadly</font>   _...
# 4     <font color="#0066CC">fivefour</font>   <font ...
# 5     <font color="#0066CC">juliepailler</font>   _...
# 6     <font color="#0066CC">karisma_p</font>   <font...
# 7     <font color="#0066CC">samheartsu</font>   yay ...
# 8     <font color="#0066CC">_loloarcanjo_</font>   _...
# 9     <font color="#0066CC">harrycan_u_not</font>   ...
# 10    <font color="#0066CC">leixxak</font>   <font c...
# 11    <font color="#0066CC">eduarte1988</font>   1st...
# 12    <font color="#0066CC">trentleft</font>   <font...
# 13    <font color="#0066CC">cherrylnotman</font>   S...
# 14    <font color="#0066CC">jocelyn8642</font>   1st...
# 15    <font color="#0066CC">jamie_plowman</font>   S...
# 16    <font color="#0066CC">jovanna_maresca</font>  ...
# 17    <font color="#0066CC">mobelaisima</font>   Car...
# 18    <font color="#0066CC">bethsbunny</font>   BOOT...
# 19    <font color="#0066CC">urgrll</font>   GO SKY G...
# 20    <font color="#0066CC">mrs.kite</font>   <font ...
# 21    <font color="#0066CC">fabrizio_47</font>   Lol...
# 22    <font color="#0066CC">odahia</font>   You look...
# 23    <font color="#0066CC">emma.presnell</font>   H...
# 24    <font color="#0066CC">hi_my_name_is_jim</font>...
# 25    <font color="#0066CC">kishanjop</font>   I hav...
# 26    <font color="#0066CC">janesfashion19</font>   ...
# 27    <font color="#0066CC">tulip.sniper</font>   <f...
# 28    <font color="#0066CC">throwin_touchdowns_15</f...
# 29    <font color="#0066CC">allygirl0517</font>   Ob...
# ...                                                 ...
# 2188  <font color="#0066CC">texas_trill956</font>   ...
# 2189  <font color="#0066CC">moonwalkingrabbit</font>...
# 2190  <font color="#0066CC">tazawarya</font>   So yo...
# 2191  <font color="#0066CC">connorf1nn</font>   prob...
# 2192  <font color="#0066CC">charlotte_aaaa</font>   ...
# 2193  <font color="#0066CC">sarahgubbels_</font>   H...
# 2194  <font color="#0066CC">rose.kesha</font>   Edit...
# 2195  <font color="#0066CC">fuckhatred</font>   eeye...
# 2196  <font color="#0066CC">__aidanc__</font>   I ha...
# 2197  <font color="#0066CC">dat723</font>   I think ...
# 2198  <font color="#0066CC">yxngsnxxl</font>   Fuck ...
# 2199  <font color="#0066CC">jasdrift</font>   <font ...
# 2200  <font color="#0066CC">imaginesforharrygirls</f...
# 2201  <font color="#0066CC">lilbshadeymob88</font>  ...
# 2202  <font color="#0066CC">the_queen_of_all_selfies...
# 2203  <font color="#0066CC">wallywojo</font>   Justi...
# 2204  <font color="#0066CC">kelmichelle87</font>   H...
# 2205  <font color="#0066CC">medusssssssa</font>   <f...
# 2206  <font color="#0066CC">thackerdotcom</font>   Y...
# 2207  <font color="#0066CC">ellerosa</font>   :) <fo...
# 2208  <font color="#0066CC">enlighten_the_spirit</fo...
# 2209  <font color="#0066CC">reichert13</font>   MUG ...
# 2210  <font color="#0066CC">therealestb_80s</font>  ...
# 2211  <font color="#0066CC">clutchdigital</font>   1...
# 2212  <font color="#0066CC">kingsagundez29</font>   ...
# 2213  <font color="#0066CC">stateofkali</font>   you...
# 2214  <font color="#0066CC">_poquitobonita</font>   ...
# 2215  <font color="#0066CC">bodhi_sutra</font>   You...
# 2216  <font color="#0066CC">https.imvu</font>   I do...
# 2217  <font color="#0066CC">chanchi_16</font>   Haha...
#
#                                                  clmn10  \
# 0     <font color="#0066CC">niazki.lam</font>   larr...
# 1     <font color="#0066CC">kyleepickering</font>   ...
# 2     <font color="#0066CC">julianarosa67</font>   F...
# 3     <font color="#0066CC">crash_edisy</font>   <fo...
# 4     <font color="#0066CC">brohr285</font>   Still ...
# 5     <font color="#0066CC">shaunmichaelchapman</fon...
# 6     <font color="#0066CC">valex_33</font>   <font ...
# 7     <font color="#0066CC">tatum.sparks</font>   <f...
# 8     <font color="#0066CC">fcbayern_isibella</font>...
# 9     <font color="#0066CC">kingstyless</font>   <fo...
# 10    <font color="#0066CC">codizzle8</font>   Yo <f...
# 11    <font color="#0066CC">street_fly76</font>   Li...
# 12    <font color="#0066CC">chevy.b</font>   _Û_Û...
# 13    <font color="#0066CC">moabengtsson_</font>   G...
# 14    <font color="#0066CC">ikasalindo</font>   Pink...
# 15    <font color="#0066CC">rchiminoo</font>   ¥ÈÑ  ...
# 16    <font color="#0066CC">jlzrus</font>   Haha, th...
# 17    <font color="#0066CC">jojotanktop</font>   Who...
# 18    <font color="#0066CC">biscuit_slut</font>   Sw...
# 19    <font color="#0066CC">ponysauriohacerawr</font...
# 20    <font color="#0066CC">kerimae2</font>   <font ...
# 21    <font color="#0066CC">hockeyplyr39</font>   <f...
# 22    <font color="#0066CC">taylorstrupp</font>   ga...
# 23    <font color="#0066CC">j.ames</font>   stfu <fo...
# 24    <font color="#0066CC">juicydoo</font>   Hahaha...
# 25    <font color="#0066CC">grandyglaze1</font>   <f...
# 26    <font color="#0066CC">daycruvinel</font>   Bea...
# 27    <font color="#0066CC">alyssashakur</font>   yo...
# 28    <font color="#0066CC">jordanrisa</font>   __...
# 29    <font color="#0066CC">kori.91</font>   <font c...
# ...                                                 ...
# 2188  <font color="#0066CC">gnarfro</font>   <font c...
# 2189  <font color="#0066CC">prettyboii_creole</font>...
# 2190  <font color="#0066CC">hebrew_king21</font>   O...
# 2191  <font color="#0066CC">creepymasterlurker</font...
# 2192  <font color="#0066CC">meandmy_fandoms</font>  ...
# 2193  <font color="#0066CC">ameliajclark</font>   HE...
# 2194  <font color="#0066CC">loveinto_thelight</font>...
# 2195  <font color="#0066CC">neenoali</font>   I just...
# 2196  <font color="#0066CC">simon_5418</font>   Had ...
# 2197  <font color="#0066CC">siscoflores</font>   Tha...
# 2198  <font color="#0066CC">rodrigo_the_creator</fon...
# 2199  <font color="#0066CC">msindell</font>   <font ...
# 2200  <font color="#0066CC">mallory.lmao</font>   Ma...
# 2201  <font color="#0066CC">12hunnidblock</font>   F...
# 2202  <font color="#0066CC">fuenciado_._</font>   Cr...
# 2203  <font color="#0066CC">_leonalitii</font>   Eli...
# 2204  <font color="#0066CC">erinlorraine</font>   <f...
# 2205  <font color="#0066CC">proffessor_horse</font> ...
# 2206  <font color="#0066CC">mattington21</font>   Su...
# 2207  <font color="#0066CC">madilynsophia</font>   <...
# 2208  <font color="#0066CC">enlighten_the_spirit</fo...
# 2209  <font color="#0066CC">mandog423</font>   He be...
# 2210  <font color="#0066CC">melobee_</font>   Who ca...
# 2211  <font color="#0066CC">mike5832</font>   That n...
# 2212  <font color="#0066CC">leephil447</font>   Beau...
# 2213  <font color="#0066CC">timtrew</font>   Stick t...
# 2214  <font color="#0066CC">demondresavagepullen</fo...
# 2215  <font color="#0066CC">hebrew_king21</font>   O...
# 2216  <font color="#0066CC">katie_graf</font>   And ...
# 2217  <font color="#0066CC">chanchi_16</font>   Fatn...
#
#                                                 clmn100  \
# 0                                                empety
# 1                                                empety
# 2     <font color="#0066CC">oopshiharry</font>   Can...
# 3                                                empety
# 4     <font color="#0066CC">buddhaplaysbass</font>  ...
# 5                                                empety
# 6     <font color="#0066CC">sndraibnz</font>   wtf_...
# 7                                                empety
# 8     <font color="#0066CC">l0lelena</font>   Ahhaha...
# 9                                                empety
# 10    <font color="#0066CC">dozi_r</font>   <font co...
# 11                                               empety
# 12    <font color="#0066CC">marriiaaa__</font>   I k...
# 13                                               empety
# 14    <font color="#0066CC">liljswim</font>   Love t...
# 15    <font color="#0066CC">chozzy.wozzy</font>   _...
# 16    <font color="#0066CC">jadea513</font>   Loved ...
# 17                                               empety
# 18    <font color="#0066CC">cottcncandyheart</font> ...
# 19                                               empety
# 20    <font color="#0066CC">jenniebug</font>   <font...
# 21                                               empety
# 22                                               empety
# 23                                               empety
# 24    <font color="#0066CC">curly_q_kiana</font>   W...
# 25                                               empety
# 26    <font color="#0066CC">carod31888</font>   <fon...
# 27                                               empety
# 28                                               empety
# 29    <font color="#0066CC">maximus_gardette85</font...
# ...                                                 ...
# 2188                                             empety
# 2189                                             empety
# 2190                                             empety
# 2191                                             empety
# 2192  <font color="#0066CC">damaskgrinnell</font>   ...
# 2193                                             empety
# 2194                                             empety
# 2195  <font color="#0066CC">tru_scorpio_king</font> ...
# 2196  <font color="#0066CC">wild_hogs_5</font>   I w...
# 2197                                             empety
# 2198  <font color="#0066CC">mauricioxsoto</font>   F...
# 2199                                             empety
# 2200  <font color="#0066CC">sarah_clubb</font>   <fo...
# 2201  <font color="#0066CC">selfmade_cardi</font>   ...
# 2202                                             empety
# 2203  <font color="#0066CC">tydale_yrn</font>   Elit...
# 2204                                             empety
# 2205                                             empety
# 2206                                             empety
# 2207  <font color="#0066CC">misskriss62</font>   <fo...
# 2208                                             empety
# 2209                                             empety
# 2210  <font color="#0066CC">mrcbd</font>   _____...
# 2211                                             empety
# 2212                                             empety
# 2213                                             empety
# 2214                                             empety
# 2215                                             empety
# 2216  <font color="#0066CC">_1989hox</font>   I just...
# 2217  <font color="#0066CC">eman_m10</font>   ....yo...
#
#                                                 clmn101  \
# 0                                                empety
# 1                                                empety
# 2     <font color="#0066CC">nuriaat</font>   <font c...
# 3                                                empety
# 4     <font color="#0066CC">tjbyerly</font>   <font ...
# 5                                                empety
# 6     <font color="#0066CC">ileanakock</font>   Gwn ...
# 7                                                empety
# 8     <font color="#0066CC">mueller_mira</font>   Ha...
# 9                                                empety
# 10    <font color="#0066CC">jakecardinalee</font>   ...
# 11                                               empety
# 12    <font color="#0066CC">emmaaacaniff</font>   <f...
# 13                                               empety
# 14    <font color="#0066CC">dwpyy</font>   this is m...
# 15    <font color="#0066CC">erzzamaloku</font>   How...
# 16    <font color="#0066CC">kellikole</font>   Love ...
# 17                                               empety
# 18    <font color="#0066CC">hes_clueing_for_looks</f...
# 19                                               empety
# 20    <font color="#0066CC">anat_blitz</font>   <fon...
# 21                                               empety
# 22                                               empety
# 23                                               empety
# 24    <font color="#0066CC">huda_187</font>   U foun...
# 25                                               empety
# 26    <font color="#0066CC">mehlene</font>   And thi...
# 27                                               empety
# 28                                               empety
# 29    <font color="#0066CC">rowank01</font>   ROMNEY...
# ...                                                 ...
# 2188                                             empety
# 2189                                             empety
# 2190                                             empety
# 2191                                             empety
# 2192  <font color="#0066CC">sadieileen</font>   <fon...
# 2193                                             empety
# 2194                                             empety
# 2195  <font color="#0066CC">jake.day</font>   <font ...
# 2196  <font color="#0066CC">r_mack10</font>   I had ...
# 2197                                             empety
# 2198  <font color="#0066CC">the_real_anthony100</fon...
# 2199                                             empety
# 2200  <font color="#0066CC">wendyfiliti</font>   <fo...
# 2201  <font color="#0066CC">bigningez</font>   Smack...
# 2202                                             empety
# 2203  <font color="#0066CC">carsonb1230</font>   Ran...
# 2204                                             empety
# 2205                                             empety
# 2206                                             empety
# 2207  <font color="#0066CC">rukiyeakm</font>   this ...
# 2208                                             empety
# 2209                                             empety
# 2210  <font color="#0066CC">dritowel</font>   Keep d...
# 2211                                             empety
# 2212                                             empety
# 2213                                             empety
# 2214                                             empety
# 2215                                             empety
# 2216  <font color="#0066CC">_1989hox</font>   And ge...
# 2217  <font color="#0066CC">eyee_van</font>   <font ...
#
#                                                 clmn102  \
# 0                                                empety
# 1                                                empety
# 2     <font color="#0066CC">agusjalo</font>   This i...
# 3                                                empety
# 4     <font color="#0066CC">fivefour</font>   <font ...
# 5                                                empety
# 6     <font color="#0066CC">olivias_01</font>   <fon...
# 7                                                empety
# 8     <font color="#0066CC">casu259</font>   Hi  (cr...
# 9                                                empety
# 10    <font color="#0066CC">rasyaadikoro</font>   Hh...
# 11                                               empety
# 12    <font color="#0066CC">breanna_marie_1</font>  ...
# 13                                               empety
# 14    <font color="#0066CC">lucianacunha82</font>   ...
# 15    <font color="#0066CC">bleonebrestovci</font>  ...
# 16    <font color="#0066CC">lovemyboys40</font>   Lo...
# 17                                               empety
# 18    <font color="#0066CC">confessionsbyyou</font> ...
# 19                                               empety
# 20    <font color="#0066CC">thelibertinee</font>   O...
# 21                                               empety
# 22                                               empety
# 23                                               empety
# 24    <font color="#0066CC">owen002</font>   BURN  (...
# 25                                               empety
# 26    <font color="#0066CC">ayyyzma</font>   Love lo...
# 27                                               empety
# 28                                               empety
# 29    <font color="#0066CC">_nicolala</font>   Obama...
# ...                                                 ...
# 2188                                             empety
# 2189                                             empety
# 2190                                             empety
# 2191                                             empety
# 2192  <font color="#0066CC">sleepy.little.kitty</fon...
# 2193                                             empety
# 2194                                             empety
# 2195  <font color="#0066CC">zaylo704</font>   Jon co...
# 2196  <font color="#0066CC">luckygoal4</font>   I ha...
# 2197                                             empety
# 2198  <font color="#0066CC">the_real_anthony100</fon...
# 2199                                             empety
# 2200  <font color="#0066CC">giorgiacaruana</font>   ...
# 2201  <font color="#0066CC">anazfinest</font>   All ...
# 2202                                             empety
# 2203  <font color="#0066CC">aidan_northup17</font>  ...
# 2204                                             empety
# 2205                                             empety
# 2206                                             empety
# 2207  <font color="#0066CC">nasser__alothman</font> ...
# 2208                                             empety
# 2209                                             empety
# 2210  <font color="#0066CC">donchristo310</font>   T...
# 2211                                             empety
# 2212                                             empety
# 2213                                             empety
# 2214                                             empety
# 2215                                             empety
# 2216  <font color="#0066CC">_1989hox</font>   These ...
# 2217  <font color="#0066CC">bryanvega_</font>   <fon...
#
#                   ...                           likes  \
# 0                 ...                  4313\r\r likes
# 1                 ...                  2102\r\r likes
# 2                 ...                108939\r\r likes
# 3                 ...                  6441\r\r likes
# 4                 ...                  1153\r\r likes
# 5                 ...                  4381\r\r likes
# 6                 ...                  8199\r\r likes
# 7                 ...                  3366\r\r likes
# 8                 ...                 86443\r\r likes
# 9                 ...                    61\r\r likes
# 10                ...                 46290\r\r likes
# 11                ...                   964\r\r likes
# 12                ...                197284\r\r likes
# 13                ...                  2236\r\r likes
# 14                ...                  3195\r\r likes
# 15                ...                 14528\r\r likes
# 16                ...                 28972\r\r likes
# 17                ...                  1244\r\r likes
# 18                ...                 10524\r\r likes
# 19                ...                  7866\r\r likes
# 20                ...                  8916\r\r likes
# 21                ...                   529\r\r likes
# 22                ...                    85\r\r likes
# 23                ...                  6868\r\r likes
# 24                ...                 23406\r\r likes
# 25                ...                  1140\r\r likes
# 26                ...                 15713\r\r likes
# 27                ...                   807\r\r likes
# 28                ...                  2135\r\r likes
# 29                ...                  8362\r\r likes
# ...               ...                             ...
# 2188              ...                       630 likes
# 2189              ...                        40 likes
# 2190              ...                        34 likes
# 2191              ...                       503 likes
# 2192              ...                      1816 likes
# 2193              ...                       695 likes
# 2194              ...                       147 likes
# 2195              ...                      7331 likes
# 2196              ...                       486 likes
# 2197              ...                       127 likes
# 2198              ...                     22892 likes
# 2199              ...                      4425 likes
# 2200              ...                      4245 likes
# 2201              ...                      2751 likes
# 2202              ...                       101 likes
# 2203              ...                       697 likes
# 2204              ...                       312 likes
# 2205              ...                       510 likes
# 2206              ...                      1258 likes
# 2207              ...                      7520 likes
# 2208              ...                       232 likes
# 2209              ...                      3075 likes
# 2210              ...                      2314 likes
# 2211              ...                      2757 likes
# 2212              ...                       294 likes
# 2213              ...                       442 likes
# 2214              ...                       196 likes
# 2215              ...                        50 likes
# 2216              ...                       454 likes
# 2217              ...                     37734 likes
#
#                                              owner_cmnt  \
# 0     gosh we love these five idiots so much __ for...
# 1     Anyone see the Pepsi halftime show commercial ...
# 2     Today I ate cr_pes and bought a drawing of ch...
# 3     New works in progress for an upcoming show at ...
# 4     Due to overwhelming response, we have went ahe...
# 5                      Loving the leather-denim combo."
# 6                                  OMFG I'M DYING _Û_"
# 7                      Yay or nay? tag your friends_ä
# 8      Afternoon in Campo Bahia with the team _Û__"
# 9     i leave you with one of my favorite harry vide...
# 10      Wishing you a happy birthday, dear @erickoston.
# 11                                     Brick by brick."
# 12                  Ridin' dirty with @hayes_instagram"
# 13                                                __"
# 14                         Pink stripes or pink shoes?"
# 15    New snapback from @larepublicclothing _´ Lov...
# 16    Charlie looking very pleased with his "#MerylS...
# 17    Doing kissy face with my baby @drodd36 #BodyEn...
# 18                                 when doge sees cate"
# 19     Cole & I up at 6 am. JK. He's still asleep __"
# 20                                                _±"
# 21                         Completely normal kids demo"
# 22    Emily missed this picture ): but with the love...
# 23                                      #doge4president
# 24                 Buuurn_î!!! @NailsCamera _Ñ___"
# 25    #repost big S/O to the awesome @Vladogirl , th...
# 26                    'Ciao Milano' by Hayden Williams"
# 27    Tune into @mtv Tuesday Jan 7th - 10pm EST, to ...
# 28    Dinner last night at @Herringbonemondrian w/ m...
# 29    Today is Election Day! #WeWill #GoVote @rockth...
# ...                                                 ...
# 2188   S/O and thank you to my boy <font color="#006...
# 2189   Maan this guy is messed up f*ckin racist bitc...
# 2190   A Third World War,the perfect set up to bring...
# 2191                                     true or false?
# 2192   Tell me what pisses you off and rant about it...
# 2193                                          HELL YEAH
# 2194   What's your favorite music video from the War...
# 2195   DAAAAAMN! <font color="#0066CC">@jarrenbenton...
# 2196                                        Go! Comment
# 2197   Fuck what y'all niggas talking bout we really...
# 2198               X games. Everybody say Fuck Anthony.
# 2199   Our dude <font color="#0066CC">@bjenner</font...
# 2200   YOU CAN NEVER TAKE HARRY SERIOUSLY WHEN HE SA...
# 2201   They asked where the mustard bottle was my so...
# 2202                    Sorry but I just had to do this
# 2203   It's time for <font color="#0066CC">#WhatFigu...
# 2204                                          Fan mail.
# 2205   The Collar-Bomb Murder of Ana Elvia in Colomb...
# 2206                     New music video up, LINK in bi
# 2207   No matter what you believe in, hunting/no hun...
# 2208   Is the root of the problem the gun? Or the fi...
# 2209   Eric Fisher gets ready for his headshot | <fo...
# 2210                                     Shit cray !!!!
# 2211   Camp life.. <font color="#0066CC">#MikeVickWe...
# 2212   Signed over 300 pics at today's signing ! Fou...
# 2213   Skills! <font color="#0066CC">#sundayfunday</...
# 2214   Lol <font color="#0066CC">#tupacamarushakur#t...
# 2215   Who cares right? There both just books? ___...
# 2216                 Media posted at 014-06-21 20:57:44
# 2217   Next Stop: Knockout Round! <font color="#0066...
#
#                                                owner_id   question1  \
# 0              <font color="#0066CC">maliksbby</font>       noneAgg
# 1           <font color="#0066CC">witneycarson</font>       noneAgg
# 2            <font color="#0066CC">namelessgem</font>       noneAgg
# 3                   <font color="#0066CC">kaws</font>    aggression
# 4               <font color="#0066CC">fivefour</font>       noneAgg
# 5         <font color="#0066CC">adidasneolabel</font>       noneAgg
# 6               <font color="#0066CC">sextpert</font>       noneAgg
# 7          <font color="#0066CC">avanityaffair</font>       noneAgg
# 8             <font color="#0066CC">gotzemario</font>       noneAgg
# 9            <font color="#0066CC">kingstyless</font>       noneAgg
# 10                <font color="#0066CC">nikesb</font>       noneAgg
# 11         <font color="#0066CC">dennistodisco</font>       noneAgg
# 12          <font color="#0066CC">jackgilinsky</font>       noneAgg
# 13               <font color="#0066CC">loekenz</font>       noneAgg
# 14        <font color="#0066CC">adidasneolabel</font>       noneAgg
# 15        <font color="#0066CC">itsjonasfossum</font>       noneAgg
# 16           <font color="#0066CC">meryledavis</font>       noneAgg
# 17         <font color="#0066CC">carlafacciolo</font>       noneAgg
# 18             <font color="#0066CC">doge.post</font>       noneAgg
# 19           <font color="#0066CC">skyferreira</font>       noneAgg
# 20          <font color="#0066CC">insta_kitten</font>       noneAgg
# 21     <font color="#0066CC">jordanroriepayton</font>       noneAgg
# 22         <font color="#0066CC">hayleyamelia_</font>       noneAgg
# 23             <font color="#0066CC">doge.post</font>       noneAgg
# 24            <font color="#0066CC">bestttextt</font>       noneAgg
# 25         <font color="#0066CC">vladofootwear</font>       noneAgg
# 26       <font color="#0066CC">hayden_williams</font>       noneAgg
# 27           <font color="#0066CC">missfamenyc</font>       noneAgg
# 28               <font color="#0066CC">klarity</font>       noneAgg
# 29        <font color="#0066CC">bridgitmendler</font>    aggression
# ...                                                 ...         ...
# 2188        <font color="#0066CC">paulwallbaby</font>    aggression
# 2189    <font color="#0066CC">makavellijackson</font>    aggression
# 2190          <font color="#0066CC">childofyah</font>       noneAgg
# 2191       <font color="#0066CC">nesserfamilia</font>       noneAgg
# 2192           <font color="#0066CC">jerkstiel</font>    aggression
# 2193     <font color="#0066CC">andthatismyfact</font>       noneAgg
# 2194          <font color="#0066CC">keshatoday</font>       noneAgg
# 2195           <font color="#0066CC">hopsinson</font>    aggression
# 2196    <font color="#0066CC">patriotsfootball</font>       noneAgg
# 2197          <font color="#0066CC">ice_marrow</font>    aggression
# 2198      <font color="#0066CC">larryfisherman</font>    aggression
# 2199        <font color="#0066CC">thehoonigans</font>    aggression
# 2200         <font color="#0066CC">haroldluvme</font>       noneAgg
# 2201           <font color="#0066CC">djmustard</font>    aggression
# 2202        <font color="#0066CC">andybvb_fanp</font>       noneAgg
# 2203           <font color="#0066CC">ringsidec</font>       noneAgg
# 2204          <font color="#0066CC">jeffdauler</font>    aggression
# 2205        <font color="#0066CC">notexplained</font>       noneAgg
# 2206           <font color="#0066CC">joeysalad</font>    aggression
# 2207       <font color="#0066CC">sophiamiacova</font>    aggression
# 2208  <font color="#0066CC">enlighten_the_spirit</fo...     noneAgg
# 2209            <font color="#0066CC">kcchiefs</font>    aggression
# 2210           <font color="#0066CC">djmustard</font>    aggression
# 2211            <font color="#0066CC">mikevick</font>    aggression
# 2212             <font color="#0066CC">rebysky</font>    aggression
# 2213          <font color="#0066CC">shawnsuggs</font>    aggression
# 2214  <font color="#0066CC">tupac_amaru_shakur1996</...     noneAgg
# 2215          <font color="#0066CC">childofyah</font>    aggression
# 2216             <font color="#0066CC">cutting</font>    aggression
# 2217        <font color="#0066CC">soccerdotcom</font>    aggression
#
#      question1:confidence question2 question2:confidence shared media  \
# 0                  0.8124   noneBll               1.0000         1477
# 1                  1.0000   noneBll               1.0000          761
# 2                  0.8056   noneBll               0.8056          698
# 3                  0.5982  bullying               0.5982         1257
# 4                  1.0000   noneBll               1.0000         2052
# 5                  1.0000   noneBll               1.0000         1520
# 6                  1.0000   noneBll               1.0000         2158
# 7                  0.5980   noneBll               1.0000         2616
# 8                  0.7965   noneBll               0.7965          507
# 9                  1.0000   noneBll               1.0000          377
# 10                 1.0000   noneBll               1.0000         1019
# 11                 0.8056   noneBll               0.8056          658
# 12                 0.7965   noneBll               1.0000          325
# 13                 0.6091   noneBll               0.6091         1451
# 14                 0.7926   noneBll               0.7926         1520
# 15                 1.0000   noneBll               1.0000          536
# 16                 1.0000   noneBll               1.0000          695
# 17                 0.7965   noneBll               1.0000         1208
# 18                 1.0000   noneBll               1.0000          277
# 19                 0.8035   noneBll               0.8035         2179
# 20                 0.7926   noneBll               0.7926          984
# 21                 0.5982   noneBll               0.5982         1087
# 22                 1.0000   noneBll               1.0000          239
# 23                 0.7965   noneBll               0.7965          277
# 24                 0.5982   noneBll               0.5982          627
# 25                 0.8035   noneBll               0.8035         1639
# 26                 1.0000   noneBll               1.0000         1567
# 27                 1.0000   noneBll               1.0000         1005
# 28                 0.8078   noneBll               1.0000          858
# 29                 0.7969  bullying               0.6093          765
# ...                   ...       ...                  ...          ...
# 2188               1.0000  bullying               0.6117         1884
# 2189               1.0000  bullying               1.0000          644
# 2190               1.0000   noneBll               1.0000         1905
# 2191               1.0000   noneBll               1.0000          640
# 2192               0.8051   noneBll               0.5888         2514
# 2193               0.8055   noneBll               0.8055          462
# 2194               1.0000   noneBll               1.0000          277
# 2195               0.6245  bullying               0.6245         1247
# 2196               1.0000   noneBll               1.0000         1147
# 2197               1.0000  bullying               1.0000         1187
# 2198               1.0000  bullying               0.8018         1556
# 2199               1.0000  bullying               0.8081         1959
# 2200               0.5995   noneBll               0.8022         1847
# 2201               1.0000  bullying               1.0000         1949
# 2202               1.0000   noneBll               1.0000         3351
# 2203               1.0000   noneBll               1.0000         1521
# 2204               0.7965   noneBll               0.6024         1676
# 2205               0.7997   noneBll               0.7997          498
# 2206               1.0000  bullying               1.0000          780
# 2207               1.0000  bullying               0.7995          407
# 2208               1.0000   noneBll               1.0000         2727
# 2209               0.7908  bullying               0.7908         1280
# 2210               1.0000  bullying               0.5886         1949
# 2211               0.7867  bullying               0.7867          323
# 2212               0.6017  bullying               0.6017         1266
# 2213               0.7879   noneBll               0.7963         1607
# 2214               1.0000   noneBll               1.0000         2204
# 2215               0.6090   noneBll               0.5868         1905
# 2216               0.5954   noneBll               0.5975          319
# 2217               1.0000  bullying               1.0000         2009
#
#            label        image_names_url_mapping
# 0         normal                           None
# 1         normal                           None
# 2         normal                           None
# 3       bullying                           None
# 4         normal                           None
# 5         normal                           None
# 6         normal                           None
# 7         normal                           None
# 8         normal                           None
# 9         normal                           None
# 10        normal                           None
# 11        normal                           None
# 12        normal                           None
# 13        normal                           None
# 14        normal                           None
# 15        normal                           None
# 16        normal                           None
# 17        normal                           None
# 18        normal                           None
# 19        normal                           None
# 20        normal                           None
# 21        normal                           None
# 22        normal                           None
# 23        normal                           None
# 24        normal                           None
# 25        normal                           None
# 26        normal                           None
# 27        normal                           None
# 28        normal                           None
# 29      bullying                           None
# ...          ...                            ...
# 2188    bullying    735537793712264421_17296540
# 2189    bullying   735555112724831441_270483046
# 2190      normal   735675530169475160_243598255
# 2191      normal     735712401639406803_2811086
# 2192  aggression   736046144866767539_391491299
# 2193      normal                           None
# 2194      normal                           None
# 2195    bullying   737102530862896608_215707036
# 2196      normal   737525783643346863_191104148
# 2197    bullying    738253376803007770_16326242
# 2198    bullying    738275438920576337_10514202
# 2199    bullying    738418075889277490_10176765
# 2200      normal   738601214135415558_293518499
# 2201    bullying                           None
# 2202      normal   740308670017689655_712250757
# 2203      normal   740564309307006754_325781254
# 2204  aggression      740574134516332082_983084
# 2205      normal                           None
# 2206    bullying   741378265404139922_278236785
# 2207    bullying    741399243826850211_14105697
# 2208      normal     741439969975495914_7077714
# 2209    bullying     741455725993483816_3315342
# 2210    bullying                           None
# 2211    bullying    742743725022238626_25771652
# 2212    bullying    742983839856476354_12270015
# 2213  aggression    743666690560754068_10427687
# 2214      normal  743879405552600819_1125593136
# 2215  aggression   746509199826150022_243598255
# 2216  aggression   747963877363716269_704541443
# 2217    bullying     749477682261450660_6389534
#
# [2218 rows x 217 columns]

# %%
count = 0

# %%
def get_image_id(row):
    
#     global count
#     print(count)
#     count+=1
    comments = [row[f'clmn{i}'] for i in range(1,196)]
    comments = [clean_comment(i) for i in comments if i != 'empety']
    username  = row['owner_id'].replace("</font>","").replace('<font color="#0066CC">','').strip()
    
    if username in username_file_map.keys():
        mapping_file_number = username_file_map[username]
    else:    
        return None

    
    ids=[]
    for filename in mapping_file_number:
        with open(f'data/DATA_I_MADE/username_indexed_datadump_jsons/{filename}','r') as reader:
            file_json = json.load(reader)
        user_block = file_json[username]
        
        print(filename)

#         clean_comment_map  = {}
    
#         for c in user_block.keys():
#             clean_one = ' '.join(c.encode('ascii', 'ignore').strip( ' _'.encode('ascii')).decode("utf-8").split())
#             clean_comment_map[clean_one] = c
        
        for comment in comments:
            try:
#                 ids.append(user_block[clean_comment_map[comment]])
                ids.append(user_block[comment])

            except:
                print(comment)
                continue
    print(len(ids))
    
    assert False
    if ids!=[]:
        return max(set(ids), key = ids.count)
    else:
        return None

# %%
final_df['image_names_juggad_method_1'] = final_df.apply (lambda row: get_image_id(row),axis=1)
# Out:
# ['NormalUserFullInfo13.json']
# NormalUserFullInfo13.json
# Bahaha look at Niall!____ @karatorreswelch
# @moll_ie
# 86
# ['NormalUserFullInfo13.json']
# NormalUserFullInfo13.json
# Bahaha look at Niall!____ @karatorreswelch
# @moll_ie
# 86
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-171-e43bd263fd3f> in <module>
# ----> 1 final_df['image_names_juggad_method_1'] = final_df.apply (lambda row: get_image_id(row),axis=1)
#
# ~/anaconda3/envs/nii_project/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# ~/anaconda3/envs/nii_project/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~/anaconda3/envs/nii_project/lib/python3.6/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# ~/anaconda3/envs/nii_project/lib/python3.6/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-171-e43bd263fd3f> in <lambda>(row)
# ----> 1 final_df['image_names_juggad_method_1'] = final_df.apply (lambda row: get_image_id(row),axis=1)
#
# <ipython-input-170-ffe19d59a059> in get_image_id(row)
#      39     print(len(ids))
#      40
# ---> 41     assert False
#      42     if ids!=[]:
#      43         return max(set(ids), key = ids.count)
#
# AssertionError: occurred at index 0

# %%
final_df
# Out:
#       _golden _last_judgment_at  _trusted_judgments   _unit_id _unit_state  \
# 0       False      4/11/15 0:40                   5  702714440   finalized
# 1       False      4/11/15 0:37                   5  702714441   finalized
# 2       False      4/11/15 2:17                   5  702714442   finalized
# 3       False      4/11/15 2:09                   5  702714443   finalized
# 4       False     4/10/15 23:41                   5  702714444   finalized
# 5       False     4/10/15 23:44                   5  702714445   finalized
# 6       False      4/11/15 0:40                   5  702714446   finalized
# 7       False      4/11/15 0:37                   5  702714447   finalized
# 8       False     4/10/15 23:48                   5  702714448   finalized
# 9       False     4/10/15 23:47                   5  702714449   finalized
# 10      False      4/11/15 0:42                   5  702714450   finalized
# 11      False      4/11/15 2:10                   5  702714451   finalized
# 12      False     4/10/15 23:48                   5  702714452   finalized
# 13      False      4/11/15 2:09                   5  702714453   finalized
# 14      False      4/11/15 2:11                   5  702714454   finalized
# 15      False     4/10/15 23:45                   5  702714455   finalized
# 16      False     4/10/15 23:44                   5  702714456   finalized
# 17      False     4/10/15 23:41                   5  702714457   finalized
# 18      False      4/11/15 2:14                   5  702714458   finalized
# 19      False      4/11/15 2:10                   5  702714459   finalized
# 20      False      4/11/15 2:08                   5  702714460   finalized
# 21      False      4/11/15 2:07                   5  702714461   finalized
# 22      False     4/10/15 23:48                   5  702714462   finalized
# 23      False     4/10/15 23:44                   5  702714463   finalized
# 24      False      4/11/15 2:14                   5  702714464   finalized
# 25      False      4/11/15 2:17                   5  702714465   finalized
# 26      False     4/10/15 23:34                   5  702714466   finalized
# 27      False     4/10/15 23:35                   5  702714467   finalized
# 28      False     4/10/15 23:37                   5  702714468   finalized
# 29      False      4/11/15 0:42                   5  702714469   finalized
# ...       ...               ...                 ...        ...         ...
# 2188    False     1/22/15 20:50                   5  652910847   finalized
# 2189    False     1/20/15 16:33                   5  652910848   finalized
# 2190    False      1/24/15 4:20                   5  652910849   finalized
# 2191    False      1/22/15 0:49                   5  652910850   finalized
# 2192    False      1/21/15 6:16                   5  652910851   finalized
# 2193    False     1/23/15 11:39                   5  652910852   finalized
# 2194    False     1/23/15 11:47                   5  652910853   finalized
# 2195    False     1/27/15 14:30                   5  652910854   finalized
# 2196    False     1/22/15 21:19                   5  652910855   finalized
# 2197    False      1/26/15 0:03                   5  652910856   finalized
# 2198    False     1/20/15 17:43                   5  652910857   finalized
# 2199    False     1/24/15 18:21                   5  652910858   finalized
# 2200    False     1/23/15 11:50                   5  652910859   finalized
# 2201    False      1/22/15 1:59                   5  652910860   finalized
# 2202    False      1/26/15 0:08                   5  652910861   finalized
# 2203    False     1/27/15 14:21                   5  652910862   finalized
# 2204    False     1/20/15 12:48                   5  652910863   finalized
# 2205    False     1/21/15 17:24                   5  652910864   finalized
# 2206    False     1/23/15 11:44                   5  652910865   finalized
# 2207    False      1/27/15 2:47                   5  652910866   finalized
# 2208    False      1/22/15 0:50                   5  652910867   finalized
# 2209    False     1/21/15 20:58                   5  652910868   finalized
# 2210    False      1/26/15 0:06                   5  652910869   finalized
# 2211    False      1/22/15 0:49                   5  652910870   finalized
# 2212    False      1/25/15 2:27                   5  652910871   finalized
# 2213    False      1/20/15 8:27                   5  652910872   finalized
# 2214    False     1/24/15 17:35                   5  652910873   finalized
# 2215    False     1/21/15 17:33                   5  652910874   finalized
# 2216    False      1/25/15 2:40                   5  652910875   finalized
# 2217    False      1/21/15 0:40                   5  652910876   finalized
#
#                                                   clmn1  \
# 0     <font color="#0066CC">lynnseyerinalexandra</fo...
# 1     <font color="#0066CC">britterkritter</font>   ...
# 2     <font color="#0066CC">mariamagv</font>   where...
# 3     <font color="#0066CC">gladlychadly</font>   _...
# 4     <font color="#0066CC">fivefour</font>   <font ...
# 5     <font color="#0066CC">juliepailler</font>   _...
# 6     <font color="#0066CC">karisma_p</font>   <font...
# 7     <font color="#0066CC">samheartsu</font>   yay ...
# 8     <font color="#0066CC">_loloarcanjo_</font>   _...
# 9     <font color="#0066CC">harrycan_u_not</font>   ...
# 10    <font color="#0066CC">leixxak</font>   <font c...
# 11    <font color="#0066CC">eduarte1988</font>   1st...
# 12    <font color="#0066CC">trentleft</font>   <font...
# 13    <font color="#0066CC">cherrylnotman</font>   S...
# 14    <font color="#0066CC">jocelyn8642</font>   1st...
# 15    <font color="#0066CC">jamie_plowman</font>   S...
# 16    <font color="#0066CC">jovanna_maresca</font>  ...
# 17    <font color="#0066CC">mobelaisima</font>   Car...
# 18    <font color="#0066CC">bethsbunny</font>   BOOT...
# 19    <font color="#0066CC">urgrll</font>   GO SKY G...
# 20    <font color="#0066CC">mrs.kite</font>   <font ...
# 21    <font color="#0066CC">fabrizio_47</font>   Lol...
# 22    <font color="#0066CC">odahia</font>   You look...
# 23    <font color="#0066CC">emma.presnell</font>   H...
# 24    <font color="#0066CC">hi_my_name_is_jim</font>...
# 25    <font color="#0066CC">kishanjop</font>   I hav...
# 26    <font color="#0066CC">janesfashion19</font>   ...
# 27    <font color="#0066CC">tulip.sniper</font>   <f...
# 28    <font color="#0066CC">throwin_touchdowns_15</f...
# 29    <font color="#0066CC">allygirl0517</font>   Ob...
# ...                                                 ...
# 2188  <font color="#0066CC">texas_trill956</font>   ...
# 2189  <font color="#0066CC">moonwalkingrabbit</font>...
# 2190  <font color="#0066CC">tazawarya</font>   So yo...
# 2191  <font color="#0066CC">connorf1nn</font>   prob...
# 2192  <font color="#0066CC">charlotte_aaaa</font>   ...
# 2193  <font color="#0066CC">sarahgubbels_</font>   H...
# 2194  <font color="#0066CC">rose.kesha</font>   Edit...
# 2195  <font color="#0066CC">fuckhatred</font>   eeye...
# 2196  <font color="#0066CC">__aidanc__</font>   I ha...
# 2197  <font color="#0066CC">dat723</font>   I think ...
# 2198  <font color="#0066CC">yxngsnxxl</font>   Fuck ...
# 2199  <font color="#0066CC">jasdrift</font>   <font ...
# 2200  <font color="#0066CC">imaginesforharrygirls</f...
# 2201  <font color="#0066CC">lilbshadeymob88</font>  ...
# 2202  <font color="#0066CC">the_queen_of_all_selfies...
# 2203  <font color="#0066CC">wallywojo</font>   Justi...
# 2204  <font color="#0066CC">kelmichelle87</font>   H...
# 2205  <font color="#0066CC">medusssssssa</font>   <f...
# 2206  <font color="#0066CC">thackerdotcom</font>   Y...
# 2207  <font color="#0066CC">ellerosa</font>   :) <fo...
# 2208  <font color="#0066CC">enlighten_the_spirit</fo...
# 2209  <font color="#0066CC">reichert13</font>   MUG ...
# 2210  <font color="#0066CC">therealestb_80s</font>  ...
# 2211  <font color="#0066CC">clutchdigital</font>   1...
# 2212  <font color="#0066CC">kingsagundez29</font>   ...
# 2213  <font color="#0066CC">stateofkali</font>   you...
# 2214  <font color="#0066CC">_poquitobonita</font>   ...
# 2215  <font color="#0066CC">bodhi_sutra</font>   You...
# 2216  <font color="#0066CC">https.imvu</font>   I do...
# 2217  <font color="#0066CC">chanchi_16</font>   Haha...
#
#                                                  clmn10  \
# 0     <font color="#0066CC">niazki.lam</font>   larr...
# 1     <font color="#0066CC">kyleepickering</font>   ...
# 2     <font color="#0066CC">julianarosa67</font>   F...
# 3     <font color="#0066CC">crash_edisy</font>   <fo...
# 4     <font color="#0066CC">brohr285</font>   Still ...
# 5     <font color="#0066CC">shaunmichaelchapman</fon...
# 6     <font color="#0066CC">valex_33</font>   <font ...
# 7     <font color="#0066CC">tatum.sparks</font>   <f...
# 8     <font color="#0066CC">fcbayern_isibella</font>...
# 9     <font color="#0066CC">kingstyless</font>   <fo...
# 10    <font color="#0066CC">codizzle8</font>   Yo <f...
# 11    <font color="#0066CC">street_fly76</font>   Li...
# 12    <font color="#0066CC">chevy.b</font>   _Û_Û...
# 13    <font color="#0066CC">moabengtsson_</font>   G...
# 14    <font color="#0066CC">ikasalindo</font>   Pink...
# 15    <font color="#0066CC">rchiminoo</font>   ¥ÈÑ  ...
# 16    <font color="#0066CC">jlzrus</font>   Haha, th...
# 17    <font color="#0066CC">jojotanktop</font>   Who...
# 18    <font color="#0066CC">biscuit_slut</font>   Sw...
# 19    <font color="#0066CC">ponysauriohacerawr</font...
# 20    <font color="#0066CC">kerimae2</font>   <font ...
# 21    <font color="#0066CC">hockeyplyr39</font>   <f...
# 22    <font color="#0066CC">taylorstrupp</font>   ga...
# 23    <font color="#0066CC">j.ames</font>   stfu <fo...
# 24    <font color="#0066CC">juicydoo</font>   Hahaha...
# 25    <font color="#0066CC">grandyglaze1</font>   <f...
# 26    <font color="#0066CC">daycruvinel</font>   Bea...
# 27    <font color="#0066CC">alyssashakur</font>   yo...
# 28    <font color="#0066CC">jordanrisa</font>   __...
# 29    <font color="#0066CC">kori.91</font>   <font c...
# ...                                                 ...
# 2188  <font color="#0066CC">gnarfro</font>   <font c...
# 2189  <font color="#0066CC">prettyboii_creole</font>...
# 2190  <font color="#0066CC">hebrew_king21</font>   O...
# 2191  <font color="#0066CC">creepymasterlurker</font...
# 2192  <font color="#0066CC">meandmy_fandoms</font>  ...
# 2193  <font color="#0066CC">ameliajclark</font>   HE...
# 2194  <font color="#0066CC">loveinto_thelight</font>...
# 2195  <font color="#0066CC">neenoali</font>   I just...
# 2196  <font color="#0066CC">simon_5418</font>   Had ...
# 2197  <font color="#0066CC">siscoflores</font>   Tha...
# 2198  <font color="#0066CC">rodrigo_the_creator</fon...
# 2199  <font color="#0066CC">msindell</font>   <font ...
# 2200  <font color="#0066CC">mallory.lmao</font>   Ma...
# 2201  <font color="#0066CC">12hunnidblock</font>   F...
# 2202  <font color="#0066CC">fuenciado_._</font>   Cr...
# 2203  <font color="#0066CC">_leonalitii</font>   Eli...
# 2204  <font color="#0066CC">erinlorraine</font>   <f...
# 2205  <font color="#0066CC">proffessor_horse</font> ...
# 2206  <font color="#0066CC">mattington21</font>   Su...
# 2207  <font color="#0066CC">madilynsophia</font>   <...
# 2208  <font color="#0066CC">enlighten_the_spirit</fo...
# 2209  <font color="#0066CC">mandog423</font>   He be...
# 2210  <font color="#0066CC">melobee_</font>   Who ca...
# 2211  <font color="#0066CC">mike5832</font>   That n...
# 2212  <font color="#0066CC">leephil447</font>   Beau...
# 2213  <font color="#0066CC">timtrew</font>   Stick t...
# 2214  <font color="#0066CC">demondresavagepullen</fo...
# 2215  <font color="#0066CC">hebrew_king21</font>   O...
# 2216  <font color="#0066CC">katie_graf</font>   And ...
# 2217  <font color="#0066CC">chanchi_16</font>   Fatn...
#
#                                                 clmn100  \
# 0                                                empety
# 1                                                empety
# 2     <font color="#0066CC">oopshiharry</font>   Can...
# 3                                                empety
# 4     <font color="#0066CC">buddhaplaysbass</font>  ...
# 5                                                empety
# 6     <font color="#0066CC">sndraibnz</font>   wtf_...
# 7                                                empety
# 8     <font color="#0066CC">l0lelena</font>   Ahhaha...
# 9                                                empety
# 10    <font color="#0066CC">dozi_r</font>   <font co...
# 11                                               empety
# 12    <font color="#0066CC">marriiaaa__</font>   I k...
# 13                                               empety
# 14    <font color="#0066CC">liljswim</font>   Love t...
# 15    <font color="#0066CC">chozzy.wozzy</font>   _...
# 16    <font color="#0066CC">jadea513</font>   Loved ...
# 17                                               empety
# 18    <font color="#0066CC">cottcncandyheart</font> ...
# 19                                               empety
# 20    <font color="#0066CC">jenniebug</font>   <font...
# 21                                               empety
# 22                                               empety
# 23                                               empety
# 24    <font color="#0066CC">curly_q_kiana</font>   W...
# 25                                               empety
# 26    <font color="#0066CC">carod31888</font>   <fon...
# 27                                               empety
# 28                                               empety
# 29    <font color="#0066CC">maximus_gardette85</font...
# ...                                                 ...
# 2188                                             empety
# 2189                                             empety
# 2190                                             empety
# 2191                                             empety
# 2192  <font color="#0066CC">damaskgrinnell</font>   ...
# 2193                                             empety
# 2194                                             empety
# 2195  <font color="#0066CC">tru_scorpio_king</font> ...
# 2196  <font color="#0066CC">wild_hogs_5</font>   I w...
# 2197                                             empety
# 2198  <font color="#0066CC">mauricioxsoto</font>   F...
# 2199                                             empety
# 2200  <font color="#0066CC">sarah_clubb</font>   <fo...
# 2201  <font color="#0066CC">selfmade_cardi</font>   ...
# 2202                                             empety
# 2203  <font color="#0066CC">tydale_yrn</font>   Elit...
# 2204                                             empety
# 2205                                             empety
# 2206                                             empety
# 2207  <font color="#0066CC">misskriss62</font>   <fo...
# 2208                                             empety
# 2209                                             empety
# 2210  <font color="#0066CC">mrcbd</font>   _____...
# 2211                                             empety
# 2212                                             empety
# 2213                                             empety
# 2214                                             empety
# 2215                                             empety
# 2216  <font color="#0066CC">_1989hox</font>   I just...
# 2217  <font color="#0066CC">eman_m10</font>   ....yo...
#
#                                                 clmn101  \
# 0                                                empety
# 1                                                empety
# 2     <font color="#0066CC">nuriaat</font>   <font c...
# 3                                                empety
# 4     <font color="#0066CC">tjbyerly</font>   <font ...
# 5                                                empety
# 6     <font color="#0066CC">ileanakock</font>   Gwn ...
# 7                                                empety
# 8     <font color="#0066CC">mueller_mira</font>   Ha...
# 9                                                empety
# 10    <font color="#0066CC">jakecardinalee</font>   ...
# 11                                               empety
# 12    <font color="#0066CC">emmaaacaniff</font>   <f...
# 13                                               empety
# 14    <font color="#0066CC">dwpyy</font>   this is m...
# 15    <font color="#0066CC">erzzamaloku</font>   How...
# 16    <font color="#0066CC">kellikole</font>   Love ...
# 17                                               empety
# 18    <font color="#0066CC">hes_clueing_for_looks</f...
# 19                                               empety
# 20    <font color="#0066CC">anat_blitz</font>   <fon...
# 21                                               empety
# 22                                               empety
# 23                                               empety
# 24    <font color="#0066CC">huda_187</font>   U foun...
# 25                                               empety
# 26    <font color="#0066CC">mehlene</font>   And thi...
# 27                                               empety
# 28                                               empety
# 29    <font color="#0066CC">rowank01</font>   ROMNEY...
# ...                                                 ...
# 2188                                             empety
# 2189                                             empety
# 2190                                             empety
# 2191                                             empety
# 2192  <font color="#0066CC">sadieileen</font>   <fon...
# 2193                                             empety
# 2194                                             empety
# 2195  <font color="#0066CC">jake.day</font>   <font ...
# 2196  <font color="#0066CC">r_mack10</font>   I had ...
# 2197                                             empety
# 2198  <font color="#0066CC">the_real_anthony100</fon...
# 2199                                             empety
# 2200  <font color="#0066CC">wendyfiliti</font>   <fo...
# 2201  <font color="#0066CC">bigningez</font>   Smack...
# 2202                                             empety
# 2203  <font color="#0066CC">carsonb1230</font>   Ran...
# 2204                                             empety
# 2205                                             empety
# 2206                                             empety
# 2207  <font color="#0066CC">rukiyeakm</font>   this ...
# 2208                                             empety
# 2209                                             empety
# 2210  <font color="#0066CC">dritowel</font>   Keep d...
# 2211                                             empety
# 2212                                             empety
# 2213                                             empety
# 2214                                             empety
# 2215                                             empety
# 2216  <font color="#0066CC">_1989hox</font>   And ge...
# 2217  <font color="#0066CC">eyee_van</font>   <font ...
#
#                                                 clmn102  \
# 0                                                empety
# 1                                                empety
# 2     <font color="#0066CC">agusjalo</font>   This i...
# 3                                                empety
# 4     <font color="#0066CC">fivefour</font>   <font ...
# 5                                                empety
# 6     <font color="#0066CC">olivias_01</font>   <fon...
# 7                                                empety
# 8     <font color="#0066CC">casu259</font>   Hi  (cr...
# 9                                                empety
# 10    <font color="#0066CC">rasyaadikoro</font>   Hh...
# 11                                               empety
# 12    <font color="#0066CC">breanna_marie_1</font>  ...
# 13                                               empety
# 14    <font color="#0066CC">lucianacunha82</font>   ...
# 15    <font color="#0066CC">bleonebrestovci</font>  ...
# 16    <font color="#0066CC">lovemyboys40</font>   Lo...
# 17                                               empety
# 18    <font color="#0066CC">confessionsbyyou</font> ...
# 19                                               empety
# 20    <font color="#0066CC">thelibertinee</font>   O...
# 21                                               empety
# 22                                               empety
# 23                                               empety
# 24    <font color="#0066CC">owen002</font>   BURN  (...
# 25                                               empety
# 26    <font color="#0066CC">ayyyzma</font>   Love lo...
# 27                                               empety
# 28                                               empety
# 29    <font color="#0066CC">_nicolala</font>   Obama...
# ...                                                 ...
# 2188                                             empety
# 2189                                             empety
# 2190                                             empety
# 2191                                             empety
# 2192  <font color="#0066CC">sleepy.little.kitty</fon...
# 2193                                             empety
# 2194                                             empety
# 2195  <font color="#0066CC">zaylo704</font>   Jon co...
# 2196  <font color="#0066CC">luckygoal4</font>   I ha...
# 2197                                             empety
# 2198  <font color="#0066CC">the_real_anthony100</fon...
# 2199                                             empety
# 2200  <font color="#0066CC">giorgiacaruana</font>   ...
# 2201  <font color="#0066CC">anazfinest</font>   All ...
# 2202                                             empety
# 2203  <font color="#0066CC">aidan_northup17</font>  ...
# 2204                                             empety
# 2205                                             empety
# 2206                                             empety
# 2207  <font color="#0066CC">nasser__alothman</font> ...
# 2208                                             empety
# 2209                                             empety
# 2210  <font color="#0066CC">donchristo310</font>   T...
# 2211                                             empety
# 2212                                             empety
# 2213                                             empety
# 2214                                             empety
# 2215                                             empety
# 2216  <font color="#0066CC">_1989hox</font>   These ...
# 2217  <font color="#0066CC">bryanvega_</font>   <fon...
#
#                   ...                           likes  \
# 0                 ...                  4313\r\r likes
# 1                 ...                  2102\r\r likes
# 2                 ...                108939\r\r likes
# 3                 ...                  6441\r\r likes
# 4                 ...                  1153\r\r likes
# 5                 ...                  4381\r\r likes
# 6                 ...                  8199\r\r likes
# 7                 ...                  3366\r\r likes
# 8                 ...                 86443\r\r likes
# 9                 ...                    61\r\r likes
# 10                ...                 46290\r\r likes
# 11                ...                   964\r\r likes
# 12                ...                197284\r\r likes
# 13                ...                  2236\r\r likes
# 14                ...                  3195\r\r likes
# 15                ...                 14528\r\r likes
# 16                ...                 28972\r\r likes
# 17                ...                  1244\r\r likes
# 18                ...                 10524\r\r likes
# 19                ...                  7866\r\r likes
# 20                ...                  8916\r\r likes
# 21                ...                   529\r\r likes
# 22                ...                    85\r\r likes
# 23                ...                  6868\r\r likes
# 24                ...                 23406\r\r likes
# 25                ...                  1140\r\r likes
# 26                ...                 15713\r\r likes
# 27                ...                   807\r\r likes
# 28                ...                  2135\r\r likes
# 29                ...                  8362\r\r likes
# ...               ...                             ...
# 2188              ...                       630 likes
# 2189              ...                        40 likes
# 2190              ...                        34 likes
# 2191              ...                       503 likes
# 2192              ...                      1816 likes
# 2193              ...                       695 likes
# 2194              ...                       147 likes
# 2195              ...                      7331 likes
# 2196              ...                       486 likes
# 2197              ...                       127 likes
# 2198              ...                     22892 likes
# 2199              ...                      4425 likes
# 2200              ...                      4245 likes
# 2201              ...                      2751 likes
# 2202              ...                       101 likes
# 2203              ...                       697 likes
# 2204              ...                       312 likes
# 2205              ...                       510 likes
# 2206              ...                      1258 likes
# 2207              ...                      7520 likes
# 2208              ...                       232 likes
# 2209              ...                      3075 likes
# 2210              ...                      2314 likes
# 2211              ...                      2757 likes
# 2212              ...                       294 likes
# 2213              ...                       442 likes
# 2214              ...                       196 likes
# 2215              ...                        50 likes
# 2216              ...                       454 likes
# 2217              ...                     37734 likes
#
#                                              owner_cmnt  \
# 0     gosh we love these five idiots so much __ for...
# 1     Anyone see the Pepsi halftime show commercial ...
# 2     Today I ate cr_pes and bought a drawing of ch...
# 3     New works in progress for an upcoming show at ...
# 4     Due to overwhelming response, we have went ahe...
# 5                      Loving the leather-denim combo."
# 6                                  OMFG I'M DYING _Û_"
# 7                      Yay or nay? tag your friends_ä
# 8      Afternoon in Campo Bahia with the team _Û__"
# 9     i leave you with one of my favorite harry vide...
# 10      Wishing you a happy birthday, dear @erickoston.
# 11                                     Brick by brick."
# 12                  Ridin' dirty with @hayes_instagram"
# 13                                                __"
# 14                         Pink stripes or pink shoes?"
# 15    New snapback from @larepublicclothing _´ Lov...
# 16    Charlie looking very pleased with his "#MerylS...
# 17    Doing kissy face with my baby @drodd36 #BodyEn...
# 18                                 when doge sees cate"
# 19     Cole & I up at 6 am. JK. He's still asleep __"
# 20                                                _±"
# 21                         Completely normal kids demo"
# 22    Emily missed this picture ): but with the love...
# 23                                      #doge4president
# 24                 Buuurn_î!!! @NailsCamera _Ñ___"
# 25    #repost big S/O to the awesome @Vladogirl , th...
# 26                    'Ciao Milano' by Hayden Williams"
# 27    Tune into @mtv Tuesday Jan 7th - 10pm EST, to ...
# 28    Dinner last night at @Herringbonemondrian w/ m...
# 29    Today is Election Day! #WeWill #GoVote @rockth...
# ...                                                 ...
# 2188   S/O and thank you to my boy <font color="#006...
# 2189   Maan this guy is messed up f*ckin racist bitc...
# 2190   A Third World War,the perfect set up to bring...
# 2191                                     true or false?
# 2192   Tell me what pisses you off and rant about it...
# 2193                                          HELL YEAH
# 2194   What's your favorite music video from the War...
# 2195   DAAAAAMN! <font color="#0066CC">@jarrenbenton...
# 2196                                        Go! Comment
# 2197   Fuck what y'all niggas talking bout we really...
# 2198               X games. Everybody say Fuck Anthony.
# 2199   Our dude <font color="#0066CC">@bjenner</font...
# 2200   YOU CAN NEVER TAKE HARRY SERIOUSLY WHEN HE SA...
# 2201   They asked where the mustard bottle was my so...
# 2202                    Sorry but I just had to do this
# 2203   It's time for <font color="#0066CC">#WhatFigu...
# 2204                                          Fan mail.
# 2205   The Collar-Bomb Murder of Ana Elvia in Colomb...
# 2206                     New music video up, LINK in bi
# 2207   No matter what you believe in, hunting/no hun...
# 2208   Is the root of the problem the gun? Or the fi...
# 2209   Eric Fisher gets ready for his headshot | <fo...
# 2210                                     Shit cray !!!!
# 2211   Camp life.. <font color="#0066CC">#MikeVickWe...
# 2212   Signed over 300 pics at today's signing ! Fou...
# 2213   Skills! <font color="#0066CC">#sundayfunday</...
# 2214   Lol <font color="#0066CC">#tupacamarushakur#t...
# 2215   Who cares right? There both just books? ___...
# 2216                 Media posted at 014-06-21 20:57:44
# 2217   Next Stop: Knockout Round! <font color="#0066...
#
#                                                owner_id   question1  \
# 0              <font color="#0066CC">maliksbby</font>       noneAgg
# 1           <font color="#0066CC">witneycarson</font>       noneAgg
# 2            <font color="#0066CC">namelessgem</font>       noneAgg
# 3                   <font color="#0066CC">kaws</font>    aggression
# 4               <font color="#0066CC">fivefour</font>       noneAgg
# 5         <font color="#0066CC">adidasneolabel</font>       noneAgg
# 6               <font color="#0066CC">sextpert</font>       noneAgg
# 7          <font color="#0066CC">avanityaffair</font>       noneAgg
# 8             <font color="#0066CC">gotzemario</font>       noneAgg
# 9            <font color="#0066CC">kingstyless</font>       noneAgg
# 10                <font color="#0066CC">nikesb</font>       noneAgg
# 11         <font color="#0066CC">dennistodisco</font>       noneAgg
# 12          <font color="#0066CC">jackgilinsky</font>       noneAgg
# 13               <font color="#0066CC">loekenz</font>       noneAgg
# 14        <font color="#0066CC">adidasneolabel</font>       noneAgg
# 15        <font color="#0066CC">itsjonasfossum</font>       noneAgg
# 16           <font color="#0066CC">meryledavis</font>       noneAgg
# 17         <font color="#0066CC">carlafacciolo</font>       noneAgg
# 18             <font color="#0066CC">doge.post</font>       noneAgg
# 19           <font color="#0066CC">skyferreira</font>       noneAgg
# 20          <font color="#0066CC">insta_kitten</font>       noneAgg
# 21     <font color="#0066CC">jordanroriepayton</font>       noneAgg
# 22         <font color="#0066CC">hayleyamelia_</font>       noneAgg
# 23             <font color="#0066CC">doge.post</font>       noneAgg
# 24            <font color="#0066CC">bestttextt</font>       noneAgg
# 25         <font color="#0066CC">vladofootwear</font>       noneAgg
# 26       <font color="#0066CC">hayden_williams</font>       noneAgg
# 27           <font color="#0066CC">missfamenyc</font>       noneAgg
# 28               <font color="#0066CC">klarity</font>       noneAgg
# 29        <font color="#0066CC">bridgitmendler</font>    aggression
# ...                                                 ...         ...
# 2188        <font color="#0066CC">paulwallbaby</font>    aggression
# 2189    <font color="#0066CC">makavellijackson</font>    aggression
# 2190          <font color="#0066CC">childofyah</font>       noneAgg
# 2191       <font color="#0066CC">nesserfamilia</font>       noneAgg
# 2192           <font color="#0066CC">jerkstiel</font>    aggression
# 2193     <font color="#0066CC">andthatismyfact</font>       noneAgg
# 2194          <font color="#0066CC">keshatoday</font>       noneAgg
# 2195           <font color="#0066CC">hopsinson</font>    aggression
# 2196    <font color="#0066CC">patriotsfootball</font>       noneAgg
# 2197          <font color="#0066CC">ice_marrow</font>    aggression
# 2198      <font color="#0066CC">larryfisherman</font>    aggression
# 2199        <font color="#0066CC">thehoonigans</font>    aggression
# 2200         <font color="#0066CC">haroldluvme</font>       noneAgg
# 2201           <font color="#0066CC">djmustard</font>    aggression
# 2202        <font color="#0066CC">andybvb_fanp</font>       noneAgg
# 2203           <font color="#0066CC">ringsidec</font>       noneAgg
# 2204          <font color="#0066CC">jeffdauler</font>    aggression
# 2205        <font color="#0066CC">notexplained</font>       noneAgg
# 2206           <font color="#0066CC">joeysalad</font>    aggression
# 2207       <font color="#0066CC">sophiamiacova</font>    aggression
# 2208  <font color="#0066CC">enlighten_the_spirit</fo...     noneAgg
# 2209            <font color="#0066CC">kcchiefs</font>    aggression
# 2210           <font color="#0066CC">djmustard</font>    aggression
# 2211            <font color="#0066CC">mikevick</font>    aggression
# 2212             <font color="#0066CC">rebysky</font>    aggression
# 2213          <font color="#0066CC">shawnsuggs</font>    aggression
# 2214  <font color="#0066CC">tupac_amaru_shakur1996</...     noneAgg
# 2215          <font color="#0066CC">childofyah</font>    aggression
# 2216             <font color="#0066CC">cutting</font>    aggression
# 2217        <font color="#0066CC">soccerdotcom</font>    aggression
#
#      question1:confidence question2 question2:confidence shared media  \
# 0                  0.8124   noneBll               1.0000         1477
# 1                  1.0000   noneBll               1.0000          761
# 2                  0.8056   noneBll               0.8056          698
# 3                  0.5982  bullying               0.5982         1257
# 4                  1.0000   noneBll               1.0000         2052
# 5                  1.0000   noneBll               1.0000         1520
# 6                  1.0000   noneBll               1.0000         2158
# 7                  0.5980   noneBll               1.0000         2616
# 8                  0.7965   noneBll               0.7965          507
# 9                  1.0000   noneBll               1.0000          377
# 10                 1.0000   noneBll               1.0000         1019
# 11                 0.8056   noneBll               0.8056          658
# 12                 0.7965   noneBll               1.0000          325
# 13                 0.6091   noneBll               0.6091         1451
# 14                 0.7926   noneBll               0.7926         1520
# 15                 1.0000   noneBll               1.0000          536
# 16                 1.0000   noneBll               1.0000          695
# 17                 0.7965   noneBll               1.0000         1208
# 18                 1.0000   noneBll               1.0000          277
# 19                 0.8035   noneBll               0.8035         2179
# 20                 0.7926   noneBll               0.7926          984
# 21                 0.5982   noneBll               0.5982         1087
# 22                 1.0000   noneBll               1.0000          239
# 23                 0.7965   noneBll               0.7965          277
# 24                 0.5982   noneBll               0.5982          627
# 25                 0.8035   noneBll               0.8035         1639
# 26                 1.0000   noneBll               1.0000         1567
# 27                 1.0000   noneBll               1.0000         1005
# 28                 0.8078   noneBll               1.0000          858
# 29                 0.7969  bullying               0.6093          765
# ...                   ...       ...                  ...          ...
# 2188               1.0000  bullying               0.6117         1884
# 2189               1.0000  bullying               1.0000          644
# 2190               1.0000   noneBll               1.0000         1905
# 2191               1.0000   noneBll               1.0000          640
# 2192               0.8051   noneBll               0.5888         2514
# 2193               0.8055   noneBll               0.8055          462
# 2194               1.0000   noneBll               1.0000          277
# 2195               0.6245  bullying               0.6245         1247
# 2196               1.0000   noneBll               1.0000         1147
# 2197               1.0000  bullying               1.0000         1187
# 2198               1.0000  bullying               0.8018         1556
# 2199               1.0000  bullying               0.8081         1959
# 2200               0.5995   noneBll               0.8022         1847
# 2201               1.0000  bullying               1.0000         1949
# 2202               1.0000   noneBll               1.0000         3351
# 2203               1.0000   noneBll               1.0000         1521
# 2204               0.7965   noneBll               0.6024         1676
# 2205               0.7997   noneBll               0.7997          498
# 2206               1.0000  bullying               1.0000          780
# 2207               1.0000  bullying               0.7995          407
# 2208               1.0000   noneBll               1.0000         2727
# 2209               0.7908  bullying               0.7908         1280
# 2210               1.0000  bullying               0.5886         1949
# 2211               0.7867  bullying               0.7867          323
# 2212               0.6017  bullying               0.6017         1266
# 2213               0.7879   noneBll               0.7963         1607
# 2214               1.0000   noneBll               1.0000         2204
# 2215               0.6090   noneBll               0.5868         1905
# 2216               0.5954   noneBll               0.5975          319
# 2217               1.0000  bullying               1.0000         2009
#
#            label                    image_names
# 0         normal   552190883286908244_298930414
# 1         normal     642359127764866726_6922532
# 2         normal   647118643004316858_627934998
# 3       bullying                           None
# 4         normal     714072510509514236_4879766
# 5         normal    675458665342891496_12958644
# 6         normal   609710384873238487_650673866
# 7         normal                           None
# 8         normal   326629905817324694_237159274
# 9         normal                           None
# 10        normal    709380341579654667_26490008
# 11        normal     512433051729855776_4145448
# 12        normal    639287130613158659_54217883
# 13        normal   454320667353994039_206604147
# 14        normal    447219051462718639_12958644
# 15        normal                           None
# 16        normal    734180960711230639_19570784
# 17        normal    487010175421664223_41085145
# 18        normal   621448822633198172_363197235
# 19        normal   608569070829974114_179861803
# 20        normal   340391427958787728_251101170
# 21        normal   505146992545029518_173930054
# 22        normal                           None
# 23        normal   634985029644251431_363197235
# 24        normal                           None
# 25        normal    732178613622458956_25051713
# 26        normal    396350735489250600_37504940
# 27        normal   627674052492589070_244975829
# 28        normal    707359384817630884_26221534
# 29      bullying    318884887533226902_53167593
# ...          ...                            ...
# 2188    bullying    735537793712264421_17296540
# 2189    bullying   735555112724831441_270483046
# 2190      normal   735675530169475160_243598255
# 2191      normal     735712401639406803_2811086
# 2192  aggression   736046144866767539_391491299
# 2193      normal                           None
# 2194      normal                           None
# 2195    bullying   737102530862896608_215707036
# 2196      normal   737525783643346863_191104148
# 2197    bullying    738253376803007770_16326242
# 2198    bullying    738275438920576337_10514202
# 2199    bullying    738418075889277490_10176765
# 2200      normal   738601214135415558_293518499
# 2201    bullying    739308126836821188_13512754
# 2202      normal   740308670017689655_712250757
# 2203      normal   740564309307006754_325781254
# 2204  aggression      740574134516332082_983084
# 2205      normal                           None
# 2206    bullying   741378265404139922_278236785
# 2207    bullying    741399243826850211_14105697
# 2208      normal     741439969975495914_7077714
# 2209    bullying     741455725993483816_3315342
# 2210    bullying    742170348852284880_13512754
# 2211    bullying    742743725022238626_25771652
# 2212    bullying    742983839856476354_12270015
# 2213  aggression    743666690560754068_10427687
# 2214      normal  743879405552600819_1125593136
# 2215  aggression   746509199826150022_243598255
# 2216  aggression   747963877363716269_704541443
# 2217    bullying     749477682261450660_6389534
#
# [2218 rows x 217 columns]

# %%
final_df.to_pickle('data/final_csv.pkl')

# %% [markdown]
# ## filter out ids

# %%
final_df = pd.read_pickle('data/final_csv_method_1.pkl')

# %%
image_names_list = final_df['image_names'].tolist()

# %%
unique_ids_found = list(set([i for i in image_names_list if i!=None]))
len(unique_ids_found)
# Out:
# 1686

# %%
intersection_found_and_folder = set(all_ids_folder)&set(unique_ids_found)
len(intersection_found_and_folder)
# Out:
# 1003

# %%
len(set(ids_present_in_data_dump)&set(unique_ids_found))
# Out:
# 776

# %%
label_list = final_df.loc[final_df['image_names'].isin(intersection_found_and_folder)]['label'].tolist()

# %%
print(f"Normal count = {label_list.count('normal')}")
print(f"Aggression count = {label_list.count('aggression')}")
print(f"Bullying count = {label_list.count('bullying')}")
# Out:
# Normal count = 484
# Aggression count = 106
# Bullying count = 413

# %%
len(ids_present_in_data_dump)
# Out:
# 1630

# %%
len(set(ids_retrived_using_links+ids_present_in_data_dump))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-717ddd382fbe> in <module>
# ----> 1 len(set(ids_retrived_using_links+ids_present_in_data_dump))
#
# NameError: name 'ids_retrived_using_links' is not defined

# %%
len(set(all_ids_folder)&set(ids_retrived_using_links))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-2ccbfcc27478> in <module>
# ----> 1 len(set(all_ids_folder)&set(ids_retrived_using_links))
#
# NameError: name 'ids_retrived_using_links' is not defined

# %% [markdown]
# # #Jugad 2

# %% [markdown]
# Data dump to media_ids_json

# %%
count=0

# %%
all_files_to_parse = [f'data/Instagram_normal_users/{i}' for i in normal_users_filenames]+ [f'data/Instagram_common_users/{i}' for i in common_users_filenames]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-4b088440f9b3> in <module>
# ----> 1 all_files_to_parse = [f'data/Instagram_normal_users/{i}' for i in normal_users_filenames]+ [f'data/Instagram_common_users/{i}' for i in common_users_filenames]
#
# NameError: name 'normal_users_filenames' is not defined

# %%
# Out:
# HBox(children=(IntProgress(value=0, max=47), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=660), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=455), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=294), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=287), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=489), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=63), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=255), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=633), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=766), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=760), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=573), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=615), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=851), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=280), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=240), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=578), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=393), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=225), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=404), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=339), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=176), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=477), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=524), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=517), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=529), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=494), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=477), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=523), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=601), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=451), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=456), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=375), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=515), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=515), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=773), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=876), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1310), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1309), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=505), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1431), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1412), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1394), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1395), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1368), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1363), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1345), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1317), HTML(value='')))

# %% [markdown]
# id to file mapping

# %%
number_of_jsons = 47
media_id_file = dict()

# %%
for i in tqdm(range(number_of_jsons)):
    with open(f'data/method_2/dump_jsons/{i}.json','r') as reader:
        file_dict = json.load(reader)
    for media_id in file_dict.keys():
        if media_id in media_id_file.keys():
            media_id_file[media_id].append(i)
        else:
            media_id_file[media_id] = [i]
# Out:
# HBox(children=(IntProgress(value=0, max=47), HTML(value='')))

# %%
with open(f'data/method_2/media_id_file_map.json','w') as fp:
            json.dump(media_id_file, fp,indent=4)

# %% [markdown]
# extracting shit from labeled file

# %%
df_copy = final_df.drop(['image_names'], axis=1)

# %%
df_copy
# Out:
#       _golden _last_judgment_at  _trusted_judgments   _unit_id _unit_state  \
# 0       False      4/11/15 0:40                   5  702714440   finalized
# 1       False      4/11/15 0:37                   5  702714441   finalized
# 2       False      4/11/15 2:17                   5  702714442   finalized
# 3       False      4/11/15 2:09                   5  702714443   finalized
# 4       False     4/10/15 23:41                   5  702714444   finalized
# 5       False     4/10/15 23:44                   5  702714445   finalized
# 6       False      4/11/15 0:40                   5  702714446   finalized
# 7       False      4/11/15 0:37                   5  702714447   finalized
# 8       False     4/10/15 23:48                   5  702714448   finalized
# 9       False     4/10/15 23:47                   5  702714449   finalized
# 10      False      4/11/15 0:42                   5  702714450   finalized
# 11      False      4/11/15 2:10                   5  702714451   finalized
# 12      False     4/10/15 23:48                   5  702714452   finalized
# 13      False      4/11/15 2:09                   5  702714453   finalized
# 14      False      4/11/15 2:11                   5  702714454   finalized
# 15      False     4/10/15 23:45                   5  702714455   finalized
# 16      False     4/10/15 23:44                   5  702714456   finalized
# 17      False     4/10/15 23:41                   5  702714457   finalized
# 18      False      4/11/15 2:14                   5  702714458   finalized
# 19      False      4/11/15 2:10                   5  702714459   finalized
# 20      False      4/11/15 2:08                   5  702714460   finalized
# 21      False      4/11/15 2:07                   5  702714461   finalized
# 22      False     4/10/15 23:48                   5  702714462   finalized
# 23      False     4/10/15 23:44                   5  702714463   finalized
# 24      False      4/11/15 2:14                   5  702714464   finalized
# 25      False      4/11/15 2:17                   5  702714465   finalized
# 26      False     4/10/15 23:34                   5  702714466   finalized
# 27      False     4/10/15 23:35                   5  702714467   finalized
# 28      False     4/10/15 23:37                   5  702714468   finalized
# 29      False      4/11/15 0:42                   5  702714469   finalized
# ...       ...               ...                 ...        ...         ...
# 2188    False     1/22/15 20:50                   5  652910847   finalized
# 2189    False     1/20/15 16:33                   5  652910848   finalized
# 2190    False      1/24/15 4:20                   5  652910849   finalized
# 2191    False      1/22/15 0:49                   5  652910850   finalized
# 2192    False      1/21/15 6:16                   5  652910851   finalized
# 2193    False     1/23/15 11:39                   5  652910852   finalized
# 2194    False     1/23/15 11:47                   5  652910853   finalized
# 2195    False     1/27/15 14:30                   5  652910854   finalized
# 2196    False     1/22/15 21:19                   5  652910855   finalized
# 2197    False      1/26/15 0:03                   5  652910856   finalized
# 2198    False     1/20/15 17:43                   5  652910857   finalized
# 2199    False     1/24/15 18:21                   5  652910858   finalized
# 2200    False     1/23/15 11:50                   5  652910859   finalized
# 2201    False      1/22/15 1:59                   5  652910860   finalized
# 2202    False      1/26/15 0:08                   5  652910861   finalized
# 2203    False     1/27/15 14:21                   5  652910862   finalized
# 2204    False     1/20/15 12:48                   5  652910863   finalized
# 2205    False     1/21/15 17:24                   5  652910864   finalized
# 2206    False     1/23/15 11:44                   5  652910865   finalized
# 2207    False      1/27/15 2:47                   5  652910866   finalized
# 2208    False      1/22/15 0:50                   5  652910867   finalized
# 2209    False     1/21/15 20:58                   5  652910868   finalized
# 2210    False      1/26/15 0:06                   5  652910869   finalized
# 2211    False      1/22/15 0:49                   5  652910870   finalized
# 2212    False      1/25/15 2:27                   5  652910871   finalized
# 2213    False      1/20/15 8:27                   5  652910872   finalized
# 2214    False     1/24/15 17:35                   5  652910873   finalized
# 2215    False     1/21/15 17:33                   5  652910874   finalized
# 2216    False      1/25/15 2:40                   5  652910875   finalized
# 2217    False      1/21/15 0:40                   5  652910876   finalized
#
#                                                   clmn1  \
# 0     <font color="#0066CC">lynnseyerinalexandra</fo...
# 1     <font color="#0066CC">britterkritter</font>   ...
# 2     <font color="#0066CC">mariamagv</font>   where...
# 3     <font color="#0066CC">gladlychadly</font>   _...
# 4     <font color="#0066CC">fivefour</font>   <font ...
# 5     <font color="#0066CC">juliepailler</font>   _...
# 6     <font color="#0066CC">karisma_p</font>   <font...
# 7     <font color="#0066CC">samheartsu</font>   yay ...
# 8     <font color="#0066CC">_loloarcanjo_</font>   _...
# 9     <font color="#0066CC">harrycan_u_not</font>   ...
# 10    <font color="#0066CC">leixxak</font>   <font c...
# 11    <font color="#0066CC">eduarte1988</font>   1st...
# 12    <font color="#0066CC">trentleft</font>   <font...
# 13    <font color="#0066CC">cherrylnotman</font>   S...
# 14    <font color="#0066CC">jocelyn8642</font>   1st...
# 15    <font color="#0066CC">jamie_plowman</font>   S...
# 16    <font color="#0066CC">jovanna_maresca</font>  ...
# 17    <font color="#0066CC">mobelaisima</font>   Car...
# 18    <font color="#0066CC">bethsbunny</font>   BOOT...
# 19    <font color="#0066CC">urgrll</font>   GO SKY G...
# 20    <font color="#0066CC">mrs.kite</font>   <font ...
# 21    <font color="#0066CC">fabrizio_47</font>   Lol...
# 22    <font color="#0066CC">odahia</font>   You look...
# 23    <font color="#0066CC">emma.presnell</font>   H...
# 24    <font color="#0066CC">hi_my_name_is_jim</font>...
# 25    <font color="#0066CC">kishanjop</font>   I hav...
# 26    <font color="#0066CC">janesfashion19</font>   ...
# 27    <font color="#0066CC">tulip.sniper</font>   <f...
# 28    <font color="#0066CC">throwin_touchdowns_15</f...
# 29    <font color="#0066CC">allygirl0517</font>   Ob...
# ...                                                 ...
# 2188  <font color="#0066CC">texas_trill956</font>   ...
# 2189  <font color="#0066CC">moonwalkingrabbit</font>...
# 2190  <font color="#0066CC">tazawarya</font>   So yo...
# 2191  <font color="#0066CC">connorf1nn</font>   prob...
# 2192  <font color="#0066CC">charlotte_aaaa</font>   ...
# 2193  <font color="#0066CC">sarahgubbels_</font>   H...
# 2194  <font color="#0066CC">rose.kesha</font>   Edit...
# 2195  <font color="#0066CC">fuckhatred</font>   eeye...
# 2196  <font color="#0066CC">__aidanc__</font>   I ha...
# 2197  <font color="#0066CC">dat723</font>   I think ...
# 2198  <font color="#0066CC">yxngsnxxl</font>   Fuck ...
# 2199  <font color="#0066CC">jasdrift</font>   <font ...
# 2200  <font color="#0066CC">imaginesforharrygirls</f...
# 2201  <font color="#0066CC">lilbshadeymob88</font>  ...
# 2202  <font color="#0066CC">the_queen_of_all_selfies...
# 2203  <font color="#0066CC">wallywojo</font>   Justi...
# 2204  <font color="#0066CC">kelmichelle87</font>   H...
# 2205  <font color="#0066CC">medusssssssa</font>   <f...
# 2206  <font color="#0066CC">thackerdotcom</font>   Y...
# 2207  <font color="#0066CC">ellerosa</font>   :) <fo...
# 2208  <font color="#0066CC">enlighten_the_spirit</fo...
# 2209  <font color="#0066CC">reichert13</font>   MUG ...
# 2210  <font color="#0066CC">therealestb_80s</font>  ...
# 2211  <font color="#0066CC">clutchdigital</font>   1...
# 2212  <font color="#0066CC">kingsagundez29</font>   ...
# 2213  <font color="#0066CC">stateofkali</font>   you...
# 2214  <font color="#0066CC">_poquitobonita</font>   ...
# 2215  <font color="#0066CC">bodhi_sutra</font>   You...
# 2216  <font color="#0066CC">https.imvu</font>   I do...
# 2217  <font color="#0066CC">chanchi_16</font>   Haha...
#
#                                                  clmn10  \
# 0     <font color="#0066CC">niazki.lam</font>   larr...
# 1     <font color="#0066CC">kyleepickering</font>   ...
# 2     <font color="#0066CC">julianarosa67</font>   F...
# 3     <font color="#0066CC">crash_edisy</font>   <fo...
# 4     <font color="#0066CC">brohr285</font>   Still ...
# 5     <font color="#0066CC">shaunmichaelchapman</fon...
# 6     <font color="#0066CC">valex_33</font>   <font ...
# 7     <font color="#0066CC">tatum.sparks</font>   <f...
# 8     <font color="#0066CC">fcbayern_isibella</font>...
# 9     <font color="#0066CC">kingstyless</font>   <fo...
# 10    <font color="#0066CC">codizzle8</font>   Yo <f...
# 11    <font color="#0066CC">street_fly76</font>   Li...
# 12    <font color="#0066CC">chevy.b</font>   _Û_Û...
# 13    <font color="#0066CC">moabengtsson_</font>   G...
# 14    <font color="#0066CC">ikasalindo</font>   Pink...
# 15    <font color="#0066CC">rchiminoo</font>   ¥ÈÑ  ...
# 16    <font color="#0066CC">jlzrus</font>   Haha, th...
# 17    <font color="#0066CC">jojotanktop</font>   Who...
# 18    <font color="#0066CC">biscuit_slut</font>   Sw...
# 19    <font color="#0066CC">ponysauriohacerawr</font...
# 20    <font color="#0066CC">kerimae2</font>   <font ...
# 21    <font color="#0066CC">hockeyplyr39</font>   <f...
# 22    <font color="#0066CC">taylorstrupp</font>   ga...
# 23    <font color="#0066CC">j.ames</font>   stfu <fo...
# 24    <font color="#0066CC">juicydoo</font>   Hahaha...
# 25    <font color="#0066CC">grandyglaze1</font>   <f...
# 26    <font color="#0066CC">daycruvinel</font>   Bea...
# 27    <font color="#0066CC">alyssashakur</font>   yo...
# 28    <font color="#0066CC">jordanrisa</font>   __...
# 29    <font color="#0066CC">kori.91</font>   <font c...
# ...                                                 ...
# 2188  <font color="#0066CC">gnarfro</font>   <font c...
# 2189  <font color="#0066CC">prettyboii_creole</font>...
# 2190  <font color="#0066CC">hebrew_king21</font>   O...
# 2191  <font color="#0066CC">creepymasterlurker</font...
# 2192  <font color="#0066CC">meandmy_fandoms</font>  ...
# 2193  <font color="#0066CC">ameliajclark</font>   HE...
# 2194  <font color="#0066CC">loveinto_thelight</font>...
# 2195  <font color="#0066CC">neenoali</font>   I just...
# 2196  <font color="#0066CC">simon_5418</font>   Had ...
# 2197  <font color="#0066CC">siscoflores</font>   Tha...
# 2198  <font color="#0066CC">rodrigo_the_creator</fon...
# 2199  <font color="#0066CC">msindell</font>   <font ...
# 2200  <font color="#0066CC">mallory.lmao</font>   Ma...
# 2201  <font color="#0066CC">12hunnidblock</font>   F...
# 2202  <font color="#0066CC">fuenciado_._</font>   Cr...
# 2203  <font color="#0066CC">_leonalitii</font>   Eli...
# 2204  <font color="#0066CC">erinlorraine</font>   <f...
# 2205  <font color="#0066CC">proffessor_horse</font> ...
# 2206  <font color="#0066CC">mattington21</font>   Su...
# 2207  <font color="#0066CC">madilynsophia</font>   <...
# 2208  <font color="#0066CC">enlighten_the_spirit</fo...
# 2209  <font color="#0066CC">mandog423</font>   He be...
# 2210  <font color="#0066CC">melobee_</font>   Who ca...
# 2211  <font color="#0066CC">mike5832</font>   That n...
# 2212  <font color="#0066CC">leephil447</font>   Beau...
# 2213  <font color="#0066CC">timtrew</font>   Stick t...
# 2214  <font color="#0066CC">demondresavagepullen</fo...
# 2215  <font color="#0066CC">hebrew_king21</font>   O...
# 2216  <font color="#0066CC">katie_graf</font>   And ...
# 2217  <font color="#0066CC">chanchi_16</font>   Fatn...
#
#                                                 clmn100  \
# 0                                                empety
# 1                                                empety
# 2     <font color="#0066CC">oopshiharry</font>   Can...
# 3                                                empety
# 4     <font color="#0066CC">buddhaplaysbass</font>  ...
# 5                                                empety
# 6     <font color="#0066CC">sndraibnz</font>   wtf_...
# 7                                                empety
# 8     <font color="#0066CC">l0lelena</font>   Ahhaha...
# 9                                                empety
# 10    <font color="#0066CC">dozi_r</font>   <font co...
# 11                                               empety
# 12    <font color="#0066CC">marriiaaa__</font>   I k...
# 13                                               empety
# 14    <font color="#0066CC">liljswim</font>   Love t...
# 15    <font color="#0066CC">chozzy.wozzy</font>   _...
# 16    <font color="#0066CC">jadea513</font>   Loved ...
# 17                                               empety
# 18    <font color="#0066CC">cottcncandyheart</font> ...
# 19                                               empety
# 20    <font color="#0066CC">jenniebug</font>   <font...
# 21                                               empety
# 22                                               empety
# 23                                               empety
# 24    <font color="#0066CC">curly_q_kiana</font>   W...
# 25                                               empety
# 26    <font color="#0066CC">carod31888</font>   <fon...
# 27                                               empety
# 28                                               empety
# 29    <font color="#0066CC">maximus_gardette85</font...
# ...                                                 ...
# 2188                                             empety
# 2189                                             empety
# 2190                                             empety
# 2191                                             empety
# 2192  <font color="#0066CC">damaskgrinnell</font>   ...
# 2193                                             empety
# 2194                                             empety
# 2195  <font color="#0066CC">tru_scorpio_king</font> ...
# 2196  <font color="#0066CC">wild_hogs_5</font>   I w...
# 2197                                             empety
# 2198  <font color="#0066CC">mauricioxsoto</font>   F...
# 2199                                             empety
# 2200  <font color="#0066CC">sarah_clubb</font>   <fo...
# 2201  <font color="#0066CC">selfmade_cardi</font>   ...
# 2202                                             empety
# 2203  <font color="#0066CC">tydale_yrn</font>   Elit...
# 2204                                             empety
# 2205                                             empety
# 2206                                             empety
# 2207  <font color="#0066CC">misskriss62</font>   <fo...
# 2208                                             empety
# 2209                                             empety
# 2210  <font color="#0066CC">mrcbd</font>   _____...
# 2211                                             empety
# 2212                                             empety
# 2213                                             empety
# 2214                                             empety
# 2215                                             empety
# 2216  <font color="#0066CC">_1989hox</font>   I just...
# 2217  <font color="#0066CC">eman_m10</font>   ....yo...
#
#                                                 clmn101  \
# 0                                                empety
# 1                                                empety
# 2     <font color="#0066CC">nuriaat</font>   <font c...
# 3                                                empety
# 4     <font color="#0066CC">tjbyerly</font>   <font ...
# 5                                                empety
# 6     <font color="#0066CC">ileanakock</font>   Gwn ...
# 7                                                empety
# 8     <font color="#0066CC">mueller_mira</font>   Ha...
# 9                                                empety
# 10    <font color="#0066CC">jakecardinalee</font>   ...
# 11                                               empety
# 12    <font color="#0066CC">emmaaacaniff</font>   <f...
# 13                                               empety
# 14    <font color="#0066CC">dwpyy</font>   this is m...
# 15    <font color="#0066CC">erzzamaloku</font>   How...
# 16    <font color="#0066CC">kellikole</font>   Love ...
# 17                                               empety
# 18    <font color="#0066CC">hes_clueing_for_looks</f...
# 19                                               empety
# 20    <font color="#0066CC">anat_blitz</font>   <fon...
# 21                                               empety
# 22                                               empety
# 23                                               empety
# 24    <font color="#0066CC">huda_187</font>   U foun...
# 25                                               empety
# 26    <font color="#0066CC">mehlene</font>   And thi...
# 27                                               empety
# 28                                               empety
# 29    <font color="#0066CC">rowank01</font>   ROMNEY...
# ...                                                 ...
# 2188                                             empety
# 2189                                             empety
# 2190                                             empety
# 2191                                             empety
# 2192  <font color="#0066CC">sadieileen</font>   <fon...
# 2193                                             empety
# 2194                                             empety
# 2195  <font color="#0066CC">jake.day</font>   <font ...
# 2196  <font color="#0066CC">r_mack10</font>   I had ...
# 2197                                             empety
# 2198  <font color="#0066CC">the_real_anthony100</fon...
# 2199                                             empety
# 2200  <font color="#0066CC">wendyfiliti</font>   <fo...
# 2201  <font color="#0066CC">bigningez</font>   Smack...
# 2202                                             empety
# 2203  <font color="#0066CC">carsonb1230</font>   Ran...
# 2204                                             empety
# 2205                                             empety
# 2206                                             empety
# 2207  <font color="#0066CC">rukiyeakm</font>   this ...
# 2208                                             empety
# 2209                                             empety
# 2210  <font color="#0066CC">dritowel</font>   Keep d...
# 2211                                             empety
# 2212                                             empety
# 2213                                             empety
# 2214                                             empety
# 2215                                             empety
# 2216  <font color="#0066CC">_1989hox</font>   And ge...
# 2217  <font color="#0066CC">eyee_van</font>   <font ...
#
#                                                 clmn102     ...      \
# 0                                                empety     ...
# 1                                                empety     ...
# 2     <font color="#0066CC">agusjalo</font>   This i...     ...
# 3                                                empety     ...
# 4     <font color="#0066CC">fivefour</font>   <font ...     ...
# 5                                                empety     ...
# 6     <font color="#0066CC">olivias_01</font>   <fon...     ...
# 7                                                empety     ...
# 8     <font color="#0066CC">casu259</font>   Hi  (cr...     ...
# 9                                                empety     ...
# 10    <font color="#0066CC">rasyaadikoro</font>   Hh...     ...
# 11                                               empety     ...
# 12    <font color="#0066CC">breanna_marie_1</font>  ...     ...
# 13                                               empety     ...
# 14    <font color="#0066CC">lucianacunha82</font>   ...     ...
# 15    <font color="#0066CC">bleonebrestovci</font>  ...     ...
# 16    <font color="#0066CC">lovemyboys40</font>   Lo...     ...
# 17                                               empety     ...
# 18    <font color="#0066CC">confessionsbyyou</font> ...     ...
# 19                                               empety     ...
# 20    <font color="#0066CC">thelibertinee</font>   O...     ...
# 21                                               empety     ...
# 22                                               empety     ...
# 23                                               empety     ...
# 24    <font color="#0066CC">owen002</font>   BURN  (...     ...
# 25                                               empety     ...
# 26    <font color="#0066CC">ayyyzma</font>   Love lo...     ...
# 27                                               empety     ...
# 28                                               empety     ...
# 29    <font color="#0066CC">_nicolala</font>   Obama...     ...
# ...                                                 ...     ...
# 2188                                             empety     ...
# 2189                                             empety     ...
# 2190                                             empety     ...
# 2191                                             empety     ...
# 2192  <font color="#0066CC">sleepy.little.kitty</fon...     ...
# 2193                                             empety     ...
# 2194                                             empety     ...
# 2195  <font color="#0066CC">zaylo704</font>   Jon co...     ...
# 2196  <font color="#0066CC">luckygoal4</font>   I ha...     ...
# 2197                                             empety     ...
# 2198  <font color="#0066CC">the_real_anthony100</fon...     ...
# 2199                                             empety     ...
# 2200  <font color="#0066CC">giorgiacaruana</font>   ...     ...
# 2201  <font color="#0066CC">anazfinest</font>   All ...     ...
# 2202                                             empety     ...
# 2203  <font color="#0066CC">aidan_northup17</font>  ...     ...
# 2204                                             empety     ...
# 2205                                             empety     ...
# 2206                                             empety     ...
# 2207  <font color="#0066CC">nasser__alothman</font> ...     ...
# 2208                                             empety     ...
# 2209                                             empety     ...
# 2210  <font color="#0066CC">donchristo310</font>   T...     ...
# 2211                                             empety     ...
# 2212                                             empety     ...
# 2213                                             empety     ...
# 2214                                             empety     ...
# 2215                                             empety     ...
# 2216  <font color="#0066CC">_1989hox</font>   These ...     ...
# 2217  <font color="#0066CC">bryanvega_</font>   <fon...     ...
#
#                                                 img_url             likes  \
# 0     https://scontent.cdninstagram.com/hphotos-xaf1...    4313\r\r likes
# 1     https://scontent.cdninstagram.com/hphotos-xap1...    2102\r\r likes
# 2     https://scontent.cdninstagram.com/hphotos-xap1...  108939\r\r likes
# 3     https://scontent.cdninstagram.com/hphotos-xaf1...    6441\r\r likes
# 4     https://scontent.cdninstagram.com/hphotos-xap1...    1153\r\r likes
# 5     https://scontent.cdninstagram.com/hphotos-xfa1...    4381\r\r likes
# 6     https://scontent.cdninstagram.com/hphotos-xaf1...    8199\r\r likes
# 7     https://scontent.cdninstagram.com/hphotos-xap1...    3366\r\r likes
# 8     https://scontent.cdninstagram.com/hphotos-xpf1...   86443\r\r likes
# 9     https://scontent.cdninstagram.com/hphotos-xpa1...      61\r\r likes
# 10    https://scontent.cdninstagram.com/hphotos-xfp1...   46290\r\r likes
# 11    https://scontent.cdninstagram.com/hphotos-xfa1...     964\r\r likes
# 12    https://scontent.cdninstagram.com/hphotos-xpa1...  197284\r\r likes
# 13    https://scontent.cdninstagram.com/hphotos-xaf1...    2236\r\r likes
# 14    https://scontent.cdninstagram.com/hphotos-xpf1...    3195\r\r likes
# 15    https://scontent.cdninstagram.com/hphotos-xfp1...   14528\r\r likes
# 16    https://scontent.cdninstagram.com/hphotos-xfp1...   28972\r\r likes
# 17    https://scontent.cdninstagram.com/hphotos-xap1...    1244\r\r likes
# 18    https://scontent.cdninstagram.com/hphotos-xaf1...   10524\r\r likes
# 19    https://scontent.cdninstagram.com/hphotos-xfp1...    7866\r\r likes
# 20    https://scontent.cdninstagram.com/hphotos-xap1...    8916\r\r likes
# 21    https://scontent.cdninstagram.com/hphotos-xpa1...     529\r\r likes
# 22    https://scontent.cdninstagram.com/hphotos-xfp1...      85\r\r likes
# 23    https://scontent.cdninstagram.com/hphotos-xpa1...    6868\r\r likes
# 24    https://scontent.cdninstagram.com/hphotos-xpa1...   23406\r\r likes
# 25    https://scontent.cdninstagram.com/hphotos-xpa1...    1140\r\r likes
# 26    https://scontent.cdninstagram.com/hphotos-xpf1...   15713\r\r likes
# 27    https://scontent.cdninstagram.com/hphotos-xpa1...     807\r\r likes
# 28    https://scontent.cdninstagram.com/hphotos-xap1...    2135\r\r likes
# 29    https://scontent.cdninstagram.com/hphotos-xpa1...    8362\r\r likes
# ...                                                 ...               ...
# 2188  http://scontent-a.cdninstagram.com/hphotos-xfp...         630 likes
# 2189  http://scontent-a.cdninstagram.com/hphotos-xpf...          40 likes
# 2190  http://scontent-a.cdninstagram.com/hphotos-xap...          34 likes
# 2191  http://scontent-b.cdninstagram.com/hphotos-xpf...         503 likes
# 2192  http://scontent-a.cdninstagram.com/hphotos-xfp...        1816 likes
# 2193  http://scontent-a.cdninstagram.com/hphotos-xpa...         695 likes
# 2194  http://scontent-b.cdninstagram.com/hphotos-xfp...         147 likes
# 2195  http://scontent-a.cdninstagram.com/hphotos-xpf...        7331 likes
# 2196  http://scontent-b.cdninstagram.com/hphotos-xpa...         486 likes
# 2197  http://scontent-a.cdninstagram.com/hphotos-xpf...         127 likes
# 2198  http://scontent-a.cdninstagram.com/hphotos-xpf...       22892 likes
# 2199  http://scontent-b.cdninstagram.com/hphotos-xpf...        4425 likes
# 2200  http://scontent-a.cdninstagram.com/hphotos-xpf...        4245 likes
# 2201  http://scontent-a.cdninstagram.com/hphotos-xap...        2751 likes
# 2202  http://scontent-a.cdninstagram.com/hphotos-xpf...         101 likes
# 2203  http://scontent-a.cdninstagram.com/hphotos-xpf...         697 likes
# 2204  http://scontent-a.cdninstagram.com/hphotos-xap...         312 likes
# 2205  http://scontent-b.cdninstagram.com/hphotos-xfa...         510 likes
# 2206  http://scontent-b.cdninstagram.com/hphotos-xfa...        1258 likes
# 2207  http://scontent-b.cdninstagram.com/hphotos-xap...        7520 likes
# 2208  http://scontent-b.cdninstagram.com/hphotos-xpa...         232 likes
# 2209  http://scontent-a.cdninstagram.com/hphotos-xpa...        3075 likes
# 2210  http://scontent-b.cdninstagram.com/hphotos-xfp...        2314 likes
# 2211  http://scontent-a.cdninstagram.com/hphotos-xpa...        2757 likes
# 2212  http://scontent-a.cdninstagram.com/hphotos-xpf...         294 likes
# 2213  http://scontent-b.cdninstagram.com/hphotos-xap...         442 likes
# 2214  http://scontent-b.cdninstagram.com/hphotos-xaf...         196 likes
# 2215  http://scontent-a.cdninstagram.com/hphotos-xpf...          50 likes
# 2216  http://scontent-b.cdninstagram.com/hphotos-xpf...         454 likes
# 2217  http://scontent-a.cdninstagram.com/hphotos-xpa...       37734 likes
#
#                                              owner_cmnt  \
# 0     gosh we love these five idiots so much __ for...
# 1     Anyone see the Pepsi halftime show commercial ...
# 2     Today I ate cr_pes and bought a drawing of ch...
# 3     New works in progress for an upcoming show at ...
# 4     Due to overwhelming response, we have went ahe...
# 5                      Loving the leather-denim combo."
# 6                                  OMFG I'M DYING _Û_"
# 7                      Yay or nay? tag your friends_ä
# 8      Afternoon in Campo Bahia with the team _Û__"
# 9     i leave you with one of my favorite harry vide...
# 10      Wishing you a happy birthday, dear @erickoston.
# 11                                     Brick by brick."
# 12                  Ridin' dirty with @hayes_instagram"
# 13                                                __"
# 14                         Pink stripes or pink shoes?"
# 15    New snapback from @larepublicclothing _´ Lov...
# 16    Charlie looking very pleased with his "#MerylS...
# 17    Doing kissy face with my baby @drodd36 #BodyEn...
# 18                                 when doge sees cate"
# 19     Cole & I up at 6 am. JK. He's still asleep __"
# 20                                                _±"
# 21                         Completely normal kids demo"
# 22    Emily missed this picture ): but with the love...
# 23                                      #doge4president
# 24                 Buuurn_î!!! @NailsCamera _Ñ___"
# 25    #repost big S/O to the awesome @Vladogirl , th...
# 26                    'Ciao Milano' by Hayden Williams"
# 27    Tune into @mtv Tuesday Jan 7th - 10pm EST, to ...
# 28    Dinner last night at @Herringbonemondrian w/ m...
# 29    Today is Election Day! #WeWill #GoVote @rockth...
# ...                                                 ...
# 2188   S/O and thank you to my boy <font color="#006...
# 2189   Maan this guy is messed up f*ckin racist bitc...
# 2190   A Third World War,the perfect set up to bring...
# 2191                                     true or false?
# 2192   Tell me what pisses you off and rant about it...
# 2193                                          HELL YEAH
# 2194   What's your favorite music video from the War...
# 2195   DAAAAAMN! <font color="#0066CC">@jarrenbenton...
# 2196                                        Go! Comment
# 2197   Fuck what y'all niggas talking bout we really...
# 2198               X games. Everybody say Fuck Anthony.
# 2199   Our dude <font color="#0066CC">@bjenner</font...
# 2200   YOU CAN NEVER TAKE HARRY SERIOUSLY WHEN HE SA...
# 2201   They asked where the mustard bottle was my so...
# 2202                    Sorry but I just had to do this
# 2203   It's time for <font color="#0066CC">#WhatFigu...
# 2204                                          Fan mail.
# 2205   The Collar-Bomb Murder of Ana Elvia in Colomb...
# 2206                     New music video up, LINK in bi
# 2207   No matter what you believe in, hunting/no hun...
# 2208   Is the root of the problem the gun? Or the fi...
# 2209   Eric Fisher gets ready for his headshot | <fo...
# 2210                                     Shit cray !!!!
# 2211   Camp life.. <font color="#0066CC">#MikeVickWe...
# 2212   Signed over 300 pics at today's signing ! Fou...
# 2213   Skills! <font color="#0066CC">#sundayfunday</...
# 2214   Lol <font color="#0066CC">#tupacamarushakur#t...
# 2215   Who cares right? There both just books? ___...
# 2216                 Media posted at 014-06-21 20:57:44
# 2217   Next Stop: Knockout Round! <font color="#0066...
#
#                                                owner_id   question1  \
# 0              <font color="#0066CC">maliksbby</font>       noneAgg
# 1           <font color="#0066CC">witneycarson</font>       noneAgg
# 2            <font color="#0066CC">namelessgem</font>       noneAgg
# 3                   <font color="#0066CC">kaws</font>    aggression
# 4               <font color="#0066CC">fivefour</font>       noneAgg
# 5         <font color="#0066CC">adidasneolabel</font>       noneAgg
# 6               <font color="#0066CC">sextpert</font>       noneAgg
# 7          <font color="#0066CC">avanityaffair</font>       noneAgg
# 8             <font color="#0066CC">gotzemario</font>       noneAgg
# 9            <font color="#0066CC">kingstyless</font>       noneAgg
# 10                <font color="#0066CC">nikesb</font>       noneAgg
# 11         <font color="#0066CC">dennistodisco</font>       noneAgg
# 12          <font color="#0066CC">jackgilinsky</font>       noneAgg
# 13               <font color="#0066CC">loekenz</font>       noneAgg
# 14        <font color="#0066CC">adidasneolabel</font>       noneAgg
# 15        <font color="#0066CC">itsjonasfossum</font>       noneAgg
# 16           <font color="#0066CC">meryledavis</font>       noneAgg
# 17         <font color="#0066CC">carlafacciolo</font>       noneAgg
# 18             <font color="#0066CC">doge.post</font>       noneAgg
# 19           <font color="#0066CC">skyferreira</font>       noneAgg
# 20          <font color="#0066CC">insta_kitten</font>       noneAgg
# 21     <font color="#0066CC">jordanroriepayton</font>       noneAgg
# 22         <font color="#0066CC">hayleyamelia_</font>       noneAgg
# 23             <font color="#0066CC">doge.post</font>       noneAgg
# 24            <font color="#0066CC">bestttextt</font>       noneAgg
# 25         <font color="#0066CC">vladofootwear</font>       noneAgg
# 26       <font color="#0066CC">hayden_williams</font>       noneAgg
# 27           <font color="#0066CC">missfamenyc</font>       noneAgg
# 28               <font color="#0066CC">klarity</font>       noneAgg
# 29        <font color="#0066CC">bridgitmendler</font>    aggression
# ...                                                 ...         ...
# 2188        <font color="#0066CC">paulwallbaby</font>    aggression
# 2189    <font color="#0066CC">makavellijackson</font>    aggression
# 2190          <font color="#0066CC">childofyah</font>       noneAgg
# 2191       <font color="#0066CC">nesserfamilia</font>       noneAgg
# 2192           <font color="#0066CC">jerkstiel</font>    aggression
# 2193     <font color="#0066CC">andthatismyfact</font>       noneAgg
# 2194          <font color="#0066CC">keshatoday</font>       noneAgg
# 2195           <font color="#0066CC">hopsinson</font>    aggression
# 2196    <font color="#0066CC">patriotsfootball</font>       noneAgg
# 2197          <font color="#0066CC">ice_marrow</font>    aggression
# 2198      <font color="#0066CC">larryfisherman</font>    aggression
# 2199        <font color="#0066CC">thehoonigans</font>    aggression
# 2200         <font color="#0066CC">haroldluvme</font>       noneAgg
# 2201           <font color="#0066CC">djmustard</font>    aggression
# 2202        <font color="#0066CC">andybvb_fanp</font>       noneAgg
# 2203           <font color="#0066CC">ringsidec</font>       noneAgg
# 2204          <font color="#0066CC">jeffdauler</font>    aggression
# 2205        <font color="#0066CC">notexplained</font>       noneAgg
# 2206           <font color="#0066CC">joeysalad</font>    aggression
# 2207       <font color="#0066CC">sophiamiacova</font>    aggression
# 2208  <font color="#0066CC">enlighten_the_spirit</fo...     noneAgg
# 2209            <font color="#0066CC">kcchiefs</font>    aggression
# 2210           <font color="#0066CC">djmustard</font>    aggression
# 2211            <font color="#0066CC">mikevick</font>    aggression
# 2212             <font color="#0066CC">rebysky</font>    aggression
# 2213          <font color="#0066CC">shawnsuggs</font>    aggression
# 2214  <font color="#0066CC">tupac_amaru_shakur1996</...     noneAgg
# 2215          <font color="#0066CC">childofyah</font>    aggression
# 2216             <font color="#0066CC">cutting</font>    aggression
# 2217        <font color="#0066CC">soccerdotcom</font>    aggression
#
#      question1:confidence question2 question2:confidence shared media  \
# 0                  0.8124   noneBll               1.0000         1477
# 1                  1.0000   noneBll               1.0000          761
# 2                  0.8056   noneBll               0.8056          698
# 3                  0.5982  bullying               0.5982         1257
# 4                  1.0000   noneBll               1.0000         2052
# 5                  1.0000   noneBll               1.0000         1520
# 6                  1.0000   noneBll               1.0000         2158
# 7                  0.5980   noneBll               1.0000         2616
# 8                  0.7965   noneBll               0.7965          507
# 9                  1.0000   noneBll               1.0000          377
# 10                 1.0000   noneBll               1.0000         1019
# 11                 0.8056   noneBll               0.8056          658
# 12                 0.7965   noneBll               1.0000          325
# 13                 0.6091   noneBll               0.6091         1451
# 14                 0.7926   noneBll               0.7926         1520
# 15                 1.0000   noneBll               1.0000          536
# 16                 1.0000   noneBll               1.0000          695
# 17                 0.7965   noneBll               1.0000         1208
# 18                 1.0000   noneBll               1.0000          277
# 19                 0.8035   noneBll               0.8035         2179
# 20                 0.7926   noneBll               0.7926          984
# 21                 0.5982   noneBll               0.5982         1087
# 22                 1.0000   noneBll               1.0000          239
# 23                 0.7965   noneBll               0.7965          277
# 24                 0.5982   noneBll               0.5982          627
# 25                 0.8035   noneBll               0.8035         1639
# 26                 1.0000   noneBll               1.0000         1567
# 27                 1.0000   noneBll               1.0000         1005
# 28                 0.8078   noneBll               1.0000          858
# 29                 0.7969  bullying               0.6093          765
# ...                   ...       ...                  ...          ...
# 2188               1.0000  bullying               0.6117         1884
# 2189               1.0000  bullying               1.0000          644
# 2190               1.0000   noneBll               1.0000         1905
# 2191               1.0000   noneBll               1.0000          640
# 2192               0.8051   noneBll               0.5888         2514
# 2193               0.8055   noneBll               0.8055          462
# 2194               1.0000   noneBll               1.0000          277
# 2195               0.6245  bullying               0.6245         1247
# 2196               1.0000   noneBll               1.0000         1147
# 2197               1.0000  bullying               1.0000         1187
# 2198               1.0000  bullying               0.8018         1556
# 2199               1.0000  bullying               0.8081         1959
# 2200               0.5995   noneBll               0.8022         1847
# 2201               1.0000  bullying               1.0000         1949
# 2202               1.0000   noneBll               1.0000         3351
# 2203               1.0000   noneBll               1.0000         1521
# 2204               0.7965   noneBll               0.6024         1676
# 2205               0.7997   noneBll               0.7997          498
# 2206               1.0000  bullying               1.0000          780
# 2207               1.0000  bullying               0.7995          407
# 2208               1.0000   noneBll               1.0000         2727
# 2209               0.7908  bullying               0.7908         1280
# 2210               1.0000  bullying               0.5886         1949
# 2211               0.7867  bullying               0.7867          323
# 2212               0.6017  bullying               0.6017         1266
# 2213               0.7879   noneBll               0.7963         1607
# 2214               1.0000   noneBll               1.0000         2204
# 2215               0.6090   noneBll               0.5868         1905
# 2216               0.5954   noneBll               0.5975          319
# 2217               1.0000  bullying               1.0000         2009
#
#            label
# 0         normal
# 1         normal
# 2         normal
# 3       bullying
# 4         normal
# 5         normal
# 6         normal
# 7         normal
# 8         normal
# 9         normal
# 10        normal
# 11        normal
# 12        normal
# 13        normal
# 14        normal
# 15        normal
# 16        normal
# 17        normal
# 18        normal
# 19        normal
# 20        normal
# 21        normal
# 22        normal
# 23        normal
# 24        normal
# 25        normal
# 26        normal
# 27        normal
# 28        normal
# 29      bullying
# ...          ...
# 2188    bullying
# 2189    bullying
# 2190      normal
# 2191      normal
# 2192  aggression
# 2193      normal
# 2194      normal
# 2195    bullying
# 2196      normal
# 2197    bullying
# 2198    bullying
# 2199    bullying
# 2200      normal
# 2201    bullying
# 2202      normal
# 2203      normal
# 2204  aggression
# 2205      normal
# 2206    bullying
# 2207    bullying
# 2208      normal
# 2209    bullying
# 2210    bullying
# 2211    bullying
# 2212    bullying
# 2213  aggression
# 2214      normal
# 2215  aggression
# 2216  aggression
# 2217    bullying
#
# [2218 rows x 216 columns]

# %%
labbeled_data_formatted = dict()

# %%
def extract_to_dict(row):
    comments = [row[f'clmn{i}'] for i in range(1,196)]
    comments = [clean_comment(i) for i in comments if i != 'empety']
    username  = row['owner_id'].replace("</font>","").replace('<font color="#0066CC">','').strip()
    unit_id = row['_unit_id']
    
    global labbeled_data_formatted
    
    if username not in labbeled_data_formatted.keys():
        labbeled_data_formatted[username] = {}
        
    for comment in comments:
        labbeled_data_formatted[username][comment] = unit_id

# %%
df_copy.apply (lambda row: extract_to_dict(row),axis=1)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14      None
# 15      None
# 16      None
# 17      None
# 18      None
# 19      None
# 20      None
# 21      None
# 22      None
# 23      None
# 24      None
# 25      None
# 26      None
# 27      None
# 28      None
# 29      None
#         ...
# 2188    None
# 2189    None
# 2190    None
# 2191    None
# 2192    None
# 2193    None
# 2194    None
# 2195    None
# 2196    None
# 2197    None
# 2198    None
# 2199    None
# 2200    None
# 2201    None
# 2202    None
# 2203    None
# 2204    None
# 2205    None
# 2206    None
# 2207    None
# 2208    None
# 2209    None
# 2210    None
# 2211    None
# 2212    None
# 2213    None
# 2214    None
# 2215    None
# 2216    None
# 2217    None
# Length: 2218, dtype: object

# %%
with open(f'data/method_2/label_data_extract.json','w') as fp:
            json.dump(labbeled_data_formatted, fp,indent=4)

# %% [markdown]
# matching now

# %%
with open(f'data/method_2/media_id_file_map.json','r') as fp:
           media_id_file=json.load(fp)
        
with open(f'data/method_2/label_data_extract.json','r') as fp:
           labbeled_data_formatted=json.load(fp)

# %%
len(all_ids_folder)
# Out:
# 2263

# %%
media_id_unit_id_map = {}

# %%
for media_id in tqdm(all_ids_folder):
    try:
        files_to_read = media_id_file[media_id]
    except:
        continue
    unit_ids = []
    for file in files_to_read:
        with open(f'data/method_2/dump_jsons/{file}.json','r') as fp:
            all_id_blocks = json.load(fp)
            
        id_block = all_id_blocks[media_id]
        username = id_block['username']
        comments_data_dump = [i.encode('ascii', 'ignore').strip().decode("utf-8") for i in id_block['comments']]
        
        
        #TODO: figure out the unicode character thing. 
        if username in labbeled_data_formatted.keys():
                user_block = labbeled_data_formatted[username]
        
#         for i,j in zip(comments_data_dump, user_block.keys()):
#             print(f'{i} $$$$$$$$$$$ {j}')
        for comment in comments_data_dump:
            try:
                unit_ids.append(user_block[comment])
            except:
                continue
    
    if unit_ids!=[]:
        media_id_unit_id_map[media_id] = max(set(unit_ids), key = unit_ids.count)
#     assert False
# Out:
# HBox(children=(IntProgress(value=0, max=2263), HTML(value='')))

# %%
with open(f'data/method_2/media_id_unit_id.json','w') as fp:
            json.dump(media_id_unit_id_map, fp,indent=4)

# %%
len(media_id_unit_id_map.keys())
# Out:
# 1252

# %%
with open(f'data/method_2/media_id_unit_id.json','r') as fp:
           media_id_unit_id_map=json.load(fp)

# %%
ids_found = list(media_id_unit_id_map.keys())

# %%
len(ids_found),len(ids_present_in_data_dump)
# Out:
# (1252, 1630)

# %%
still_not_found = set(ids_present_in_data_dump)-set(ids_found)

# %%
len(still_not_found)
# Out:
# 378

# %%
still_not_found
# Out:
# {'139318261840550022_22113781',
#  '145987663735565198_18535777',
#  '147869160522252676_10427687',
#  '154301341416985166_3810419',
#  '155667610695957758_2811086',
#  '156597748082641148_11846505',
#  '158692097365427009_26167095',
#  '173786259875513115_1063663',
#  '175358595089088066_9191582',
#  '175617245772428989_3378244',
#  '182225247_7604835',
#  '189370206914221306_9677692',
#  '196084223967956949_13512754',
#  '198203765600174128_6723983',
#  '199186186928198702_29875324',
#  '209231380450191288_46601608',
#  '211969982805315239_181272562',
#  '213016772030326750_31266112',
#  '213020516447657212_6118814',
#  '216124804486068348_14240701',
#  '217887011659083324_23241818',
#  '220877542877898323_46601608',
#  '222646849740557469_53837386',
#  '224570728466369795_29143090',
#  '227010215019449612_6341954',
#  '227010371729945725_177844796',
#  '227174937703856464_6928437',
#  '229040258057554399_16554657',
#  '234829957546799401_145598227',
#  '235720109500693641_25573358',
#  '241496085814370665_45086847',
#  '245144349909986537_49731290',
#  '246539819990656329_22265520',
#  '248004416718034154_1843380',
#  '252044355146373875_8262325',
#  '254181692067666041_44071653',
#  '255184981129273646_19563687',
#  '255201749_3778225',
#  '259290695303586707_22162199',
#  '264007575792794422_54237317',
#  '264981307_2560145',
#  '265979195923393950_185332586',
#  '266134079993368671_38112131',
#  '268294097683218560_4348967',
#  '269761931236915774_6174909',
#  '270391279553171606_38112131',
#  '272356384588029577_177877934',
#  '275676297810752379_75',
#  '282740438485322761_15580914',
#  '286570860920964262_182137816',
#  '289431973365941836_8151920',
#  '291994398627639767_7001707',
#  '306707863363998033_38112131',
#  '308098571233493214_230707911',
#  '308838658_4080110',
#  '309332316986955841_20045917',
#  '311953100_10575454',
#  '317425814361495566_20045917',
#  '318271425912823062_13343126',
#  '318363812033726244_210746792',
#  '318839824242443883_11858584',
#  '323652047258661271_4182955',
#  '324861590745622040_23376000',
#  '327719506201509038_239231758',
#  '329267009209697854_198343264',
#  '331250232748343517_183858775',
#  '332713025400049335_8681890',
#  '333466982975982202_245816713',
#  '335521611050472015_38112131',
#  '335945963089971962_4808345',
#  '340564720636530235_6136154',
#  '342965899881712626_14585353',
#  '345588670_12996727',
#  '347266676602687481_29383826',
#  '349326732014817065_249044770',
#  '350166268716076955_53837386',
#  '356588753523633520_8142874',
#  '358057923061236512_12631295',
#  '361624297523604981_13570730',
#  '364079114872770727_201817131',
#  '369512571102738923_287541965',
#  '371310404912199430_3378244',
#  '371824734793193516_5130853',
#  '372082140899739321_242666568',
#  '375668899681667408_8208073',
#  '375777565357656158_4808345',
#  '376111048134921118_229652977',
#  '376253645721332251_194937713',
#  '381427914171225848_17296540',
#  '382047040125994667_198343264',
#  '382446925733061172_10164247',
#  '389532425_5314346',
#  '390530934107347950_19554421',
#  '390633934778622146_5243159',
#  '395194532369964471_174786446',
#  '397297474155685451_278928432',
#  '397895184194201351_13278832',
#  '400213969590118088_31266112',
#  '401402870771958204_9418023',
#  '401416810550979603_256554282',
#  '401724528522610214_1412480',
#  '403595848826573522_38112131',
#  '404438664007278262_234096430',
#  '405120861767914466_266689531',
#  '405263995046892144_3810419',
#  '405288371422678408_30489018',
#  '406468093860523313_176486418',
#  '407064968596759074_311038527',
#  '410356436975617253_259138712',
#  '416713353823157513_4879766',
#  '420608150851218355_601977',
#  '420618540829862569_4326753',
#  '426838771801832584_192976838',
#  '427978819104038811_234096430',
#  '431045402901619471_145625263',
#  '431793757122996458_18535777',
#  '432930328473064216_38112131',
#  '433580251672100396_49645654',
#  '434718421337943481_305017730',
#  '435709608117263529_24715886',
#  '437501579084991752_315885546',
#  '439707331279766499_274891071',
#  '440071888463556254_358470090',
#  '440351517529470577_28182428',
#  '442741881149218251_234096430',
#  '443840928818624015_145300220',
#  '445851376629431790_241041902',
#  '446915456445582493_6136154',
#  '448647910213765861_13080209',
#  '451126821284048460_340529698',
#  '451698142814070708_249317232',
#  '453605897738725610_55863913',
#  '458149423196988521_325313384',
#  '460910358540507162_17051717',
#  '462836278466664699_326352773',
#  '463464058_14810717',
#  '466364899178954210_194909462',
#  '468247439888473662_21395630',
#  '469663032856505922_7565730',
#  '469833193479954481_17980983',
#  '472470555429372327_362913263',
#  '472860089561703746_41199664',
#  '476046859689033251_25573358',
#  '478409374413477753_582164',
#  '478493192236798044_4678555',
#  '478625546360905432_226514406',
#  '479324379583162636_23323913',
#  '482118328427024717_25521603',
#  '482556026111551791_20861689',
#  '485307806920415992_3383525',
#  '485711926295683962_346185407',
#  '487079239512036204_271271347',
#  '487673434244796328_15580914',
#  '487867778648261968_3938088',
#  '488175873_3752388',
#  '488521435768668222_363832543',
#  '489130500860733381_284056848',
#  '489795166586683477_14416679',
#  '489943310379404404_199868986',
#  '490641590263418370_5948010',
#  '492648990220036824_750329',
#  '492669734_7296124',
#  '494392549562894058_24799848',
#  '494426308069328175_297091312',
#  '498493051136788880_2560145',
#  '499538795438250398_49392021',
#  '500829360775245650_208206546',
#  '502345711873380827_236957515',
#  '504744081127927120_23241818',
#  '505752835080437236_241041902',
#  '506897297802302727_297736828',
#  '507072000738427372_29145991',
#  '507474973781485902_298982393',
#  '508888642136208856_182439252',
#  '509337659060008275_375940012',
#  '509516776329423706_335643561',
#  '509634498572614846_25573358',
#  '509759783331914125_6869567',
#  '514662718799101749_320677574',
#  '514751301650689337_6215970',
#  '515723870857318510_50692291',
#  '516028900380352747_145125103',
#  '516307574992682962_186099622',
#  '519094181069424450_273046888',
#  '521378420988348348_330076056',
#  '529180042882188423_11858584',
#  '529648619231413556_330076056',
#  '529851309252772088_6299703',
#  '531055964386309745_478601612',
#  '531825895165452851_252788127',
#  '531879221522204827_43153969',
#  '532218825978966733_14024123',
#  '532489579447630325_1706197',
#  '532797105886967916_4874077',
#  '533831310599875763_340529698',
#  '534284565173734856_10427530',
#  '535782533024561519_4774717',
#  '537046486567757069_16048976',
#  '537166878276599023_186099622',
#  '537964766_2896306',
#  '540570555603615429_284634734',
#  '544766982974101710_27165533',
#  '545045336947140855_335643561',
#  '545792952187741809_204241016',
#  '546627794048128114_10156540',
#  '548613331935194991_8250666',
#  '549291339300114020_13422978',
#  '549513752504796269_215303936',
#  '552508856379107026_13278832',
#  '552580970084743254_256395685',
#  '555959551477525558_39609970',
#  '556461434886384495_295386753',
#  '556590961698114723_7188426',
#  '560263642365265663_397394064',
#  '560780151814930761_316280303',
#  '562128672803805538_27165533',
#  '563124322860909166_38595111',
#  '563788508561082024_21838776',
#  '564717698198667677_8000127',
#  '565169206_1561454',
#  '565864270296835188_605637104',
#  '568189071503886299_397394064',
#  '568309385488793428_26971310',
#  '569234578262889157_522508747',
#  '569694754796425431_13875723',
#  '569848029127257233_176486418',
#  '570218541371325515_145454574',
#  '570487221831555287_326352773',
#  '570743554296905819_26393455',
#  '571143932541997134_289184675',
#  '574869986932605357_32907479',
#  '574928131459421102_581820291',
#  '575032460237643145_13634646',
#  '575791079430188061_1364506',
#  '576304132655507407_224350344',
#  '576717289278886152_186499819',
#  '577485819778183907_12853339',
#  '579061100687285359_32768478',
#  '579175454342761353_278203697',
#  '579610853671398988_13570730',
#  '581468656894428219_144318536',
#  '581890819068735206_21202506',
#  '587341901418587044_11319215',
#  '587981683136413594_186099622',
#  '588682902235405708_234096430',
#  '589541807121322709_7858411',
#  '593718401579390539_422039132',
#  '594284244871689273_983084',
#  '595863597265408471_421656491',
#  '596003448422491300_11242136',
#  '596590486834428225_24142349',
#  '596672156910641566_296300407',
#  '597156003054092040_18100510',
#  '597606993419609362_183716064',
#  '597755669418075553_1697296',
#  '598821056138160923_15982281',
#  '600837577651989778_21202506',
#  '601549038777137459_300189733',
#  '603795040601398313_320853094',
#  '605196386819048760_198343264',
#  '605909277126812734_329279216',
#  '606108612377378122_534925958',
#  '607498988325667690_29145991',
#  '607973381442559275_6389534',
#  '610379278445793050_513775338',
#  '611015575183829896_29056033',
#  '612609939072000406_11734263',
#  '612755165757999452_292919769',
#  '613077672794813742_712762588',
#  '613280372978663881_510616839',
#  '616296639384685024_292919769',
#  '617238639007717410_10438285',
#  '618648919714990644_292919769',
#  '618929342412000866_3755546',
#  '622921525024545020_27165533',
#  '623630423_12853339',
#  '624769954331122760_258378990',
#  '625590336605539565_232174754',
#  '626107395175844164_193173297',
#  '626893602748533010_292919769',
#  '627138884334879970_273046888',
#  '628671727906801096_144318536',
#  '629891038409890505_49392021',
#  '629907548350049431_562508962',
#  '630401603478864592_395208183',
#  '633086126429848191_6496295',
#  '633642624948851544_552003',
#  '635567750043903421_23376000',
#  '636381065000252926_329287044',
#  '637029966366920733_391491299',
#  '638764681221150707_422039132',
#  '639493542418724603_271510396',
#  '640087986775274649_20083852',
#  '645843771442001440_186828260',
#  '646702541899841442_186099622',
#  '647269987521923841_11080257',
#  '647885618372871756_198343264',
#  '649454369_19829737',
#  '650379478431486618_174101843',
#  '652335760527176394_421275107',
#  '655180497389613805_581882811',
#  '657885394049178811_410928590',
#  '657967692851304986_436796397',
#  '658075720867593999_839671998',
#  '658146282098103407_17978300',
#  '658243894363348008_402786590',
#  '658811968840609843_10505331',
#  '658886431320341569_7167846',
#  '662502190139908178_388598399',
#  '666110778006018202_10176765',
#  '668167171320856033_320677574',
#  '668178754613052494_25427848',
#  '669720897232782604_144318536',
#  '669875103433580436_289705598',
#  '671400087676962165_1412480',
#  '672083155918071989_750329',
#  '673690932973236645_218159443',
#  '674877936776177891_785199793',
#  '675477913583493809_5854359',
#  '676712292250640414_341518927',
#  '678320226367414872_4806511',
#  '678574121136853108_16827211',
#  '679038346906502897_21838776',
#  '680480209411256288_14372314',
#  '682557802911071661_27468038',
#  '682711972256290234_1062358972',
#  '683656762542571628_6922351',
#  '684987401710196379_840300884',
#  '685092653402439662_186099622',
#  '688720202297054481_643685836',
#  '690325205823989949_390927249',
#  '690818255703143452_806590668',
#  '691209264074826997_185027280',
#  '693511128671154450_347833675',
#  '693726488589750788_9132803',
#  '694596396061618147_1043890314',
#  '695204510348513342_1164881187',
#  '696012226891692664_25008405',
#  '696587644966266585_1697296',
#  '698645309992205688_198906278',
#  '699338612689689663_10616366',
#  '701306453351183164_1051813051',
#  '701528160277696612_289184675',
#  '703243269622347530_271510396',
#  '704389871305029527_34775316',
#  '705115373229356101_409830044',
#  '705785209453479892_198343264',
#  '707663460032855705_186099622',
#  '709473457738880673_17296540',
#  '709474596754118688_185348157',
#  '709678578766238580_635601075',
#  '709822513978593926_233749403',
#  '710930409914897997_11955004',
#  '712256822511982540_365172868',
#  '714078191774226950_20045917',
#  '714969126470520150_450802402',
#  '716117954968903157_307413286',
#  '716705863151117500_204241016',
#  '716943196923341558_30919073',
#  '717129977492959187_12804122',
#  '718257449841861227_231176671',
#  '719008428690199023_421656491',
#  '724953457887362153_19831102',
#  '726635919503811884_469586048',
#  '727804581615328184_223271365',
#  '733268995550969504_23272014',
#  '735746375963930189_643816818',
#  '736620097102575343_1373163484',
#  '736758514743782108_18535777',
#  '737032625142951726_1043890314',
#  '737148703666795983_186828260',
#  '737719567891252213_16560207',
#  '739620930011033572_12804122',
#  '740548865143499431_3778225',
#  '742109393058706142_264269011',
#  '742314963597723263_198343264',
#  '742504982193523656_1656681',
#  '748014397361274797_9191582'}

# %%
val = list(media_id_unit_id_map.values())

# %%
len(val),len(set(val))
# Out:
# (1252, 873)

# %% [markdown]
# for some reason method 2 is also not working well...have spent too much time on this one..maybe lets just work on what i have for now

# %% [markdown]
# ## looking into the #juggad results

# %%
final_df = pd.read_pickle('data/final_csv_method_1.pkl')

# %%
final_df
# Out:
#       _golden _last_judgment_at  _trusted_judgments   _unit_id _unit_state  \
# 0       False      4/11/15 0:40                   5  702714440   finalized
# 1       False      4/11/15 0:37                   5  702714441   finalized
# 2       False      4/11/15 2:17                   5  702714442   finalized
# 3       False      4/11/15 2:09                   5  702714443   finalized
# 4       False     4/10/15 23:41                   5  702714444   finalized
# 5       False     4/10/15 23:44                   5  702714445   finalized
# 6       False      4/11/15 0:40                   5  702714446   finalized
# 7       False      4/11/15 0:37                   5  702714447   finalized
# 8       False     4/10/15 23:48                   5  702714448   finalized
# 9       False     4/10/15 23:47                   5  702714449   finalized
# 10      False      4/11/15 0:42                   5  702714450   finalized
# 11      False      4/11/15 2:10                   5  702714451   finalized
# 12      False     4/10/15 23:48                   5  702714452   finalized
# 13      False      4/11/15 2:09                   5  702714453   finalized
# 14      False      4/11/15 2:11                   5  702714454   finalized
# 15      False     4/10/15 23:45                   5  702714455   finalized
# 16      False     4/10/15 23:44                   5  702714456   finalized
# 17      False     4/10/15 23:41                   5  702714457   finalized
# 18      False      4/11/15 2:14                   5  702714458   finalized
# 19      False      4/11/15 2:10                   5  702714459   finalized
# 20      False      4/11/15 2:08                   5  702714460   finalized
# 21      False      4/11/15 2:07                   5  702714461   finalized
# 22      False     4/10/15 23:48                   5  702714462   finalized
# 23      False     4/10/15 23:44                   5  702714463   finalized
# 24      False      4/11/15 2:14                   5  702714464   finalized
# 25      False      4/11/15 2:17                   5  702714465   finalized
# 26      False     4/10/15 23:34                   5  702714466   finalized
# 27      False     4/10/15 23:35                   5  702714467   finalized
# 28      False     4/10/15 23:37                   5  702714468   finalized
# 29      False      4/11/15 0:42                   5  702714469   finalized
# ...       ...               ...                 ...        ...         ...
# 2188    False     1/22/15 20:50                   5  652910847   finalized
# 2189    False     1/20/15 16:33                   5  652910848   finalized
# 2190    False      1/24/15 4:20                   5  652910849   finalized
# 2191    False      1/22/15 0:49                   5  652910850   finalized
# 2192    False      1/21/15 6:16                   5  652910851   finalized
# 2193    False     1/23/15 11:39                   5  652910852   finalized
# 2194    False     1/23/15 11:47                   5  652910853   finalized
# 2195    False     1/27/15 14:30                   5  652910854   finalized
# 2196    False     1/22/15 21:19                   5  652910855   finalized
# 2197    False      1/26/15 0:03                   5  652910856   finalized
# 2198    False     1/20/15 17:43                   5  652910857   finalized
# 2199    False     1/24/15 18:21                   5  652910858   finalized
# 2200    False     1/23/15 11:50                   5  652910859   finalized
# 2201    False      1/22/15 1:59                   5  652910860   finalized
# 2202    False      1/26/15 0:08                   5  652910861   finalized
# 2203    False     1/27/15 14:21                   5  652910862   finalized
# 2204    False     1/20/15 12:48                   5  652910863   finalized
# 2205    False     1/21/15 17:24                   5  652910864   finalized
# 2206    False     1/23/15 11:44                   5  652910865   finalized
# 2207    False      1/27/15 2:47                   5  652910866   finalized
# 2208    False      1/22/15 0:50                   5  652910867   finalized
# 2209    False     1/21/15 20:58                   5  652910868   finalized
# 2210    False      1/26/15 0:06                   5  652910869   finalized
# 2211    False      1/22/15 0:49                   5  652910870   finalized
# 2212    False      1/25/15 2:27                   5  652910871   finalized
# 2213    False      1/20/15 8:27                   5  652910872   finalized
# 2214    False     1/24/15 17:35                   5  652910873   finalized
# 2215    False     1/21/15 17:33                   5  652910874   finalized
# 2216    False      1/25/15 2:40                   5  652910875   finalized
# 2217    False      1/21/15 0:40                   5  652910876   finalized
#
#                                                   clmn1  \
# 0     <font color="#0066CC">lynnseyerinalexandra</fo...
# 1     <font color="#0066CC">britterkritter</font>   ...
# 2     <font color="#0066CC">mariamagv</font>   where...
# 3     <font color="#0066CC">gladlychadly</font>   _...
# 4     <font color="#0066CC">fivefour</font>   <font ...
# 5     <font color="#0066CC">juliepailler</font>   _...
# 6     <font color="#0066CC">karisma_p</font>   <font...
# 7     <font color="#0066CC">samheartsu</font>   yay ...
# 8     <font color="#0066CC">_loloarcanjo_</font>   _...
# 9     <font color="#0066CC">harrycan_u_not</font>   ...
# 10    <font color="#0066CC">leixxak</font>   <font c...
# 11    <font color="#0066CC">eduarte1988</font>   1st...
# 12    <font color="#0066CC">trentleft</font>   <font...
# 13    <font color="#0066CC">cherrylnotman</font>   S...
# 14    <font color="#0066CC">jocelyn8642</font>   1st...
# 15    <font color="#0066CC">jamie_plowman</font>   S...
# 16    <font color="#0066CC">jovanna_maresca</font>  ...
# 17    <font color="#0066CC">mobelaisima</font>   Car...
# 18    <font color="#0066CC">bethsbunny</font>   BOOT...
# 19    <font color="#0066CC">urgrll</font>   GO SKY G...
# 20    <font color="#0066CC">mrs.kite</font>   <font ...
# 21    <font color="#0066CC">fabrizio_47</font>   Lol...
# 22    <font color="#0066CC">odahia</font>   You look...
# 23    <font color="#0066CC">emma.presnell</font>   H...
# 24    <font color="#0066CC">hi_my_name_is_jim</font>...
# 25    <font color="#0066CC">kishanjop</font>   I hav...
# 26    <font color="#0066CC">janesfashion19</font>   ...
# 27    <font color="#0066CC">tulip.sniper</font>   <f...
# 28    <font color="#0066CC">throwin_touchdowns_15</f...
# 29    <font color="#0066CC">allygirl0517</font>   Ob...
# ...                                                 ...
# 2188  <font color="#0066CC">texas_trill956</font>   ...
# 2189  <font color="#0066CC">moonwalkingrabbit</font>...
# 2190  <font color="#0066CC">tazawarya</font>   So yo...
# 2191  <font color="#0066CC">connorf1nn</font>   prob...
# 2192  <font color="#0066CC">charlotte_aaaa</font>   ...
# 2193  <font color="#0066CC">sarahgubbels_</font>   H...
# 2194  <font color="#0066CC">rose.kesha</font>   Edit...
# 2195  <font color="#0066CC">fuckhatred</font>   eeye...
# 2196  <font color="#0066CC">__aidanc__</font>   I ha...
# 2197  <font color="#0066CC">dat723</font>   I think ...
# 2198  <font color="#0066CC">yxngsnxxl</font>   Fuck ...
# 2199  <font color="#0066CC">jasdrift</font>   <font ...
# 2200  <font color="#0066CC">imaginesforharrygirls</f...
# 2201  <font color="#0066CC">lilbshadeymob88</font>  ...
# 2202  <font color="#0066CC">the_queen_of_all_selfies...
# 2203  <font color="#0066CC">wallywojo</font>   Justi...
# 2204  <font color="#0066CC">kelmichelle87</font>   H...
# 2205  <font color="#0066CC">medusssssssa</font>   <f...
# 2206  <font color="#0066CC">thackerdotcom</font>   Y...
# 2207  <font color="#0066CC">ellerosa</font>   :) <fo...
# 2208  <font color="#0066CC">enlighten_the_spirit</fo...
# 2209  <font color="#0066CC">reichert13</font>   MUG ...
# 2210  <font color="#0066CC">therealestb_80s</font>  ...
# 2211  <font color="#0066CC">clutchdigital</font>   1...
# 2212  <font color="#0066CC">kingsagundez29</font>   ...
# 2213  <font color="#0066CC">stateofkali</font>   you...
# 2214  <font color="#0066CC">_poquitobonita</font>   ...
# 2215  <font color="#0066CC">bodhi_sutra</font>   You...
# 2216  <font color="#0066CC">https.imvu</font>   I do...
# 2217  <font color="#0066CC">chanchi_16</font>   Haha...
#
#                                                  clmn10  \
# 0     <font color="#0066CC">niazki.lam</font>   larr...
# 1     <font color="#0066CC">kyleepickering</font>   ...
# 2     <font color="#0066CC">julianarosa67</font>   F...
# 3     <font color="#0066CC">crash_edisy</font>   <fo...
# 4     <font color="#0066CC">brohr285</font>   Still ...
# 5     <font color="#0066CC">shaunmichaelchapman</fon...
# 6     <font color="#0066CC">valex_33</font>   <font ...
# 7     <font color="#0066CC">tatum.sparks</font>   <f...
# 8     <font color="#0066CC">fcbayern_isibella</font>...
# 9     <font color="#0066CC">kingstyless</font>   <fo...
# 10    <font color="#0066CC">codizzle8</font>   Yo <f...
# 11    <font color="#0066CC">street_fly76</font>   Li...
# 12    <font color="#0066CC">chevy.b</font>   _Û_Û...
# 13    <font color="#0066CC">moabengtsson_</font>   G...
# 14    <font color="#0066CC">ikasalindo</font>   Pink...
# 15    <font color="#0066CC">rchiminoo</font>   ¥ÈÑ  ...
# 16    <font color="#0066CC">jlzrus</font>   Haha, th...
# 17    <font color="#0066CC">jojotanktop</font>   Who...
# 18    <font color="#0066CC">biscuit_slut</font>   Sw...
# 19    <font color="#0066CC">ponysauriohacerawr</font...
# 20    <font color="#0066CC">kerimae2</font>   <font ...
# 21    <font color="#0066CC">hockeyplyr39</font>   <f...
# 22    <font color="#0066CC">taylorstrupp</font>   ga...
# 23    <font color="#0066CC">j.ames</font>   stfu <fo...
# 24    <font color="#0066CC">juicydoo</font>   Hahaha...
# 25    <font color="#0066CC">grandyglaze1</font>   <f...
# 26    <font color="#0066CC">daycruvinel</font>   Bea...
# 27    <font color="#0066CC">alyssashakur</font>   yo...
# 28    <font color="#0066CC">jordanrisa</font>   __...
# 29    <font color="#0066CC">kori.91</font>   <font c...
# ...                                                 ...
# 2188  <font color="#0066CC">gnarfro</font>   <font c...
# 2189  <font color="#0066CC">prettyboii_creole</font>...
# 2190  <font color="#0066CC">hebrew_king21</font>   O...
# 2191  <font color="#0066CC">creepymasterlurker</font...
# 2192  <font color="#0066CC">meandmy_fandoms</font>  ...
# 2193  <font color="#0066CC">ameliajclark</font>   HE...
# 2194  <font color="#0066CC">loveinto_thelight</font>...
# 2195  <font color="#0066CC">neenoali</font>   I just...
# 2196  <font color="#0066CC">simon_5418</font>   Had ...
# 2197  <font color="#0066CC">siscoflores</font>   Tha...
# 2198  <font color="#0066CC">rodrigo_the_creator</fon...
# 2199  <font color="#0066CC">msindell</font>   <font ...
# 2200  <font color="#0066CC">mallory.lmao</font>   Ma...
# 2201  <font color="#0066CC">12hunnidblock</font>   F...
# 2202  <font color="#0066CC">fuenciado_._</font>   Cr...
# 2203  <font color="#0066CC">_leonalitii</font>   Eli...
# 2204  <font color="#0066CC">erinlorraine</font>   <f...
# 2205  <font color="#0066CC">proffessor_horse</font> ...
# 2206  <font color="#0066CC">mattington21</font>   Su...
# 2207  <font color="#0066CC">madilynsophia</font>   <...
# 2208  <font color="#0066CC">enlighten_the_spirit</fo...
# 2209  <font color="#0066CC">mandog423</font>   He be...
# 2210  <font color="#0066CC">melobee_</font>   Who ca...
# 2211  <font color="#0066CC">mike5832</font>   That n...
# 2212  <font color="#0066CC">leephil447</font>   Beau...
# 2213  <font color="#0066CC">timtrew</font>   Stick t...
# 2214  <font color="#0066CC">demondresavagepullen</fo...
# 2215  <font color="#0066CC">hebrew_king21</font>   O...
# 2216  <font color="#0066CC">katie_graf</font>   And ...
# 2217  <font color="#0066CC">chanchi_16</font>   Fatn...
#
#                                                 clmn100  \
# 0                                                empety
# 1                                                empety
# 2     <font color="#0066CC">oopshiharry</font>   Can...
# 3                                                empety
# 4     <font color="#0066CC">buddhaplaysbass</font>  ...
# 5                                                empety
# 6     <font color="#0066CC">sndraibnz</font>   wtf_...
# 7                                                empety
# 8     <font color="#0066CC">l0lelena</font>   Ahhaha...
# 9                                                empety
# 10    <font color="#0066CC">dozi_r</font>   <font co...
# 11                                               empety
# 12    <font color="#0066CC">marriiaaa__</font>   I k...
# 13                                               empety
# 14    <font color="#0066CC">liljswim</font>   Love t...
# 15    <font color="#0066CC">chozzy.wozzy</font>   _...
# 16    <font color="#0066CC">jadea513</font>   Loved ...
# 17                                               empety
# 18    <font color="#0066CC">cottcncandyheart</font> ...
# 19                                               empety
# 20    <font color="#0066CC">jenniebug</font>   <font...
# 21                                               empety
# 22                                               empety
# 23                                               empety
# 24    <font color="#0066CC">curly_q_kiana</font>   W...
# 25                                               empety
# 26    <font color="#0066CC">carod31888</font>   <fon...
# 27                                               empety
# 28                                               empety
# 29    <font color="#0066CC">maximus_gardette85</font...
# ...                                                 ...
# 2188                                             empety
# 2189                                             empety
# 2190                                             empety
# 2191                                             empety
# 2192  <font color="#0066CC">damaskgrinnell</font>   ...
# 2193                                             empety
# 2194                                             empety
# 2195  <font color="#0066CC">tru_scorpio_king</font> ...
# 2196  <font color="#0066CC">wild_hogs_5</font>   I w...
# 2197                                             empety
# 2198  <font color="#0066CC">mauricioxsoto</font>   F...
# 2199                                             empety
# 2200  <font color="#0066CC">sarah_clubb</font>   <fo...
# 2201  <font color="#0066CC">selfmade_cardi</font>   ...
# 2202                                             empety
# 2203  <font color="#0066CC">tydale_yrn</font>   Elit...
# 2204                                             empety
# 2205                                             empety
# 2206                                             empety
# 2207  <font color="#0066CC">misskriss62</font>   <fo...
# 2208                                             empety
# 2209                                             empety
# 2210  <font color="#0066CC">mrcbd</font>   _____...
# 2211                                             empety
# 2212                                             empety
# 2213                                             empety
# 2214                                             empety
# 2215                                             empety
# 2216  <font color="#0066CC">_1989hox</font>   I just...
# 2217  <font color="#0066CC">eman_m10</font>   ....yo...
#
#                                                 clmn101  \
# 0                                                empety
# 1                                                empety
# 2     <font color="#0066CC">nuriaat</font>   <font c...
# 3                                                empety
# 4     <font color="#0066CC">tjbyerly</font>   <font ...
# 5                                                empety
# 6     <font color="#0066CC">ileanakock</font>   Gwn ...
# 7                                                empety
# 8     <font color="#0066CC">mueller_mira</font>   Ha...
# 9                                                empety
# 10    <font color="#0066CC">jakecardinalee</font>   ...
# 11                                               empety
# 12    <font color="#0066CC">emmaaacaniff</font>   <f...
# 13                                               empety
# 14    <font color="#0066CC">dwpyy</font>   this is m...
# 15    <font color="#0066CC">erzzamaloku</font>   How...
# 16    <font color="#0066CC">kellikole</font>   Love ...
# 17                                               empety
# 18    <font color="#0066CC">hes_clueing_for_looks</f...
# 19                                               empety
# 20    <font color="#0066CC">anat_blitz</font>   <fon...
# 21                                               empety
# 22                                               empety
# 23                                               empety
# 24    <font color="#0066CC">huda_187</font>   U foun...
# 25                                               empety
# 26    <font color="#0066CC">mehlene</font>   And thi...
# 27                                               empety
# 28                                               empety
# 29    <font color="#0066CC">rowank01</font>   ROMNEY...
# ...                                                 ...
# 2188                                             empety
# 2189                                             empety
# 2190                                             empety
# 2191                                             empety
# 2192  <font color="#0066CC">sadieileen</font>   <fon...
# 2193                                             empety
# 2194                                             empety
# 2195  <font color="#0066CC">jake.day</font>   <font ...
# 2196  <font color="#0066CC">r_mack10</font>   I had ...
# 2197                                             empety
# 2198  <font color="#0066CC">the_real_anthony100</fon...
# 2199                                             empety
# 2200  <font color="#0066CC">wendyfiliti</font>   <fo...
# 2201  <font color="#0066CC">bigningez</font>   Smack...
# 2202                                             empety
# 2203  <font color="#0066CC">carsonb1230</font>   Ran...
# 2204                                             empety
# 2205                                             empety
# 2206                                             empety
# 2207  <font color="#0066CC">rukiyeakm</font>   this ...
# 2208                                             empety
# 2209                                             empety
# 2210  <font color="#0066CC">dritowel</font>   Keep d...
# 2211                                             empety
# 2212                                             empety
# 2213                                             empety
# 2214                                             empety
# 2215                                             empety
# 2216  <font color="#0066CC">_1989hox</font>   And ge...
# 2217  <font color="#0066CC">eyee_van</font>   <font ...
#
#                                                 clmn102  \
# 0                                                empety
# 1                                                empety
# 2     <font color="#0066CC">agusjalo</font>   This i...
# 3                                                empety
# 4     <font color="#0066CC">fivefour</font>   <font ...
# 5                                                empety
# 6     <font color="#0066CC">olivias_01</font>   <fon...
# 7                                                empety
# 8     <font color="#0066CC">casu259</font>   Hi  (cr...
# 9                                                empety
# 10    <font color="#0066CC">rasyaadikoro</font>   Hh...
# 11                                               empety
# 12    <font color="#0066CC">breanna_marie_1</font>  ...
# 13                                               empety
# 14    <font color="#0066CC">lucianacunha82</font>   ...
# 15    <font color="#0066CC">bleonebrestovci</font>  ...
# 16    <font color="#0066CC">lovemyboys40</font>   Lo...
# 17                                               empety
# 18    <font color="#0066CC">confessionsbyyou</font> ...
# 19                                               empety
# 20    <font color="#0066CC">thelibertinee</font>   O...
# 21                                               empety
# 22                                               empety
# 23                                               empety
# 24    <font color="#0066CC">owen002</font>   BURN  (...
# 25                                               empety
# 26    <font color="#0066CC">ayyyzma</font>   Love lo...
# 27                                               empety
# 28                                               empety
# 29    <font color="#0066CC">_nicolala</font>   Obama...
# ...                                                 ...
# 2188                                             empety
# 2189                                             empety
# 2190                                             empety
# 2191                                             empety
# 2192  <font color="#0066CC">sleepy.little.kitty</fon...
# 2193                                             empety
# 2194                                             empety
# 2195  <font color="#0066CC">zaylo704</font>   Jon co...
# 2196  <font color="#0066CC">luckygoal4</font>   I ha...
# 2197                                             empety
# 2198  <font color="#0066CC">the_real_anthony100</fon...
# 2199                                             empety
# 2200  <font color="#0066CC">giorgiacaruana</font>   ...
# 2201  <font color="#0066CC">anazfinest</font>   All ...
# 2202                                             empety
# 2203  <font color="#0066CC">aidan_northup17</font>  ...
# 2204                                             empety
# 2205                                             empety
# 2206                                             empety
# 2207  <font color="#0066CC">nasser__alothman</font> ...
# 2208                                             empety
# 2209                                             empety
# 2210  <font color="#0066CC">donchristo310</font>   T...
# 2211                                             empety
# 2212                                             empety
# 2213                                             empety
# 2214                                             empety
# 2215                                             empety
# 2216  <font color="#0066CC">_1989hox</font>   These ...
# 2217  <font color="#0066CC">bryanvega_</font>   <fon...
#
#                   ...                           likes  \
# 0                 ...                  4313\r\r likes
# 1                 ...                  2102\r\r likes
# 2                 ...                108939\r\r likes
# 3                 ...                  6441\r\r likes
# 4                 ...                  1153\r\r likes
# 5                 ...                  4381\r\r likes
# 6                 ...                  8199\r\r likes
# 7                 ...                  3366\r\r likes
# 8                 ...                 86443\r\r likes
# 9                 ...                    61\r\r likes
# 10                ...                 46290\r\r likes
# 11                ...                   964\r\r likes
# 12                ...                197284\r\r likes
# 13                ...                  2236\r\r likes
# 14                ...                  3195\r\r likes
# 15                ...                 14528\r\r likes
# 16                ...                 28972\r\r likes
# 17                ...                  1244\r\r likes
# 18                ...                 10524\r\r likes
# 19                ...                  7866\r\r likes
# 20                ...                  8916\r\r likes
# 21                ...                   529\r\r likes
# 22                ...                    85\r\r likes
# 23                ...                  6868\r\r likes
# 24                ...                 23406\r\r likes
# 25                ...                  1140\r\r likes
# 26                ...                 15713\r\r likes
# 27                ...                   807\r\r likes
# 28                ...                  2135\r\r likes
# 29                ...                  8362\r\r likes
# ...               ...                             ...
# 2188              ...                       630 likes
# 2189              ...                        40 likes
# 2190              ...                        34 likes
# 2191              ...                       503 likes
# 2192              ...                      1816 likes
# 2193              ...                       695 likes
# 2194              ...                       147 likes
# 2195              ...                      7331 likes
# 2196              ...                       486 likes
# 2197              ...                       127 likes
# 2198              ...                     22892 likes
# 2199              ...                      4425 likes
# 2200              ...                      4245 likes
# 2201              ...                      2751 likes
# 2202              ...                       101 likes
# 2203              ...                       697 likes
# 2204              ...                       312 likes
# 2205              ...                       510 likes
# 2206              ...                      1258 likes
# 2207              ...                      7520 likes
# 2208              ...                       232 likes
# 2209              ...                      3075 likes
# 2210              ...                      2314 likes
# 2211              ...                      2757 likes
# 2212              ...                       294 likes
# 2213              ...                       442 likes
# 2214              ...                       196 likes
# 2215              ...                        50 likes
# 2216              ...                       454 likes
# 2217              ...                     37734 likes
#
#                                              owner_cmnt  \
# 0     gosh we love these five idiots so much __ for...
# 1     Anyone see the Pepsi halftime show commercial ...
# 2     Today I ate cr_pes and bought a drawing of ch...
# 3     New works in progress for an upcoming show at ...
# 4     Due to overwhelming response, we have went ahe...
# 5                      Loving the leather-denim combo."
# 6                                  OMFG I'M DYING _Û_"
# 7                      Yay or nay? tag your friends_ä
# 8      Afternoon in Campo Bahia with the team _Û__"
# 9     i leave you with one of my favorite harry vide...
# 10      Wishing you a happy birthday, dear @erickoston.
# 11                                     Brick by brick."
# 12                  Ridin' dirty with @hayes_instagram"
# 13                                                __"
# 14                         Pink stripes or pink shoes?"
# 15    New snapback from @larepublicclothing _´ Lov...
# 16    Charlie looking very pleased with his "#MerylS...
# 17    Doing kissy face with my baby @drodd36 #BodyEn...
# 18                                 when doge sees cate"
# 19     Cole & I up at 6 am. JK. He's still asleep __"
# 20                                                _±"
# 21                         Completely normal kids demo"
# 22    Emily missed this picture ): but with the love...
# 23                                      #doge4president
# 24                 Buuurn_î!!! @NailsCamera _Ñ___"
# 25    #repost big S/O to the awesome @Vladogirl , th...
# 26                    'Ciao Milano' by Hayden Williams"
# 27    Tune into @mtv Tuesday Jan 7th - 10pm EST, to ...
# 28    Dinner last night at @Herringbonemondrian w/ m...
# 29    Today is Election Day! #WeWill #GoVote @rockth...
# ...                                                 ...
# 2188   S/O and thank you to my boy <font color="#006...
# 2189   Maan this guy is messed up f*ckin racist bitc...
# 2190   A Third World War,the perfect set up to bring...
# 2191                                     true or false?
# 2192   Tell me what pisses you off and rant about it...
# 2193                                          HELL YEAH
# 2194   What's your favorite music video from the War...
# 2195   DAAAAAMN! <font color="#0066CC">@jarrenbenton...
# 2196                                        Go! Comment
# 2197   Fuck what y'all niggas talking bout we really...
# 2198               X games. Everybody say Fuck Anthony.
# 2199   Our dude <font color="#0066CC">@bjenner</font...
# 2200   YOU CAN NEVER TAKE HARRY SERIOUSLY WHEN HE SA...
# 2201   They asked where the mustard bottle was my so...
# 2202                    Sorry but I just had to do this
# 2203   It's time for <font color="#0066CC">#WhatFigu...
# 2204                                          Fan mail.
# 2205   The Collar-Bomb Murder of Ana Elvia in Colomb...
# 2206                     New music video up, LINK in bi
# 2207   No matter what you believe in, hunting/no hun...
# 2208   Is the root of the problem the gun? Or the fi...
# 2209   Eric Fisher gets ready for his headshot | <fo...
# 2210                                     Shit cray !!!!
# 2211   Camp life.. <font color="#0066CC">#MikeVickWe...
# 2212   Signed over 300 pics at today's signing ! Fou...
# 2213   Skills! <font color="#0066CC">#sundayfunday</...
# 2214   Lol <font color="#0066CC">#tupacamarushakur#t...
# 2215   Who cares right? There both just books? ___...
# 2216                 Media posted at 014-06-21 20:57:44
# 2217   Next Stop: Knockout Round! <font color="#0066...
#
#                                                owner_id   question1  \
# 0              <font color="#0066CC">maliksbby</font>       noneAgg
# 1           <font color="#0066CC">witneycarson</font>       noneAgg
# 2            <font color="#0066CC">namelessgem</font>       noneAgg
# 3                   <font color="#0066CC">kaws</font>    aggression
# 4               <font color="#0066CC">fivefour</font>       noneAgg
# 5         <font color="#0066CC">adidasneolabel</font>       noneAgg
# 6               <font color="#0066CC">sextpert</font>       noneAgg
# 7          <font color="#0066CC">avanityaffair</font>       noneAgg
# 8             <font color="#0066CC">gotzemario</font>       noneAgg
# 9            <font color="#0066CC">kingstyless</font>       noneAgg
# 10                <font color="#0066CC">nikesb</font>       noneAgg
# 11         <font color="#0066CC">dennistodisco</font>       noneAgg
# 12          <font color="#0066CC">jackgilinsky</font>       noneAgg
# 13               <font color="#0066CC">loekenz</font>       noneAgg
# 14        <font color="#0066CC">adidasneolabel</font>       noneAgg
# 15        <font color="#0066CC">itsjonasfossum</font>       noneAgg
# 16           <font color="#0066CC">meryledavis</font>       noneAgg
# 17         <font color="#0066CC">carlafacciolo</font>       noneAgg
# 18             <font color="#0066CC">doge.post</font>       noneAgg
# 19           <font color="#0066CC">skyferreira</font>       noneAgg
# 20          <font color="#0066CC">insta_kitten</font>       noneAgg
# 21     <font color="#0066CC">jordanroriepayton</font>       noneAgg
# 22         <font color="#0066CC">hayleyamelia_</font>       noneAgg
# 23             <font color="#0066CC">doge.post</font>       noneAgg
# 24            <font color="#0066CC">bestttextt</font>       noneAgg
# 25         <font color="#0066CC">vladofootwear</font>       noneAgg
# 26       <font color="#0066CC">hayden_williams</font>       noneAgg
# 27           <font color="#0066CC">missfamenyc</font>       noneAgg
# 28               <font color="#0066CC">klarity</font>       noneAgg
# 29        <font color="#0066CC">bridgitmendler</font>    aggression
# ...                                                 ...         ...
# 2188        <font color="#0066CC">paulwallbaby</font>    aggression
# 2189    <font color="#0066CC">makavellijackson</font>    aggression
# 2190          <font color="#0066CC">childofyah</font>       noneAgg
# 2191       <font color="#0066CC">nesserfamilia</font>       noneAgg
# 2192           <font color="#0066CC">jerkstiel</font>    aggression
# 2193     <font color="#0066CC">andthatismyfact</font>       noneAgg
# 2194          <font color="#0066CC">keshatoday</font>       noneAgg
# 2195           <font color="#0066CC">hopsinson</font>    aggression
# 2196    <font color="#0066CC">patriotsfootball</font>       noneAgg
# 2197          <font color="#0066CC">ice_marrow</font>    aggression
# 2198      <font color="#0066CC">larryfisherman</font>    aggression
# 2199        <font color="#0066CC">thehoonigans</font>    aggression
# 2200         <font color="#0066CC">haroldluvme</font>       noneAgg
# 2201           <font color="#0066CC">djmustard</font>    aggression
# 2202        <font color="#0066CC">andybvb_fanp</font>       noneAgg
# 2203           <font color="#0066CC">ringsidec</font>       noneAgg
# 2204          <font color="#0066CC">jeffdauler</font>    aggression
# 2205        <font color="#0066CC">notexplained</font>       noneAgg
# 2206           <font color="#0066CC">joeysalad</font>    aggression
# 2207       <font color="#0066CC">sophiamiacova</font>    aggression
# 2208  <font color="#0066CC">enlighten_the_spirit</fo...     noneAgg
# 2209            <font color="#0066CC">kcchiefs</font>    aggression
# 2210           <font color="#0066CC">djmustard</font>    aggression
# 2211            <font color="#0066CC">mikevick</font>    aggression
# 2212             <font color="#0066CC">rebysky</font>    aggression
# 2213          <font color="#0066CC">shawnsuggs</font>    aggression
# 2214  <font color="#0066CC">tupac_amaru_shakur1996</...     noneAgg
# 2215          <font color="#0066CC">childofyah</font>    aggression
# 2216             <font color="#0066CC">cutting</font>    aggression
# 2217        <font color="#0066CC">soccerdotcom</font>    aggression
#
#      question1:confidence question2 question2:confidence shared media  \
# 0                  0.8124   noneBll               1.0000         1477
# 1                  1.0000   noneBll               1.0000          761
# 2                  0.8056   noneBll               0.8056          698
# 3                  0.5982  bullying               0.5982         1257
# 4                  1.0000   noneBll               1.0000         2052
# 5                  1.0000   noneBll               1.0000         1520
# 6                  1.0000   noneBll               1.0000         2158
# 7                  0.5980   noneBll               1.0000         2616
# 8                  0.7965   noneBll               0.7965          507
# 9                  1.0000   noneBll               1.0000          377
# 10                 1.0000   noneBll               1.0000         1019
# 11                 0.8056   noneBll               0.8056          658
# 12                 0.7965   noneBll               1.0000          325
# 13                 0.6091   noneBll               0.6091         1451
# 14                 0.7926   noneBll               0.7926         1520
# 15                 1.0000   noneBll               1.0000          536
# 16                 1.0000   noneBll               1.0000          695
# 17                 0.7965   noneBll               1.0000         1208
# 18                 1.0000   noneBll               1.0000          277
# 19                 0.8035   noneBll               0.8035         2179
# 20                 0.7926   noneBll               0.7926          984
# 21                 0.5982   noneBll               0.5982         1087
# 22                 1.0000   noneBll               1.0000          239
# 23                 0.7965   noneBll               0.7965          277
# 24                 0.5982   noneBll               0.5982          627
# 25                 0.8035   noneBll               0.8035         1639
# 26                 1.0000   noneBll               1.0000         1567
# 27                 1.0000   noneBll               1.0000         1005
# 28                 0.8078   noneBll               1.0000          858
# 29                 0.7969  bullying               0.6093          765
# ...                   ...       ...                  ...          ...
# 2188               1.0000  bullying               0.6117         1884
# 2189               1.0000  bullying               1.0000          644
# 2190               1.0000   noneBll               1.0000         1905
# 2191               1.0000   noneBll               1.0000          640
# 2192               0.8051   noneBll               0.5888         2514
# 2193               0.8055   noneBll               0.8055          462
# 2194               1.0000   noneBll               1.0000          277
# 2195               0.6245  bullying               0.6245         1247
# 2196               1.0000   noneBll               1.0000         1147
# 2197               1.0000  bullying               1.0000         1187
# 2198               1.0000  bullying               0.8018         1556
# 2199               1.0000  bullying               0.8081         1959
# 2200               0.5995   noneBll               0.8022         1847
# 2201               1.0000  bullying               1.0000         1949
# 2202               1.0000   noneBll               1.0000         3351
# 2203               1.0000   noneBll               1.0000         1521
# 2204               0.7965   noneBll               0.6024         1676
# 2205               0.7997   noneBll               0.7997          498
# 2206               1.0000  bullying               1.0000          780
# 2207               1.0000  bullying               0.7995          407
# 2208               1.0000   noneBll               1.0000         2727
# 2209               0.7908  bullying               0.7908         1280
# 2210               1.0000  bullying               0.5886         1949
# 2211               0.7867  bullying               0.7867          323
# 2212               0.6017  bullying               0.6017         1266
# 2213               0.7879   noneBll               0.7963         1607
# 2214               1.0000   noneBll               1.0000         2204
# 2215               0.6090   noneBll               0.5868         1905
# 2216               0.5954   noneBll               0.5975          319
# 2217               1.0000  bullying               1.0000         2009
#
#            label                    image_names
# 0         normal   552190883286908244_298930414
# 1         normal     642359127764866726_6922532
# 2         normal   647118643004316858_627934998
# 3       bullying                           None
# 4         normal     714072510509514236_4879766
# 5         normal    675458665342891496_12958644
# 6         normal   609710384873238487_650673866
# 7         normal                           None
# 8         normal   326629905817324694_237159274
# 9         normal                           None
# 10        normal    709380341579654667_26490008
# 11        normal     512433051729855776_4145448
# 12        normal    639287130613158659_54217883
# 13        normal   454320667353994039_206604147
# 14        normal    447219051462718639_12958644
# 15        normal                           None
# 16        normal    734180960711230639_19570784
# 17        normal    487010175421664223_41085145
# 18        normal   621448822633198172_363197235
# 19        normal   608569070829974114_179861803
# 20        normal   340391427958787728_251101170
# 21        normal   505146992545029518_173930054
# 22        normal                           None
# 23        normal   634985029644251431_363197235
# 24        normal                           None
# 25        normal    732178613622458956_25051713
# 26        normal    396350735489250600_37504940
# 27        normal   627674052492589070_244975829
# 28        normal    707359384817630884_26221534
# 29      bullying    318884887533226902_53167593
# ...          ...                            ...
# 2188    bullying    735537793712264421_17296540
# 2189    bullying   735555112724831441_270483046
# 2190      normal   735675530169475160_243598255
# 2191      normal     735712401639406803_2811086
# 2192  aggression   736046144866767539_391491299
# 2193      normal                           None
# 2194      normal                           None
# 2195    bullying   737102530862896608_215707036
# 2196      normal   737525783643346863_191104148
# 2197    bullying    738253376803007770_16326242
# 2198    bullying    738275438920576337_10514202
# 2199    bullying    738418075889277490_10176765
# 2200      normal   738601214135415558_293518499
# 2201    bullying    739308126836821188_13512754
# 2202      normal   740308670017689655_712250757
# 2203      normal   740564309307006754_325781254
# 2204  aggression      740574134516332082_983084
# 2205      normal                           None
# 2206    bullying   741378265404139922_278236785
# 2207    bullying    741399243826850211_14105697
# 2208      normal     741439969975495914_7077714
# 2209    bullying     741455725993483816_3315342
# 2210    bullying    742170348852284880_13512754
# 2211    bullying    742743725022238626_25771652
# 2212    bullying    742983839856476354_12270015
# 2213  aggression    743666690560754068_10427687
# 2214      normal  743879405552600819_1125593136
# 2215  aggression   746509199826150022_243598255
# 2216  aggression   747963877363716269_704541443
# 2217    bullying     749477682261450660_6389534
#
# [2218 rows x 217 columns]
